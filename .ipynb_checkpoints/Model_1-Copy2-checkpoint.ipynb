# %%
# !pip install tfa-nightly
# !pip install pygame
# Out:
# Collecting tfa-nightly
#   Downloading tfa_nightly-0.15.0.dev20211014164307-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 14.9 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tfa-nightly) (2.7.1)
# Installing collected packages: tfa-nightly
# Successfully installed tfa-nightly-0.15.0.dev20211014164307
# Collecting pygame
#   Downloading pygame-2.0.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (13.8 MB)
#      |████████████████████████████████| 13.8 MB 15.3 MB/s
# Installing collected packages: pygame
# Successfully installed pygame-2.0.2

# %%
import os

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from difflib import SequenceMatcher

import random
import json
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
import tensorflow.keras as keras
from keras.regularizers import l2, L1
import tensorflow_addons as tfa
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, TimeDistributed, Dense, Activation, Embedding, GRU
from sklearn.model_selection import train_test_split

import pygame
from IPython.display import Image, display

gpus = tf.config.experimental.list_physical_devices('GPU') 
for gpu in gpus: 
  tf.config.experimental.set_memory_growth(gpu, True)

print("Tensorflow version is: ", tf.__version__)
assert tf.__version__[0] == '2'

# %load_ext tensorboard

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.8)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Tensorflow version is:  2.6.0
# Tue Oct 19 19:27:42 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 471.41       Driver Version: 471.41       CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:02:00.0 Off |                  N/A |
# | N/A    0C    P8     2W /  N/A |     90MiB /  6144MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Data Processing Functions

# %%
def convert_to_df(lines):
    all_rows = []
    index = 0
    num_tunes = 0

    # For each line in the file, 
    for line in lines:

        # To ensure we skip the newlines 
        if len(line) > 1:

            print(line)

            # If the line has an X (index value)
            if line[0] == 'X':

                # If this not the first line 
                if index != 0: 

                    # Add everything in dict_line to the all_rows list
                    all_rows.append(dict_line)
                    print("**** Added info: Added dict_line to all rows ****")
                    print()

                # Create an empty dict 
                dict_line = {}
                dict_line['transcription'] = ''

                index += 1
                num_tunes += 1

                print("**** Added info: Dictionary reinitialized ****")
                print()

                continue

            # else if the line has an M, 
            elif line[0] == 'M':

                # Save everything after the colon to dict_line with key 'M'
                dict_line['M'] = line[2:].strip()
                print("**** Added info: Dictionary added M = " + dict_line['M'] + " ****")
                print()
                continue

            # else if the line has a K, 
            elif line[0] == 'K':

                # Save everything after the colon to dict_line with key 'K'
                dict_line['K'] = line[2:].strip()
                print("**** Added info: Dictionary added K = " + dict_line['K'] + " ****")
                print()

            # else if the conditions for it being the transcription are true, 
            elif (line[0] == "|" or line[1] != ":") and (line[0] != "%") and (line != ''):

                # Add that to the dict_line with key 'transcription'
                dict_line['transcription'] += line.strip()
                print("**** Added info : Dictionary added transcription ****")
                print()        


    df = pd.DataFrame(all_rows)
    return df



# Version of previous function that takes in just one generated sample and returns a dictionaty in the 
# dict_line format from the previous function
def convert_sample_to_dict(generated_sample):
    
    dict_line = {}
    dict_line['transcription'] = ''
    
    # For each line in the generated sample, 
    for line in generated_sample.splitlines():
        
        # To ensure we skip the newlines 
        if len(line) > 1:
            
            # if the line has an M,
            if line[0] == "M":    
                
                # Save everything after the colon to dict_line with key 'M'
                dict_line['M'] = line[2:].strip()
                continue
            
            # else if the line has a K,
            elif line[0] == 'K':
                
                # Save everything after the colon to dict_line with key 'K'
                dict_line['K'] = line[2:].strip()
                continue
            
            # else if the conditions for it being the transcription are true, 
            elif (line[0] == "|" or line[1] != ":") and (line[0] != "%") and (line != ''):
                
                # Add that to the dict_line with key 'transcription'
                dict_line['transcription'] += line.strip()
                
    
    return dict_line


# Function that gives each character an index number and returns a dictionary (as well as a reversed dictionary)
def give_characters_indexes(data):

    char_index_dict = {}
    index_char_dict = {}
    for (i, char) in enumerate(sorted(list(set(data)))):
        char_index_dict[char] = i
        index_char_dict[i] = char

    with open(data_directory + char_index_json, mode = "w") as f:
        json.dump(char_index_dict, f)

    return char_index_dict, index_char_dict

# %% [markdown]
# # Sequence Generator Functions

# %%
# Function taken and modified from here - https://medium.datadriveninvestor.com/music-generation-using-deep-learning-85010fb982e2 
def generate_sequence(epoch_num, initial_index, seq_length):
    
    char_index_dict, index_char_dict = give_characters_indexes(data)
    num_unique_chars = len(index_char_dict)

    generator_model = make_model(num_unique_chars)
    weights_dir = model_weights_directory + "Weights_{}.h5".format(num_epochs)
    generator_model.load_weights(weights_dir)

    sequence_index = [initial_index]
    
    for _ in range(seq_length):
        batch = np.zeros((1, 1))
        batch[0, 0] = sequence_index[-1]
        
        predicted_probs = generator_model.predict_on_batch(batch).ravel()
        sample = np.random.choice(range(num_unique_chars), size = 1, p = predicted_probs)
        sequence_index.append(sample[0])
    
    seq = ''.join(index_char_dict[c] for c in sequence_index)
    
    #print(f"SEQ: {seq}"
    
    if seq == '':
        return ''

    cnt = 0
    if len(seq) > 1:
        
        for j in seq:
            cnt += 1
            if j == "\n":
                break
        seq1 = seq[cnt:]
    else:
        return ''
    #print(f"SEQ1: {seq1}")
    #above code is for ignoring the starting string of a generated sequence. This is because we are passing any arbitrary 
    #character to the model for generating music. Now, the model start generating sequence from that character itself which we 
    #have passed, so first few characters before "\n" contains meaningless word. Model start generating the music rhythm from
    #next line onwards. The correct sequence it start generating from next line onwards which we are considering.
    
    if seq1 == '':
        return ''

    cnt = 0

    if len(seq1) > 1:
        for j in seq1:
            cnt += 1
            if j == "\n":
                if len(seq1) > cnt:
                    if seq1[cnt] == "\n":
                        break
        seq2 = seq1[:cnt]
    else:
        return ''
    #print(f"SEQ2: {seq2}")
    #Now our data contains three newline characters after every tune. So, the model has leart that too. So, above code is used for
    #ignoring all the characters that model has generated after three new line characters. So, here we are considering only one
    #tune of music at a time and finally we are returning it..
    
    return seq2

# %% [markdown]
# # Evaluation Functions

# %%
# Function that takes care of the 'Distribution Similarity' pillar
def compare_distributions(music_df, generated_df, metric):
    
    # Get the value counts of both the datasets
    generated_df_val_counts = dict(generated_df[metric].value_counts(normalize=True, ascending=False))
    music_df_val_counts = dict(music_df[metric].value_counts(normalize=True, ascending=False))
    
    print()
    print("Original Dataset Distribution")
    print(music_df_val_counts)
    print("Generated Dataset Distribution")
    print(generated_df_val_counts)
    
    # Add the missing keys from each dataset to the otehr
    for key in music_df_val_counts.keys():
        if key not in generated_df_val_counts.keys():
            generated_df_val_counts[key] = 0

    unique_keys = []
    for key in generated_df_val_counts.keys():
        if key not in music_df_val_counts.keys():
            unique_keys.append(key)
            music_df_val_counts[key] = 0

    print()
    print(f"Unique '{metric}' values to generated dataset: {unique_keys}")
    print()

    # Plot the figure for both distributions
    plt.figure(figsize=(15,7))
    plt.grid(True)
    
    # Number of bars we want for the figure
    num_bars = np.arange(len(music_df_val_counts))           
    width = 0.3
    
    plt.bar(num_bars, music_df_val_counts.values() , width, label='Original Dataset')
    plt.bar(num_bars + width, generated_df_val_counts.values(), width, label='Generated Dataset')
    plt.xticks(num_bars + width / 2, music_df_val_counts.keys())
    plt.legend(loc='best')
    plt.show()

    
    
# Function that takes care of the 'Error Rate' pillar
def determine_error_rate(generated_df):

    num_errors = 0
    for i in range(len(generated_df)):
        
        # If the transcription is empty
        if (generated_df.iloc[i]['transcription'] == ''):
            num_errors += 1
        
        # Else if the transcription is null
        elif (pd.isnull(generated_df.iloc[i]['transcription'])):
            num_errors += 1
        
        # Else if the 'K' value is null
        elif pd.isnull(generated_df.iloc[i]['K']):
            num_errors += 1
        
        # Else if the 'K' value has any characters other than letters
        elif not (all(i.isalpha() for i in generated_df.iloc[i]['K'])):
            num_errors += 1
        
        # Else if the 'M' valye is null
        elif pd.isnull(generated_df.iloc[i]['M']):
            num_errors += 1
        
        # Else if the 'M' value has any letters
        elif (any(i.isalpha() for i in generated_df.iloc[i]['M'])):
            num_errors += 1
        
    error_rate = (num_errors / len(generated_df)) * 100
        
    return error_rate

# Function that takes care of the "Average Maximum Similarity Score" pillar
def get_average_similarity_score(music_df, generated_df):
    
    total_similarity_score = 0
    
    # For each generated sample
    for i in range(len(generated_df)):
        
        # Get the transcription value from the dataframe
        generated_sample = generated_df.iloc[i]["transcription"]
        max_similarity_score = 0
        
        # For each training sample
        for j in range(len(music_df)):
            
            # Get the transcription value from the dataframe
            original_sample = music_df.iloc[j]["transcription"]
            
            # Calculate the similarity score
            similarity_score = SequenceMatcher(None, generated_sample, original_sample).ratio()
            
            # If this is the most similar transcription, save to max
            if similarity_score > max_similarity_score:
                max_similarity_score = similarity_score
        
        total_similarity_score += max_similarity_score
    
    # Return the average of all the max scores
    avg_similarity_score = total_similarity_score / len(generated_df)
    return avg_similarity_score

# Average Length comparison function
def get_length_comparison(music_df, generated_df):

    return music_df['transcription'].apply(len).mean(), generated_df['transcription'].apply(len).mean()


# Function that brings it all together and prints out the different performance metrics
def evaluate_performance(music_df, generated_df):
    print("-------------------------------------------------------------------------------------")
    print("Distribution Comparison - Meter / Time Signature")
    compare_distributions(music_df, generated_df, 'M')
    print("-------------------------------------------------------------------------------------")
    print()
    
    print("-------------------------------------------------------------------------------------")
    print("Distribution Comparison - Key")
    compare_distributions(music_df, generated_df, 'K')
    print("-------------------------------------------------------------------------------------")
    print()
    
    print("-------------------------------------------------------------------------------------")
    print("Average Length Comparison")
    original_length, generated_length = get_length_comparison(music_df, generated_df)
    print(f"Original Average Transcription Length - {original_length}")
    print(f"Generated Average Transcription Length - {generated_length}")
    print("-------------------------------------------------------------------------------------")
    print()

    print("-------------------------------------------------------------------------------------")
    print(f"Error Rate - {determine_error_rate(generated_df)}%")
    print("-------------------------------------------------------------------------------------")
    print()
    
    print("-------------------------------------------------------------------------------------")
    print(f"Average Max Similarity Score - {get_average_similarity_score(music_df, generated_df)}")
    print("-------------------------------------------------------------------------------------")
    print()

# %% [markdown]
# # Function for playing samples

# %% [markdown]
# The following code to play the samples in the notebook was taken from here - https://www.daniweb.com/programming/software-development/code/216976/play-a-midi-music-file-using-pygame

# %%
freq = 44100    # audio CD quality
bitsize = -16   # unsigned 16 bit
channels = 2    # 1 is mono, 2 is stereo
buffer = 1024    # number of samples
pygame.mixer.init(freq, bitsize, channels, buffer)

# optional volume 0 to 1.0
pygame.mixer.music.set_volume(1)

def play_music(music_file):
    """
    stream music with mixer.music module in blocking manner
    this will stream the sound from disk while playing
    """
    clock = pygame.time.Clock()
    try:
        pygame.mixer.music.load(music_file)
        #print("Music file %s loaded!" % music_file)
    except pygame.error:
        print("File %s not found! (%s)" % (music_file, pygame.get_error()))
        return
    pygame.mixer.music.play()
    while pygame.mixer.music.get_busy():
        # check if playback has finished
        clock.tick(30)

# %%
data_directory = "Data/"
data_file = "Data_Tunes.txt"
char_index_json = "char_to_index.json"

file_ = open(data_directory+data_file, 'r')
data_lines = file_.readlines()
music_df = convert_to_df(data_lines)

file_ = open(os.path.join(data_directory, data_file), mode = 'r')
data = file_.read()

char_index_dict, index_char_dict = give_characters_indexes(data)
num_unique_chars = len(char_index_dict)
all_characters = np.asarray([char_index_dict[c] for c in data], dtype = np.int32)
# Out:
# X: 1
#
# **** Added info: Dictionary reinitialized ****
#
# T:A and D
#
# % Nottingham Music Database
#
# S:EF
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# K:A
#
# **** Added info: Dictionary added K = A ****
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# P:A
#
# f|"A"ecc c2f|"A"ecc c2f|"A"ecc c2f|"Bm"BcB "E7"B2f|
#
# **** Added info : Dictionary added transcription ****
#
# "A"ecc c2f|"A"ecc c2c/2d/2|"D"efe "E7"dcB| [1"A"Ace a2:|
#
# **** Added info : Dictionary added transcription ****
#
#  [2"A"Ace ag=g||\
#
# **** Added info : Dictionary added transcription ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# P:B
#
# "D"f2f Fdd|"D"AFA f2e/2f/2|"G"g2g ecd|"Em"efd "A7"cBA|
#
# **** Added info : Dictionary added transcription ****
#
# "D"f^ef dcd|"D"AFA f=ef|"G"gfg "A7"ABc |1"D"d3 d2e:|2"D"d3 d2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 2
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Abacus
#
# % Nottingham Music Database
#
# S:By Hugh Barwell, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# "G"g2g B^AB|d2d G3|"Em"GAB "Am"A2A|"D7"ABc "G"BAG|
#
# **** Added info : Dictionary added transcription ****
#
# "G"g2g B^AB|d2d G2G|"Em"GAB "Am"A2G|"D7"FGA "G"G3::
#
# **** Added info : Dictionary added transcription ****
#
# "D7"A^GA DFA|"G"B^AB G3|"A7"^c=c^c Ace|"D7"fef def|
#
# **** Added info : Dictionary added transcription ****
#
# "G"g2g de=f|"E7"e2e Bcd|"Am"c2c "D7"Adc| [1"G"B2A G3:|
#
# **** Added info : Dictionary added transcription ****
#
#  [2"G"B2A G2F||"Em"E2E G2G|B2B e2e|"Am"c2A "B7"FBA|"Em"G2F E3|"Em"EFG "Am"ABc|
#
# **** Added info : Dictionary added transcription ****
#
# "B7"B^c^d "Em"e2e|"F#7"f2f f2e|"B7"^def BAF|"Em"E2E G2G|B2B e2e|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"c2A "B7"FBA|"Em"G2F E3|"Em"EFG "Am"ABc|"B7"B^c^d "Em"e2e|
#
# **** Added info : Dictionary added transcription ****
#
# "F#7"f2e "B7"^def |[1"Em"e3 "D7"d3:|[2"Em"e3 "E7"e3||
#
# **** Added info : Dictionary added transcription ****
#
# X: 3
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:The American Dwarf
#
# % Nottingham Music Database
#
# S:FTB, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# P:A
#
# A|"D" def fed|"G" BdB AFD| "D"DFA "G"B2 A|"Em" cee "A7" e2 A|
#
# **** Added info : Dictionary added transcription ****
#
# "D" def fed|"G" BdB "D"AFD|"D" DFA "G"B2 A|"A7" Add "D" d2:|
#
# **** Added info : Dictionary added transcription ****
#
# "B"e|"D"fga agf|"G" gab "A7"bag|"D"fga "D"agf|"Em" gfg "A7"e2 g|
#
# **** Added info : Dictionary added transcription ****
#
# "D"fga agf|"G"gab "A7"bag|"D" fga "A7"efg|"D" fdd d2 :|
#
# **** Added info : Dictionary added transcription ****
#
# X: 4
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Ap Shenkin
#
# % Nottingham Music Database
#
# P:AABABA
#
# S:FTB 1 p 46, via EF
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# |d/2c/2\
#
# **** Added info : Dictionary added transcription ****
#
# P:A
#
# !segno! "G"B2B Bgf|"C"e2e efg|"G"ded "Em"dcB|"Am"cAA "D7"Adc|
#
# **** Added info : Dictionary added transcription ****
#
# "G"BcB Bgf|"C"efe efg|"G"ded "D7"cBA|"G"G2B G3|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# |g/2a/2|"G"b2g "D"a2f|"G"gfg "G"dcB|"C"cde "G"dgB|"Am"BAA "D7"A2g/2a/2|
#
# **** Added info : Dictionary added transcription ****
#
# "G"b2g "D"a2f|"Em"gfe "D7"agf|"G"bag "A7"fge|"D7"dgf ed\
#
# **** Added info : Dictionary added transcription ****
#
# P:D.S.
#
# c|
#
# **** Added info : Dictionary added transcription ****
#
# X: 5
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Armstrongs
#
# % Nottingham Music Database
#
# S:Kevin Briggs, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:A
#
# **** Added info: Dictionary added K = A ****
#
# P:A
#
# e|"A"eaf e2c|"E7"BAB "A"c3|"A"E2A "E7/b"BAB|"A/c+"cBc "D"dcd|
#
# **** Added info : Dictionary added transcription ****
#
# "A"eaf e2c|"E7"BAB "A"c3|"E7"E2E EFG|"A"A3 A2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# e|"A"ecA Acd|"A"ecA "E7"B2A|"A"ecA cAc|"Bm"B2B "E7"dcd|
#
# **** Added info : Dictionary added transcription ****
#
# "A"ecA Acd|"A"ecA Acd|"E7"e2e efg|"A"aec A2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 6
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Arthur Darley
#
# % Nottingham Music Database
#
# S:Formally, but with lift, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# dc/2B/2|\
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# A2D AGF|EDC D3|\
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# d2e fgf|edc d2A|
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# d2e fgf|\
#
# **** Added info : Dictionary added transcription ****
#
# M:9/8
#
# **** Added info: Dictionary added M = 9/8 ****
#
# edc d2A BAG|\
#
# **** Added info : Dictionary added transcription ****
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# FED EDC|DA,B, CDE|
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# Ddd \
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# Aee|\
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# Aff \
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# Agg|fed edc|d3 dcB||
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# !segno! A2D AGF|EDC D3|d2e fgf|edc d2A|d2e fgf|
#
# **** Added info : Dictionary added transcription ****
#
# M:9/8
#
# **** Added info: Dictionary added M = 9/8 ****
#
# edc d2A BAG|\
#
# **** Added info : Dictionary added transcription ****
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# FED EDC|DA,B, CDE|
#
# **** Added info : Dictionary added transcription ****
#
# Ddd Aee|Aff Agg|fed edc|d3 d=c_B
#
# **** Added info : Dictionary added transcription ****
#
# |:\
#
# **** Added info : Dictionary added transcription ****
#
# K:F
#
# **** Added info: Dictionary added K = F ****
#
# A2f fef|A2f fef|\
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# Aff
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# Agg|\
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# Aaa \
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# Abb|A2f fef
#
# **** Added info : Dictionary added transcription ****
#
# |A2f f2g|fed ed^c|1d3 dcB:|2d3 d2e||
#
# **** Added info : Dictionary added transcription ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# fgf edc|d2A BAG|\
#
# **** Added info : Dictionary added transcription ****
#
# FED EDC|DA,B, CDE|
#
# **** Added info : Dictionary added transcription ****
#
# Ddd Aee|Aff Agg|fed edc|\
#
# **** Added info : Dictionary added transcription ****
#
# P:Fine.
#
# d3 dc\
#
# **** Added info : Dictionary added transcription ****
#
# P:D.S.
#
# B||
#
# **** Added info : Dictionary added transcription ****
#
# X: 7
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:As Luck Will Have It
#
# % Nottingham Music Database
#
# S:John Lagden, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# E|"D"F3 "A7/c+"A2G|"Bm"FGF "A7"E3|"D"F2A d2c|"G"BcB "D"A3|"G"G2B "A7"A2G|\
#
# **** Added info : Dictionary added transcription ****
#
# "D"F2A d2f|
#
# **** Added info : Dictionary added transcription ****
#
# "G"efe "E7"dcB|"A7"ABA GFE|"D"F3 "A7/c+"A2G|"Bm"FGF "A7"E3|"D"F2A d2c|
#
# **** Added info : Dictionary added transcription ****
#
# "G"BcB "D"A3|"G"G2B "A7"A2G|"D"F2E "Bm"D2F|"Em"EFG "A7"F2E|"D"D3 -D2||
#
# **** Added info : Dictionary added transcription ****
#
# A|"D"d3 fed|"A"c2d e2A|"Bm"Bcd c2B|"F#m"A3 A2A|"G"B3 dcB|
#
# **** Added info : Dictionary added transcription ****
#
# "D"A2d f2a|"G"agf "E7"fed|"A7"e3 e2A|"D"d3 fed|"A"c2B A2A|
#
# **** Added info : Dictionary added transcription ****
#
# "Bm"B3 dcB|"F#m"A3 A2F|"G"G3 BAG|"D"F2A d2D|"Em"EFG "A7"F2E|"D"D3 -D2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 8
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Atholl Highlanders
#
# % Nottingham Music Database
#
# P:AABBCCDD
#
# S:Kevin Briggs, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:A
#
# **** Added info: Dictionary added K = A ****
#
# P:A
#
# |:c/2d/2|"A"e3 ecA|"A"ecA "E7"Bcd|"A"e3 ecA|"D"Bcd "E7"cBA|
#
# **** Added info : Dictionary added transcription ****
#
# "A"e3 ecA|"A"ecA "E7"Bcd|"A"e/2a3/2e "D"fed|"E7"cdB "A"A2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# |:e|"A"Ace Ace|"D"Adf Adf|"A"Ace Ace|"Bm"Bcd "E7"c2B|
#
# **** Added info : Dictionary added transcription ****
#
# "A"Ace Ace|"D"Adf Adf|"A"e/2a3/2e "D"fed|"E7"cdB "A"A2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:C
#
# |:e|"A"aee edc|"A"aee edc|"A"aee edc|"D"Bcd "E7"cBA|
#
# **** Added info : Dictionary added transcription ****
#
# "A"aee edc|"A"aee edc|"A"aee fed|"E7"cdB "A"A2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:D
#
# |:A/2B/2|"A"cAc cAc|"D"dBd dBd|"A"cAc cAc|"G"B=GB BGB|
#
# **** Added info : Dictionary added transcription ****
#
# "A"cAc cAc|"E7"dBd dBd|"A"e/2a3/2e "D"fed|"E7"cdB "A"A2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 9
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Aunt Mary's Canadian Jig
#
# % Nottingham Music Database
#
# S:Ms L Dolman, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# A|"D"f2f fga|d2d dcB|"D"ABA "B7"AGF|"Em"E2E E2A|
#
# **** Added info : Dictionary added transcription ****
#
# "A7"e2e efg|e2d c2B|ABA ABA|"D"F3 F2:|
#
# **** Added info : Dictionary added transcription ****
#
# A|"D"ABA fgf|e2d d2z|"D"AFA "B7"BcB|"Em"A2G G2z|
#
# **** Added info : Dictionary added transcription ****
#
# "A7"GFG efe|d2c c2B|ABA ABc|"D"d3 d2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 10
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Avon Jig
#
# % Nottingham Music Database
#
# S:Pauline Wilson, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Em
#
# **** Added info: Dictionary added K = Em ****
#
# B|"Em"e2e B2B|GAB E3|"D7"FED AGF|FED AGF|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"e2e B2B|"Em"GAB E3|"D7"FED A2A|"Em"GEE E2::
#
# **** Added info : Dictionary added transcription ****
#
# D|"G"G2G B2B|"D7"ABA D3|"G"G2G B2B|"Am"d2d "D7"cBA|"G"G2G B2B|"D7"ABA D3|\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"EFG "A7"FED|"Em"E3 -E2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 11
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Backstairs Jig
#
# % Nottingham Music Database
#
# S:EF
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# P:A
#
# d|"G"d2b baf|"G"a2g g2g|"D7"f2f fef|"G"a2g "D7"gfe|
#
# **** Added info : Dictionary added transcription ****
#
# "G"d2b baf|"G"a2g g2g|"D7"f2f fef|"G"a2g fg:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# d|"G"gfg bge|"D7"d2d def|"G"gfg bge|"A7"e2d "D7"def|
#
# **** Added info : Dictionary added transcription ****
#
# "G"g2g "G7"gab|"C"e2e "Am"efg|"D7"ded cBF|"G"GBd g2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 12
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:The Leaking Bagpipe
#
# % Nottingham Music Database
#
# S:The Cantii Collection, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# D3 |"Em"E3 B2A|B2G E2G|"D"F3 A2G|A2F DEF|"Em"E3 B2A|"Em"B2c d2e|"G"B2A "C"G2F|\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"E3 ::
#
# **** Added info : Dictionary added transcription ****
#
# G3 |"Am"A3 c2B|A2B c2A|"Em"E3 G2F|E2F G2E|"Am"A3 c2B|A2B c2d|"Em"e2f gfg|\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"e3 :|
#
# **** Added info : Dictionary added transcription ****
#
# X: 13
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Ballybunion
#
# % Nottingham Music Database
#
# S:Folk Camps, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# P:A
#
# B/2A/2|"G"G3 "C"g2e|"G/b"dBG "D7/a"AFD|"G"G3 "C"g2e|"G"dBG "D"A2B|
#
# **** Added info : Dictionary added transcription ****
#
# "G""Em"G3 g2e|"G"dBG GAB|"C"cde "G/b"dcB|"D7/a"cBA "G"G2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# B|"Em"eBe gbg|"Em"eBe gbg|"Em"eBe g2a|"Am"bag "B7"agf|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"eBe "Em/d+"gbg|"Em/d"eBe "Em/c+"g2a|"Am/c"bag "B7"agf|1"Em"e3 e2:|2\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"e3 "D7"d2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 14
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Barbary Bell
#
# % Nottingham Music Database
#
# S:Kevin Briggs, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# P:A
#
# d|"G"GAG GBc|"G"ded dBG|"C"ABc "G/b"BAG|"Am"EGE "D7"E2D|
#
# **** Added info : Dictionary added transcription ****
#
# "G"GAG GBc|"G"ded dBG|"C"ABc "G/b"BAG|"C"E2F "G"G2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# D|"D7"def "G"gag|"D"fed "Em"edB|"Bm"def "Em"gag|"Bm"fed "Em"e2d|
#
# **** Added info : Dictionary added transcription ****
#
# "D7"def "G"gdB|"C"cde "G"dBG|"C"ABc "G/b"BAG|"C"E2F "G"G2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 15
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:The Barley Mow
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# "G"G2G "D"A2A|"G"B2c dBG|"C"E2E c2B|"Am"ABG "D7"FED|"G"G2G "D"A2A|"G"B2c dBG|\
#
# **** Added info : Dictionary added transcription ****
#
# "C"EcB "D7"AGF|"G"G6:|
#
# **** Added info : Dictionary added transcription ****
#
# "G"d2d "C"e2e|"G"d2g dBG|"G"d2d "C"e2e|"G"dBG "D"A3|"G"d2d "C"e2e|"G"d2g g2f|\
#
# **** Added info : Dictionary added transcription ****
#
# "A7"egf ed^c|"D7"d3 D3||
#
# **** Added info : Dictionary added transcription ****
#
# "G"G2G "D"A2A|"G"B2c dBG|"C"E2E c2B|"Am"ABG "D7"FED|"G"G2G "D"A2A|"G"B2c dBG|\
#
# **** Added info : Dictionary added transcription ****
#
# "C"EcB "D7"AGF|"G"G6||
#
# **** Added info : Dictionary added transcription ****
#
# X: 16
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Bean Setting (North Skelton)
#
# % Nottingham Music Database
#
# S:EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# P:A
#
# G/2A/2|"G"BAG D2D|"C"EFG "D7"FED|"G"BAG D2D|"C"E2D "D7"G2A|"G"BAG D2D|
#
# **** Added info : Dictionary added transcription ****
#
# "C"EFG "D7"FED|"G"BAG D2D|"C"E2D "D7"G2A|"G"B2B "D"A2A|"Em"G2G "Bm"FED|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"G2B "D7"A2F|"G"G2B "G7"d3|"C"e2e "G"d2B|"D7"c2c "G"BAG|"G"GAB "C"c2B|\
#
# **** Added info : Dictionary added transcription ****
#
# "D7"AGF "G"G2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 17
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Belfast Almanac
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# D|"G"G2G "D7"FED|"C"E2F G2A|"G"B2G "D7"c2A|"G"B2G "D7"c2A|
#
# **** Added info : Dictionary added transcription ****
#
# "G"B3/2c/2d "Am"E2E|"A7"ABG "D7"FED|"C"EFG "D7"AFD|"G"G3 -G2::
#
# **** Added info : Dictionary added transcription ****
#
# c|"G"Bcd def|g2g g3|"G"B2B Bcd|"C"e2e e3|
#
# **** Added info : Dictionary added transcription ****
#
# "G"dcB "C"cde|"G"dBd D2D|"C"EFG "D7"AFD|"G"G3 -G2::
#
# **** Added info : Dictionary added transcription ****
#
# A|"G"B2G "D7"c2A|"G"B2G "D7"c2A|"G"Bcd "C"E2E|"A7"ABG "D7"FED|
#
# **** Added info : Dictionary added transcription ****
#
# "G"B2G "D7"c2A|"G"B2G Bcd|"C"EFG "D7"AFD|"G"G3 -G2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 18
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Bell's Favourite
#
# % Nottingham Music Database
#
# S:Don Messer's Way Down East Fiddlin' Tunes, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# A|"D"FEF "G"GFG|"D"BAF A2d|"A7"cde ABc|"D"dcB "A7"A2G|
#
# **** Added info : Dictionary added transcription ****
#
# "D"FEF "G"GFG|"D"BAF A2d|"A7"cde ABc|"D"d3 d2::
#
# **** Added info : Dictionary added transcription ****
#
# f|"D"aba fef|"Em"gfg e2d|"A7"cde ABc|"D"dcB "A7"A2f|
#
# **** Added info : Dictionary added transcription ****
#
# "D"aba fef|"Em"gfg e2d|"A7"cde ABc|"D"d3 d2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 19
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Squire of Bensham
#
# % Nottingham Music Database
#
# S:NPTB, via EF
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# K:C
#
# **** Added info: Dictionary added K = C ****
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# P:A
#
# c/2d/2|"C"edc "F"A2F|"C/e"G2c "G7/d"E2c|"C"edc g2c|"Dm"Bdd "G7"d2c/2d/2|
#
# **** Added info : Dictionary added transcription ****
#
# "C"edc "F"A2c|"C"G2c "Am"E2c|"Dm"def "G7"e2d|"C"edc c2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# |:c/2d/2|"C"ed"C/e"c g2c|"F"c'2a "G7"g2c|"C"edc g2c|"Dm"Adc "G7"BAG|
#
# **** Added info : Dictionary added transcription ****
#
# "C"ed"C/c"c g2c|"F"c'2a "G"ggf|"Am"abc' "G7/b"bd'b|[1"C"c'ge c2:|[2 "C" c'ge c3|
#
# **** Added info : Dictionary added transcription ****
#
# X: 20
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:The Bent Pin
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# "A7"A|"D"D2F A2d| "G7"^A2B "D"=AFD|\
#
# **** Added info : Dictionary added transcription ****
#
# "G7"^A2B "D"=AFD|"E7" =FDF "A7"EDB,|
#
# **** Added info : Dictionary added transcription ****
#
# "D"D2^F A2d|\
#
# **** Added info : Dictionary added transcription ****
#
# "G7"^A2B "D"=AFD|"E7"=FDF "A7"EDB,|"D"D3 -D2::
#
# **** Added info : Dictionary added transcription ****
#
# d|"G7"B2d e2=f| "D"^fdB A2d|"G7"B=Fd e2=f|"D"fdB A2d|
#
# **** Added info : Dictionary added transcription ****
#
# "G7"B=Fd e2=f\
#
# **** Added info : Dictionary added transcription ****
#
# | "D"=fdB "Bm"ABA|\
#
# **** Added info : Dictionary added transcription ****
#
# =FDF "A7"EDB,|"D"D3 -D2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 21
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Biddy The Bowl Wife
#
# % Nottingham Music Database
#
# S:FTB 2 34, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:A
#
# **** Added info: Dictionary added K = A ****
#
# P:A
#
# c|"A"EAc e2f|"A"ecA a2f|"A"ecA EAc|"D"dcd "E7"B2c|
#
# **** Added info : Dictionary added transcription ****
#
# "A"EAc e2f|"A"ecA a2f|"A"ecA EAc|"E7"B3 "A"A2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# e|"A"efe a2g|"D"bag fga|"A"ecA EAc|"E7"dcd B2e|
#
# **** Added info : Dictionary added transcription ****
#
# "A"efe a2g|"D"bag fga|"A"ecA EAc|"E7"B3 "A"A2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 22
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Bill Charlton's Fancy
#
# % Nottingham Music Database
#
# S:Billy Pigg, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# P:A
#
# (3d/2e/2f/2|"G"g2G f2G|e2G d3|"G"DGB dBG|"D"DFA c3|"D"aAc g2A|
#
# **** Added info : Dictionary added transcription ****
#
# "D"f2A e3|"D7"d^cd e2=c|"G"Bdg B2d|"G"gGB f2G|e2G d3|"G"DGB dBG|
#
# **** Added info : Dictionary added transcription ****
#
# "C"ecA E3|"C"ecG EGc|"G"gdB GBd|"D7"fed ^cdF|"G"GBd g2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# (3d/2e/2f/2|gGB fGB|eGB dGB|eGB dGB|cAF DFA|
#
# **** Added info : Dictionary added transcription ****
#
# aAc gAc|fAc eAc|d^cd ^de=c|Bdg B2d|
#
# **** Added info : Dictionary added transcription ****
#
# gGB fGB|eGB dGB|eGB dGB|"C"ecA E3|
#
# **** Added info : Dictionary added transcription ****
#
# "C"ecG EGc|"G"gdB GBd|"D7"fed ^cdF|"G"GBd g2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:C
#
# d|bGB aBG|gGB fGB|eGB dGB|cAF DFA|
#
# **** Added info : Dictionary added transcription ****
#
# aAc gAc|fAc eAc|d^cd ^de=c|Bdg B2d|
#
# **** Added info : Dictionary added transcription ****
#
# bGB aBG|gGB fGB|eGB dGB|"C"ecA E3|
#
# **** Added info : Dictionary added transcription ****
#
# "C"ecG EGc|"G"gdB GBd|"D7"fed ^cdF|"G"GBd g2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 23
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Blackberry Quadrille
#
# % Nottingham Music Database
#
# S:Kevin Briggs, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# P:A
#
# f/2g/2|"D"a2a ba^g|"D"a2f d2f|"A7"e2c A2g|"D"fdB "A7"A2f/2g/2|
#
# **** Added info : Dictionary added transcription ****
#
# "D"a2a ba^g|"D"a2f d2f|"A7"e2c ABc|"D"d3 d2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# c/2B/2|"D"A2B "A7"G2A|"D"F2A def|"Em"g2e "A7"cBc|"D"dfe "G"dcB|
#
# **** Added info : Dictionary added transcription ****
#
# "D"A2B "A7"G2A|"D"F2A def|"G"g2e "A7"cBc|"D"d3 d2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 24
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Blackthorne Stick
#
# % Nottingham Music Database
#
# S:Kevin Briggs, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# P:A
#
# d|"G"gfg "C"ege|"G"dBG "C"AGE|"G"DGG "D7"FGA|"G"BAG "D7"A2d|
#
# **** Added info : Dictionary added transcription ****
#
# "G"gfg "C"age|"G"dBG "C"AGE|"G"DGG "D7"FGA|"G"BGG G2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# d|"G"edd gdd|"G"edd gdd|"G"ede "C"gfe|"Am"dcB "D7"A2d|
#
# **** Added info : Dictionary added transcription ****
#
# "G"gfg "C"age|"G"dBG "C"AGE|"G"DGG "D7"FGA|"G"BGG G2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 25
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Blarney Pilgrim
#
# % Nottingham Music Database
#
# P:AABBCC
#
# S:Alistair Anderson, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# P:A
#
# |:D|"G"DED DEG|"C"A2G ABc|"G"BAG "C"AGE|"Am"GEA "D7"GED|
#
# **** Added info : Dictionary added transcription ****
#
# "G"DED DEG|"C"A2G ABc|"G"BAG "C"AGE|"D7"GED D2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# |:d|"G"ded dBG|"Am"AGA "Em"BGE|"G"ded dBG|"C"AGA "D7"GBd|
#
# **** Added info : Dictionary added transcription ****
#
# "G"g2e dBG|"Am"AGA "Em"BGE|"Em"B2G AGE|"Em"GAG G2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:C
#
# |:G|"D"A2D "Em"B2D|"D"A2D ABc|"G"BAG "C"AGE|"Am"GEA "D7"GED|
#
# **** Added info : Dictionary added transcription ****
#
# "D"A2D "Em"B2D|"D"A2D ABc|"G"BAG "C"AGE|"D7"GED D2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 26
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Blaydon Races
#
# % Nottingham Music Database
#
# S:Kevin Briggs, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# A|"D"d2d d2d|"D"d2d d2d|"A7"e2e e2e|"D"f3 "D7"d3|"G"ggg g2g|"D"f2f f2f|
#
# **** Added info : Dictionary added transcription ****
#
# "E7"e2f e2d|"A7"c3 A3|"D"d2d d2d|"D"d2d d2d|"A7"e2e e2e|"D"f3 "D7"d3|\
#
# **** Added info : Dictionary added transcription ****
#
# "G"ggg g2g|
#
# **** Added info : Dictionary added transcription ****
#
# "D"f2g a2a|"A7"a2g f2e|"D"d2e f2g|"D"a3 "A7/e"a2f|"D/f+"d3 "G"d2d|\
#
# **** Added info : Dictionary added transcription ****
#
# "E7/g+"e2e "A7"e2e|
#
# **** Added info : Dictionary added transcription ****
#
# "D"f3 "D7/c"d3|"G/b"g2g "A7/c+"g2g|"D"f2f "D/f+"f2f|"G"e2f "E7/g+"e2d|\
#
# **** Added info : Dictionary added transcription ****
#
# "A"c3 "A7/g"A3|"D/f+"d2d "G"d2d|"D/f+"d3 "G"d2d|
#
# **** Added info : Dictionary added transcription ****
#
# "E7/g+"e2e "A7"e2e|"D"f3 "D7/c"d3|"G/b"g2g "A7/c+"g2g|"D"f2g "B7/f+"a2a|\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"a2g "A7"f2e|"D"d3 d2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 27
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Bonnets So Blue
#
# % Nottingham Music Database
#
# P:AAB
#
# S:Kevin Briggs, via EF
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# K:C
#
# **** Added info: Dictionary added K = C ****
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# P:A
#
# |:G|"C"cdc efg|"G7"GAG GAB|"C"ceg gec|"G7"d2e gfd|
#
# **** Added info : Dictionary added transcription ****
#
# "C"cdc efg|"Dm"GAG "G7"G2g|"Am"gfe "G7"dcB|"C"c3 c2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# |:d/2c/2|"G/b"Bcd "D7/a"ded|"G/b"G3 "D7/a"G2c|"G"Bcd "G7/f"def|"C/e"g3 "G7/d"g2f|
#
# **** Added info : Dictionary added transcription ****
#
# "C"e2 d c2 "b"B|"Am"A2 B c2 d|"Am" efe "E7" dcB|"Am" A3 "G7" G3|
#
# **** Added info : Dictionary added transcription ****
#
# "C"cdc efg|"C" cdc "G7" c2A|"C"ceg gec|"Dm" d3 "G7" e2d|
#
# **** Added info : Dictionary added transcription ****
#
# "C"cdc efg|"G"GAG G2 g| "Am" gfe "G7"dcB|"C" c3 c2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 28
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Bonnets So Blue
#
# % Nottingham Music Database
#
# P:AAB
#
# S:FTB 1 p 47, via EF
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# P:A
#
# |:A|"D"ded def|"A7"ABA ABc|"A7"dfb afd|"A7"efe e2A|
#
# **** Added info : Dictionary added transcription ****
#
# "D"ded def|"A7"ABA A2b|"Bm"agf "A7"age|"D"d3 d2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# |:e/2d/2|"A"cde "E7"efe|"A"A3 A2d|"A"cde "A7"efg|"D"a3 "A7"a2g|"D"f2e d2c|\
#
# **** Added info : Dictionary added transcription ****
#
# "Bm"B2c d2e|
#
# **** Added info : Dictionary added transcription ****
#
# "Bm"fgf "F#7"edc|"Bm"B3 "A7"A3|"D"def def|"D"def d2A|"D"dfb agf|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"egf "A7"e2A|"D"def def|"Bm"def d2b|"Em"agf "A7"age|"D"d3 d2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 29
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Brian Borouhme
#
# % Nottingham Music Database
#
# S:Jimmy Galway, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Am
#
# **** Added info: Dictionary added K = Am ****
#
# P:A
#
# e|"Am"cBA Aed|"Am"cBA A2"ab"d|"G"BAG Gdc|"G"BAG G2" ""gb"e|
#
# **** Added info : Dictionary added transcription ****
#
# "Am""F"cBA Aed|"Am""F"cBA A2B|"Dm""E7"cde "E7"e2d|"Am"cAA A2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# B|"C"cde efe|"C"efe edc|"G"Bcd ded|"G"ded dcB|
#
# **** Added info : Dictionary added transcription ****
#
# "C"cde efe|"C"efe edc|"E7"e3 e2d|"Am"cAA A2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 30
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Bridal Jig
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# D|"G"G2G BGB|"D"def "Em"gfg|"Am"ecA "G"dBG|"D7"FAG FED|
#
# **** Added info : Dictionary added transcription ****
#
# "G"GFG BGB|"D"def "Em"gfg|"Am"ecA "G"dBG|"D7"FED G2::
#
# **** Added info : Dictionary added transcription ****
#
# A|"Em"Bee edB|"D"def "Em"g2a|"G"bag "D"agf|"Em"geg "Bm"fdB|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"Bee edB|"D"def "Em"g2a|"G"bag "D"agf| [1"Em"gee e2:|\
#
# **** Added info : Dictionary added transcription ****
#
#  [2"G"g2g gdB||
#
# **** Added info : Dictionary added transcription ****
#
# X: 31
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:The Mug of Brown Ale
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# G|"Am"EAA ABd|edB c2A|"G"BGG dGG|Bdc BAG|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"EAA ABd|"Am"ede "Em"a2g|"Am"edc "Em"Bcd|"Am"ecA A2:|
#
# **** Added info : Dictionary added transcription ****
#
# f|"Em"gef g2a|"Em"gef "D7"gdc|"G"BGG dGG|Bdc BAG|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"gef g2a|"D7"gef "G"g2d|"C"edc "E7"Bcd|"Am"ecA A2f|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"gef g2a|"Em"gef "D7"gdc|"G"BGG dGG|Bdc BAG|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"EAA ABd|"Am"ede "Em"a2g|"Am"edc "E7"Bcd|"Am"ecA A2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 32
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:St. Bruno
#
# % Nottingham Music Database
#
# S:Chris Dewhurst, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Dm
#
# **** Added info: Dictionary added K = Dm ****
#
# A|"Dm"d2e f2g|"Dm"a2d "G"def|"C"g2c cde|"Bb"fed "Am"c=BA|
#
# **** Added info : Dictionary added transcription ****
#
# "Dm"d2e "A7"f2g|"Dm"afd "Gm"b2g|"Dm"fed "A"ed^c|"Dm"d3 -d2::
#
# **** Added info : Dictionary added transcription ****
#
# a|"Dm"add "Gm"bdd|"Dm"add fef|"Gm"g2b d'c'b|"Dm"a3 d3|
#
# **** Added info : Dictionary added transcription ****
#
# "Gm"g2a bag|"Dm"afd A2f|"A"e^cA f2e|"Dm"d3 -d2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 33
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Buggy Ride Jig
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# P:INTRO
#
# g|f/2a3/2d f/2a3/2d|fg2 "D7"d^c=c|:"G"B2B BAG|B2B BAG|"G"B/2d3/2G B/2d3/2G|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"Bcc cBc|"D"eff fed|"D"f2f fed|"D7"f/2a3/2d f/2a3/2d|"G"fg2 "D7"gfg::
#
# **** Added info : Dictionary added transcription ****
#
# "G"D2G B2d|"G"b3 -b2f|"G"a2g "E7"f2e|"Am"c3 cBA|"D"c2c cBA|
#
# **** Added info : Dictionary added transcription ****
#
# "D"f2f fed|"Am"f/2a3/2d "D7"f/2a3/2d| [1"G"fg2 gfg:|
#
# **** Added info : Dictionary added transcription ****
#
#  [2"G"g2zz3|"G"g6||
#
# **** Added info : Dictionary added transcription ****
#
# X: 34
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Bung Your Eye
#
# % Nottingham Music Database
#
# S:FTB 2/42, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Am
#
# **** Added info: Dictionary added K = Am ****
#
# P:A
#
# E|"Am"ABA c2d|"Am"edc B2A|"G"GAG B2c|"G"dge dBG|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"ABA c2d|"Am"edc "G"Bcd|"Am"e2A "E7"AB^G|"Am"A3 A2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# B|"C"c3/2d/2e/2f/2 g2a|"C"gec gec|"G"G3/2A/2B/2c/2 d2e|"G"dge dBG|
#
# **** Added info : Dictionary added transcription ****
#
# "C"c3/2d/2e/2f/2 g2a|"C"gec "E7"de^g|"Am"a2A "E7"AB^G|"Am"A3 A2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 35
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:The Burdett
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# A|"D"d2d f2a|"Em"gfg "A7"e2a|"Bm"f2d "E7"B2e|"A7"cBc A2A|
#
# **** Added info : Dictionary added transcription ****
#
# "D"d2d f2a|"Em"gfg "A7"e2a|"Em"afd "A7"gec|"D"d2f d2::
#
# **** Added info : Dictionary added transcription ****
#
# A|"D"d2d "F#m"cBc|"G"B2B B2B|"E7"e2e dcd|"A7"c2c c2A|
#
# **** Added info : Dictionary added transcription ****
#
# "D"dcd "A7"ede|"Bm"fef "Em"gfg|"D"afd "A7"gec|"D"d2f d2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 36
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Cadeau's Jig
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Bb
#
# **** Added info: Dictionary added K = Bb ****
#
# B-c|"Bb"dBF DFB-|dBF DFE-|"Bb"DFB dcB|
#
# **** Added info : Dictionary added transcription ****
#
# "Eb"AG^F "Cm"G2A|"F7"aAA aAa|"F7"g3 -ga-g|"F7"f=ef _ede-|d3 dB-c|
#
# **** Added info : Dictionary added transcription ****
#
# "Bb"dBF DFB-|dBF DFE-|"Bb"DFB dcB-|"Eb"AG^F "Cm"G2A|
#
# **** Added info : Dictionary added transcription ****
#
# "F7"aAA aAa|g3 -gA-G|"F7"FAc -ecA-|"Bb"B3 BF-E||
#
# **** Added info : Dictionary added transcription ****
#
# "Bb"D-FA BFB-|d3 d^c=c|"Bb"B-AB gfg|f3 -f2b|"F7"a3 -a^ga|
#
# **** Added info : Dictionary added transcription ****
#
# "F7"g3 -gag|f=ef _ede|"Bb"d3 -dF-E|"Bb"D-FA BFB-|d3 d^c=c|
#
# **** Added info : Dictionary added transcription ****
#
# "Bb"B-AB gfg|f3 -f2b|"F7"a3 -a^ga|"F7"g3 -gAG|F-Ac ecA-|"Bb"B3 B||
#
# **** Added info : Dictionary added transcription ****
#
# X: 37
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:There Came A Young Man
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Am
#
# **** Added info: Dictionary added K = Am ****
#
# E|"Am"ABA c2d|"Am"edc "D7"\
#
# **** Added info : Dictionary added transcription ****
#
# B2A|"G"GAG B2c|dge d
#
# **** Added info : Dictionary added transcription ****
#
# BG|"Am"ABA c2d|"Am"edc "E7"Bcd|"Am"e2A "E7"AB^G|"Am"
#
# **** Added info : Dictionary added transcription ****
#
# A3 -A2::B|"C"c2e g2a|gec gec|"G"G2B d2e|dge d
#
# **** Added info : Dictionary added transcription ****
#
# BG|"C"\
#
# **** Added info : Dictionary added transcription ****
#
# c2e g2a|"C"gec "E7"de^g|"Am"a2A "E7"AB^G|"Am"A3 -A2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 38
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Captain White
#
# % Nottingham Music Database
#
# P:AAB
#
# S:Kevin Briggs, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# P:A
#
# A|"D"DFA d2f|"A"edc "G"B2d|"D"A2d F2B|"Em"AGF "A7"E2A|
#
# **** Added info : Dictionary added transcription ****
#
# "D"DFA d2f|"A"edc "G"B2d|"D"A2d "Bm"F2B|"A7"ABc "D"d2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# f|"A"e^de A2f|"A"e^de a2f|"Bm"efe "E7"dcB|"A"A2B "E7"c2f|"A"e^de A2f|
#
# **** Added info : Dictionary added transcription ****
#
# "A"e^de a2f|"Bm"efe "E7"dcB|"A7"ABA GFE|"D"D2f fef|"D"d2A A^GA|
#
# **** Added info : Dictionary added transcription ****
#
# "D"D2f fef|"G"gfe "A7"ecA|"D"D2f fef|"D"d2A A^GA|"Em"Bed "A7"cBc|"D"d3 -d2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 39
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Crossing The Cascades
#
# % Nottingham Music Database
#
# S:Mike Richardson 16.9.90, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# "A"A2F |:"D"DED DFA|d3 d2c|"G"B2B Bcd|"D"A3 F2A|
#
# **** Added info : Dictionary added transcription ****
#
# "G"BAB "A"cBc|"D"d2A "Bm"AGF| [1"Em"E2F GFE|"A"C3 A,2C:|
#
# **** Added info : Dictionary added transcription ****
#
#  [2"A"EFG F2E|"D"D3 DFA||"D"d3 def|"F#"c3 -cBc|"G"d2d dcB|"D"A3 F2A|
#
# **** Added info : Dictionary added transcription ****
#
# "G"B2c dcB|"D"A2d "Bm"AGF|"Em"E2F GFE|"A"C3 A2c|"D"d3 def|"F#"c3 -cBc|
#
# **** Added info : Dictionary added transcription ****
#
# "G"d2d dcB|"D"A3 F2A|"G"BAB "A"cBc|"D"dcd "G"efg|"D"fed "A"A2c|"D"d3 ||
#
# **** Added info : Dictionary added transcription ****
#
# X: 40
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:The Castle
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# D|"G"G3 GAB|"Am"A3 "D7"ABc|"G"edd gdd|"C"edB "D7"dBA|
#
# **** Added info : Dictionary added transcription ****
#
# "G"G3 GAB|"Am"A3 "D7"ABc|"G"edd gdB|"D7"AGF "G"G2::
#
# **** Added info : Dictionary added transcription ****
#
# A|"G"BAB dBd|"C"e/2f/2ge "D"dBA|"G"BAB dBG|"D7"ABA A2A|
#
# **** Added info : Dictionary added transcription ****
#
# "G"BAB dBd|"C"e/2f/2ge "D"dBA|"G"gfg "D7"aga|"G"bgg g2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 41
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Cat in the Kitchen
#
# % Nottingham Music Database
#
# S:Bob McQuillen Jan 1975, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Bm
#
# **** Added info: Dictionary added K = Bm ****
#
# F|"Bm"B2c dcB|"Em"e2f gfe|"Bm"fbb bag|"F#7"fgf edc|
#
# **** Added info : Dictionary added transcription ****
#
# "Bm"B2c dcB|"Em"e2f gfe|"Bm"fgf "F#7"edc|[1"Bm"dBB B2:|[2 dBB B
#
# **** Added info : Dictionary added transcription ****
#
# |:"A7"AG|"D"F2B "A7"ABc|"D"d2d "A"ede|"Bm"fBB Bcd|"A"cAA "G"BAG|
#
# **** Added info : Dictionary added transcription ****
#
# "F#m"F2B "A7"ABc|"D"dcd "A"ede|"Bm"fed "F#m"cBA|"Bm"FBB B:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 42
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Cavan Buck
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Bm
#
# **** Added info: Dictionary added K = Bm ****
#
# "Bm""Bm"d2B "F#m""A"c3|"Bm""G"B2c d2e|"Bm"f2f "E7"e2d| "A"c2A ABc|
#
# **** Added info : Dictionary added transcription ****
#
#  "Bm"dcB "F#m"cBA|"Bm"B2c d2e|"Bm"f^ga "F#m"gfe|"Bm"f2B B3::
#
# **** Added info : Dictionary added transcription ****
#
# "D"a2f d2e|"Bm"f2b b2f|"D"a2f "E7"e2d|"A"c2A ABc|
#
# **** Added info : Dictionary added transcription ****
#
# "Bm"dcB "F#m"cBA|"Bm"B2c d2e|"Bm"f^ga "F#m"gfe|"Bm"f2B B3:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 43
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Champion Jig
#
# % Nottingham Music Database
#
# S:EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Em
#
# **** Added info: Dictionary added K = Em ****
#
# P:A
#
# |:B|"Em"Bef gfe|"Em"bef gfe|"B7"f^dB fdB|"B7"bc'b agf|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"Bef gfe|"Em"bef gfe|"B7"b3 b2a|[1"Em"gee e2:|[2 "Em" gee e3|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"\
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# |:d3 "D7"c3|"G"Bdg bgd|"D7"cdf afd|"G"Bdg bgd|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"d3 "D7"c3|"G"Bdg bgd|"D7"cdf afd|"G"gdb g3:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 44
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Charlbytown Two-Step
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:C
#
# **** Added info: Dictionary added K = C ****
#
# ef|"C"g^fg a2g|"C7"edc G2E|"F"FEF A2G|F3 -FEF|"G7"G^FG B2A|
#
# **** Added info : Dictionary added transcription ****
#
# G^FG B2A|"G7"G^FG A2G|"C"E3 -"G7"E2g|"C"g^fg a2g|"C7"edc G2E|"Dm"FEF A2G|
#
# **** Added info : Dictionary added transcription ****
#
# F3 -FEF|"G7"G^FG B2A|G^FG B2A|"G7"GAB e2d|"C"+E3 c3 +zef||
#
# **** Added info : Dictionary added transcription ****
#
# "C"g2g gfe|"C7"g3 -g^fg|"F"agf def|"Dm"a3 -a^ga|"G7"b2a g2f|
#
# **** Added info : Dictionary added transcription ****
#
# "C"e2d cBA|"G""c"G^FG "G7"A2G|"C"e3 -"G7"eef|"C"g2g gfe|"C7"g3 z^fg|"F"agf def\
#
# **** Added info : Dictionary added transcription ****
#
# |
#
# **** Added info : Dictionary added transcription ****
#
# "D7"a3 -a^ga|"G7"b2a g2f|"C"e2d "C/dim"cBA|"G"GAB "G7"e2d|"C"[E3c3]-[E3c3]|
#
# **** Added info : Dictionary added transcription ****
#
# X: 45
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Charlie Hunter
#
# % Nottingham Music Database
#
# S:Jim McLeod, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# P:A
#
# A|"D"DFA "G"GBd|"D/f+"Adf "A7/e"a2g|"D"fed "G"Bcd|"Em"ecA "A7"GFE|
#
# **** Added info : Dictionary added transcription ****
#
# "D"DFA "G"GBd|"D"Adf "A"a2g|"Bm"fef "A7"gec|"A7"edc "D"d2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# f/2g/2|"D"afd d2c|"G"BGG G2F|"E7"E^GB e2d|"A7"cAA Aag|
#
# **** Added info : Dictionary added transcription ****
#
# "D"fdA FDF|"G"GBd g2a/2g/2|"D"fef "A7"gec|"A7"edc "D"d2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 46
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Chuntering Charlie
#
# % Nottingham Music Database
#
# S:John Kirkpatrick, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:C
#
# **** Added info: Dictionary added K = C ****
#
# "C"cGE "G"B2A|"C"GEC "F"F2E|"G"DB,G, DB,G,|"C"CDE "G"D2G|
#
# **** Added info : Dictionary added transcription ****
#
# "C"cGE "G"B2A|"C"GEC "F"F2E|"G"DB,G, DB,G,|"G"GAB "C"c3::
#
# **** Added info : Dictionary added transcription ****
#
# "G"DDD D2E|F2G A2B|"C"cGE "F"B2A|"C"GEC "F"F2E|
#
# **** Added info : Dictionary added transcription ****
#
# "G"DDD D2E|F2G A2B|"C"cGE "F"B2A|"G"GAB "C"c3::
#
# **** Added info : Dictionary added transcription ****
#
# "F"A2c A2G|F2A F2E|"F"D2F D2C|"G"B,2D G,A,B,|
#
# **** Added info : Dictionary added transcription ****
#
# "C"C2E "G"D2F|"C"E2G "F"F2A| "G"BAG BAG|"G"BAG "C"c3:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 47
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Chelmsford Races
#
# % Nottingham Music Database
#
# S:Thomas Hardy Collection, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Bb
#
# **** Added info: Dictionary added K = Bb ****
#
# F|"Bb"B2B BAB|"F"c2c f2f|"Bb"d2d B2B|"F"ABc FGA|
#
# **** Added info : Dictionary added transcription ****
#
# "Bb"B2B BAB|"F"c2c f2f|"Eb"egf "F"edc|"Bb"B2B B2::
#
# **** Added info : Dictionary added transcription ****
#
# f|"Bb"fef def|"Eb"g2g g3|"F"aga fga|"Bb"b2b b3|
#
# **** Added info : Dictionary added transcription ****
#
# "Bb"fef def|"Eb"g2a bag|"Bb"fgf "F7"edc|"Bb"B2B B2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 48
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Cherish The Ladies
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# B/2c/2|"D"dFF AGF|DFA AFA|"Em"BEE GEE|"G"BdB "A7"AFA|
#
# **** Added info : Dictionary added transcription ****
#
# "D"dFF AGF|"D"DFA AFA|"G"Bcd "A7"efg|"D"fdd d2::
#
# **** Added info : Dictionary added transcription ****
#
# B/2c/2|"D"dfd "A"cec|"Bm"BdB "D"AGF|"Em"BEE GEE|"G"BdB "A7"AFA|
#
# **** Added info : Dictionary added transcription ****
#
# "D"dfd "A"cec|"Bm"BdB "D"AFA|"G"Bcd "A7"efg|"D"fdd d2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 49
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Jig For Chris
#
# % Nottingham Music Database
#
# S:Mike Richardson 30.3.89, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# D|"G"GBd "D"cBA|"G"BGE DB,D|"G"EDB, "Em"G,B,D|"Am"GDB, "D"A,2D|
#
# **** Added info : Dictionary added transcription ****
#
# "G"GBd "D"cBA|"G"BGE DB,D|"G"EDB, "Em"G,B,D|"D"EGF "G"G2:|
#
# **** Added info : Dictionary added transcription ****
#
# A|"G"Bdd gdd|"D"Add fdd|"C"Gcc ecA|"D"
#
# **** Added info : Dictionary added transcription ****
#
# P:3
#
# FAG FED|"G"Bdd gdd|"D"Add fdd|"A"egf ed^c|
#
# **** Added info : Dictionary added transcription ****
#
# "D"d3 dcB|"C"cee "G"Bdd|"D"Acc "G"GBB|"C"cBA "G"BAG|"D"FAF DEF|
#
# **** Added info : Dictionary added transcription ****
#
# "G"GBB "C"Acc|"G"Bdd "C"cee|"G"def "Em"gdB|"D"AGF G2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 50
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Circle Around
#
# % Nottingham Music Database
#
# S:Chris Dewhurst 1978, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# "(D7)"B,2C |"G"D2B B^AB|"G"G2D B,CD|"C"E2F GFE|"G"D3 "D"d2c|"G"B2B B^AB|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"G2B E2B|"A7"A^GA ABc|"D"d3 "D7"d2c|"G"B2D B^AB|"G"G2D B,CD|
#
# **** Added info : Dictionary added transcription ****
#
# "C"E2F GFE|"G"D3 ^D3|"C7"E^DE GFE|"G"DGB "Em"d2D|"Am"E2A "D"FEF|"G"G3 B2c||
#
# **** Added info : Dictionary added transcription ****
#
# "G"ded BdB|"G"GBG "C"EGE|"G"DBA GF=F|"C"E3 "E7"e2d|"Am"cdc BcB|
#
# **** Added info : Dictionary added transcription ****
#
# "A7"ABA GAG|"D"FGF "A"EAc|"D"d3 "D7"B2c|"G"ded BdB|"G"GBG "C"EGE|
#
# **** Added info : Dictionary added transcription ****
#
# "G"D2B "G7"c2d|"C"e3 e2f|g2f efg|"G""b"d2B "Em"GAB|"Am"cAF "D"DEF|"G"G3 ||
#
# **** Added info : Dictionary added transcription ****
#
# X: 51
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:The Cobbler
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# D|"D"DFA "G"B2A|"D"def "A7"gfe|"D"fdf "A7"ecA|"G"BGB "D"AFD|
#
# **** Added info : Dictionary added transcription ****
#
# "D"DFA "G"B2A|"D"def "A7"gfe|"D"fdf "A7"ecA|"D"Add d2::
#
# **** Added info : Dictionary added transcription ****
#
# g|"D"fad fad|faa agf|"C"eg=c eg=c|efg gfe|
#
# **** Added info : Dictionary added transcription ****
#
# "D"fef "G"gfg|"D"agf "A7"efg|"D"fed "Am"=cAG|"D"Add d2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 52
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Cock of the North
#
# % Nottingham Music Database
#
# S:Kevin Briggs, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:A
#
# **** Added info: Dictionary added K = A ****
#
# P:A
#
# e/2d/2|"A"cdc cBA|"A"Ace "D"f2e|"A"cdc cBA|"B7"BcB "E7"Bed|
#
# **** Added info : Dictionary added transcription ****
#
# "A"cdc cBA|"A"Ace "D"f2e|"A"c2c "E7"BcB|"A"A3 A2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# (3e/2f/2g/2|"A"a2e "D"f2e|"A"a2e "D"f2e|"A"cdc cBA|"Bm"Bcd "E7"efg|
#
# **** Added info : Dictionary added transcription ****
#
# "A"a2e "D"f2e|"A"a2e "D"f2e|"A"c2c "E7"BcB|"A"A3 A2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 53
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Coleraine
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Am
#
# **** Added info: Dictionary added K = Am ****
#
# E|"Am"EAA ABc|"E7"Bee e2d|"Am"cBA ABc|"E7"B^GE E2E|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"EAA ABc|"E7"Bee e2d|"Am"cBA "E7"B^GE|"Am"A3 -A2::
#
# **** Added info : Dictionary added transcription ****
#
# B|"C"c2c cdc|"G"Bdg g2^g|"Am"aed cBA|"E7"^GBG E^FG|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"A^GA "E7"BAB|"Am"cde "Dm"fed|"Am"cBA "E7"EA^G|"Am"A3 -A2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 54
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:The Connaught Man's Rambles
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# A|"D"FAA dAA|"G"BAB "A7"dAG|"D"FAA "A"Afe|"Bm"dBB "A7"BAG|
#
# ...
#
# **** Added info : Dictionary added transcription ****
#
# X: 45
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Starry Nights of Shetland
#
# % Nottingham Music Database
#
# S:Kevin Briggs
#
# M:3/4
#
# **** Added info: Dictionary added M = 3/4 ****
#
# L:1/4
#
# K:C
#
# **** Added info: Dictionary added K = C ****
#
# G|"C"e2c|"C"GAG|"Dm"F3|"Dm"B2A|"G"G2B|"G"d2G|"C"e3-|"C"e2G|"C"e2c|
#
# **** Added info : Dictionary added transcription ****
#
# "C"GAG|"Dm"F3|"Dm"B2A|"G"G3/2B/2d/2e/2|"G7"fAB|"C"c3-|"C"cde|"F"fAf|
#
# **** Added info : Dictionary added transcription ****
#
# "F"fAf|"C"eGe|"C"eGe|"C"ece|"Am"gfe|"Dm"d3-|"G7"d2G|
#
# **** Added info : Dictionary added transcription ****
#
# "C"e2c|"C"GAG|"Dm"F3|"Dm"B2A|"G"G3/2B/2d/2e/2|"G7"fAB|"C"c3-|"C"c2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 46
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Just as the Sun was Setting
#
# % Nottingham Music Database
#
# S:John Kirkpatrick
#
# M:3/4
#
# **** Added info: Dictionary added M = 3/4 ****
#
# L:1/4
#
# K:Am
#
# **** Added info: Dictionary added K = Am ****
#
# E|"Am"A3/2B/2A|"Am"e2a|"Em"g3/2a/2g|"Em"e2d|"Am"c3/2B/2A|"G"BAG|"F"A3/2B/2A|\
#
# **** Added info : Dictionary added transcription ****
#
# "E7"E2E|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"A3/2B/2A|"Am"e2a|"C"g3/2a/2g|"Em"e2d|"Am"c3/2B/2A|"E7"e3/2d/2e|"Am"A2"G"G|\
#
# **** Added info : Dictionary added transcription ****
#
# "Am"A2e|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"a3/2b/2"B7"a|"E7"^g2e/2^f/2|"G"g3/2a/2"A7"g|"D"^f2d/2e/2|"F"f3/2g/2"G7"f|\
#
# **** Added info : Dictionary added transcription ****
#
# "C"e2d|"F"c3/2d/2c|"E7"B2E|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"A3/2B/2A|"Am"e2a|"C"g3/2a/2g|"Em"e2d|"Am"c3/2B/2A|"E7"e3/2d/2e|"Am"A2"G"G|\
#
# **** Added info : Dictionary added transcription ****
#
# "Am"A2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 47
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Sunset Over Ayr
#
# % Nottingham Music Database
#
# S:Bryon Bonnett
#
# M:3/4
#
# **** Added info: Dictionary added M = 3/4 ****
#
# L:1/4
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# D|"G"B3/2A/2B|"Bm"d2d|"C"eGA|"D7"B2A|"Em"G3/2F/2G|"C"G2G|"Am"ecB|
#
# **** Added info : Dictionary added transcription ****
#
# "D7"A2D|"G"B3/2A/2B|"Bm"d2d|"C"gcB|"D7"B2A|"Em"B3/2A/2B|"Bm"d2D|"D7"DBA|
#
# **** Added info : Dictionary added transcription ****
#
# "G"G2A|"Em"B3/2A/2B|"Bm"d2d|"Em"B3/2A/2B|"Bm"d3|"C"e2e|"G"d2B|B3/2c/2B|"D7"A2D\
#
# **** Added info : Dictionary added transcription ****
#
# |
#
# **** Added info : Dictionary added transcription ****
#
# "G"B3/2A/2B|"Bm"d2d|"C"gcB|"D7"B2A|"Em"B3/2A/2B|"Bm"d2D|"D7"DBA|"G"G2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 48
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Twickenham Ferry
#
# % Nottingham Music Database
#
# S:by Pat Shuldam-Shaw for Amy Foxley
#
# M:3/4
#
# **** Added info: Dictionary added M = 3/4 ****
#
# L:1/4
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# d|"G"g3/2f/2e|"G/b"d3/2c/2B|"C"A3/2B/2G|"D7"FED|"G"G3/2A/2B|"G"d3/2e/2B|\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"d3/2e/2B|
#
# **** Added info : Dictionary added transcription ****
#
# "D"d2e/2f/2|"Em"g3/2f/2e|"Bm"d3/2c/2B|"A7"A3/2B/2G|"D7"FED|"G"G3/2E/2"f#"D|\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"G3/2E/2"d"D|"C"G3/2E/2D|
#
# **** Added info : Dictionary added transcription ****
#
# "G"G2d|"Em"e3/2f/2e|"Em"B^AB|"Bm"d3/2e/2d|"Bm"dcB|"Em"e3/2f/2e|"Em"B^AB|\
#
# **** Added info : Dictionary added transcription ****
#
# "Bm"d3/2e/2d|
#
# **** Added info : Dictionary added transcription ****
#
# "D7"def|"G"g3/2f/2e|"Bm"d3/2c/2B|"A7"A3/2B/2G|"D7"FED|"G"G3/2E/2"f#"D|\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"G3/2E/2"d"D|"C"G3/2E/2D|"G"G2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 49
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Waters of Tyne
#
# % Nottingham Music Database
#
# S:NPTB
#
# M:3/4
#
# **** Added info: Dictionary added M = 3/4 ****
#
# L:1/4
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# F/2G/2|"D"AFF|"A"AFE|"G"DD3/2D/2|"D"D2E/2F/2|"G"GGF|"A"EFA|"G"BB3/2B/2|
#
# **** Added info : Dictionary added transcription ****
#
# "A"A2F/2E/2|"D"Dd3/2d/2|"D"def|"D"dA3/2B/2|"G"B2c/2d/2|"D"AFA|"A"A2F/2E/2|\
#
# **** Added info : Dictionary added transcription ****
#
# "G"DD3/2D/2|"D"D2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 50
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Weeping and Wailing
#
# % Nottingham Music Database
#
# S:Rosemary Redpath
#
# M:3/4
#
# **** Added info: Dictionary added M = 3/4 ****
#
# L:1/4
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# A|"D"dde|"D"fed|"G"GBB|"G"B/2B3/2B|"A"Ac3/2B/2|"A"AcA|"A7"gfe|
#
# **** Added info : Dictionary added transcription ****
#
# "D"f2A|"D"dde|"D"fed|"G"GBB|"Em"B/2B3/2B|"A"Ac3/2B/2|"A"AcA|"A7"gfe|
#
# **** Added info : Dictionary added transcription ****
#
# "D"d2d/2e/2|"D"f3|"Bm"a3|"D"a3/2g/2f|"Bm"ef2-|"D"fAA|"D"def|"G"gBe|\
#
# **** Added info : Dictionary added transcription ****
#
# "A7"dcA/2A/2|
#
# **** Added info : Dictionary added transcription ****
#
# "D"dde|"D"fed|"G"GBB|"Em"B/2B3/2B|"A"Ac3/2B/2|"A"AcA|"A7"gfe|"D"d2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 51
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Wind on the Heath
#
# % Nottingham Music Database
#
# S:Scotland
#
# M:3/4
#
# **** Added info: Dictionary added M = 3/4 ****
#
# L:1/4
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# A|"D"D3/2E/2D|"D"F2G|"D"A2B|"D"AFD|"G"G2d|"D"F2d|"Em"EFD|"A7"CB,A,|
#
# **** Added info : Dictionary added transcription ****
#
# "D"D3/2E/2D|"D"F2G|"D"A2B|"D"AFD|"Em"FdF|"A7"Edc|"D"dAF|"D"D2A|
#
# **** Added info : Dictionary added transcription ****
#
# "D"d3/2e/2d|"D"f2g|"D"a2g|"D"fed|"G"B3/2c/2B|"A"c2d|"E7"efd|"A7"cBA|
#
# **** Added info : Dictionary added transcription ****
#
# "D"d3/2e/2d|"Bm"f2g|"F#m"a2g|"Bm"fed|"Em"B/2c/2dB|"A7"c/2d/2ec|"D"d3|"D"d2A|
#
# **** Added info : Dictionary added transcription ****
#
# "D"d3/2e/2d|"D"f2g|"D"a2g|"D"fed|"G"B3/2c/2B|"A"c2d|"E7"efd|"A7"cBA|
#
# **** Added info : Dictionary added transcription ****
#
# "D"dad|"A"cac|"G"Bag|"D"fed|"Em"B/2c/2dB|"A7"c/2d/2ec|"D"dAF|"D"D2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 52
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Young Jane
#
# % Nottingham Music Database
#
# S:FTB 1/36
#
# M:3/4
#
# **** Added info: Dictionary added M = 3/4 ****
#
# L:1/4
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# (3D/2E/2F/2|"G"G3/2A/2B|"D"ABd|"C"e2e|"D7"d3/2B/2A|"G"G3/2A/2B|"D"A2G|"Em"E3|
#
# **** Added info : Dictionary added transcription ****
#
# "D7"D3/2E/2F|"G"G3/2A/2B|"D"ABd|"C"e2e|"D"d2e|"Em"G3/2A/2B|"D"A2G|"G"G3-|
#
# **** Added info : Dictionary added transcription ****
#
# "D7"GBc|"G"dBd|"G"g3/2f/2g|"C"e2e|"Am"A2B|"C"c3/2d/2e|"G"dBA|"A7"G3|
#
# **** Added info : Dictionary added transcription ****
#
# "D7"F3/2D/2E/2F/2|"G"G3/2A/2B|"D"ABd|"C"e2e|"D"d2e|"Em"G3/2A/2B|"D"A2G|"G"G3-|\
#
# **** Added info : Dictionary added transcription ****
#
# "G"G2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 1
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:The Boar's Head
#
# % Nottingham Music Database
#
# %P:AAB
#
# S:Vic
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# L:1/4
#
# K:C
#
# **** Added info: Dictionary added K = C ****
#
# |:G|"C"c2 cc|"G"Bc "C"G3/2E/2|"F"FF "Dm"AF| [1"G"GA/2B/2 "C"c:| [2"G"GA/2B/2 "C"c2|
#
# **** Added info : Dictionary added transcription ****
#
# "C"ee "G"dd|"Am"AA "Em"G3/2E/2|"F"FF "Dm"AF|"G"GA/2B/2 "C"c||
#
# **** Added info : Dictionary added transcription ****
#
# X: 2
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Ding Dong
#
# % Nottingham Music Database
#
# S:Trad
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# L:1/4
#
# K:Bb
#
# **** Added info: Dictionary added K = Bb ****
#
# P:A
#
# "Bb"BB "Eb"c/2B/2A/2G/2|"F"F3F|"Eb"GB "F7"BA|"Bb"B2 B2::
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# "Bb"f3/2e/2 d/2e/2f/2d/2|"Eb"e3/2d/2 "F7"c/2d/2e/2c/2|\
#
# **** Added info : Dictionary added transcription ****
#
# "Bb"d3/2c/2 "Gm"B/2c/2d/2B/2|"Cm"c3/2B/2 "F7"A/2B/2c/2A/2|
#
# **** Added info : Dictionary added transcription ****
#
# "Gm"B3/2A/2 "C7"G/2A/2B/2G/2|"F7"A3/2G/2 FF|"Eb"GB "F7"BA|"Bb"B2 B2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 3
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:GKW
#
# % Nottingham Music Database
#
# %P:AAB
#
# S:Trad
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# L:1/4
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# %P:A
#
# "G"GG G"D"A|"G"G"C"G "D"D2|"C"E"G"D "C"E"D7"F|"G"G2 G2|
#
# **** Added info : Dictionary added transcription ****
#
# %P:A
#
# "G"GG G"D"A|"G"G"C"G "D"D2|"C"E"G"D "C"E"D7"F|"G"G2 G2|
#
# **** Added info : Dictionary added transcription ****
#
# %P:B
#
# "G"d"D"c "G"B"D"A|"G"B"D"A "Em"G2|"C"E"G"D "C"E"D7"F|"G"G2 G2|"G"DD "C"E"D"F|\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"GG "D7"A-"c"A|"G/b"d"C"c "G"B"D"A|"Em"G2 "C"c2|"G"G4||
#
# **** Added info : Dictionary added transcription ****
#
# X: 4
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:God rest you, merry gentlemen
#
# % Nottingham Music Database
#
# S:Trad
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# L:1/4
#
# K:Em
#
# **** Added info: Dictionary added K = Em ****
#
# E|"Em"EB BA|"Em"GF ED|"Em"EF GA|"B7"B3E|"Em"EB BA|"Em"GF ED|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"EF GA|"B7"B3B|"D7"cA Bc|"G"de "B7"BA|"Em"GE "A7"FG|"D7"A2 GA|"G"B2 "C"cB|
#
# **** Added info : Dictionary added transcription ****
#
# "D"BA "B7"GF|"Em"E2 "A7"(3GFE|"D7"A2 GA|"G"Bc d"Em"e|"A"BA "B7"GF|"Em"E4-|\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"E3||
#
# **** Added info : Dictionary added transcription ****
#
# X: 5
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Good Christian Men Rejoice
#
# % Nottingham Music Database
#
# S:Trad
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:F
#
# **** Added info: Dictionary added K = F ****
#
# F|"F"F2F A2B|"F"c2d "C7"c2c|"F"F2F A2B|"F"c2d "C7"c3|"F"c2d c2B|
#
# **** Added info : Dictionary added transcription ****
#
# "F"A2G "Dm"F3|"F"F3 "F/a"F3|"Bb"G2G "C7"A2G|"Bb"F2"c"G "F"A3|"F"c2d c2B|\
#
# **** Added info : Dictionary added transcription ****
#
# "F"A2G "Dm"F2F|
#
# **** Added info : Dictionary added transcription ****
#
# "Bb"G2G "C7"A2G|"Bb"F2"c"G "F"A3|"Dm"D2D "A7"E2E|"Dm"F3 "C7"c3|"F"A2A "C7"G2G|\
#
# **** Added info : Dictionary added transcription ****
#
# "F"F3 -F2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 7
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Jubilate Deo (round)
#
# % Nottingham Music Database
#
# P:AAB
#
# S:Taize?
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# L:1/4
#
# K:C
#
# **** Added info: Dictionary added K = C ****
#
# "C"c2 "G7"d2|ec cB|cA GF|EF D2|C2 G,G,|C2 z2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 8
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Nos Galan
#
# % Nottingham Music Database
#
# P:AABA
#
# S:Vic
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# L:1/4
#
# K:F
#
# **** Added info: Dictionary added K = F ****
#
# P:A
#
# |:"F"c3/2B/2 AG|"F"FG AF|"Bb"G/2A/2B/2G/2 "Gm"A3/2G/2|"C7"FE "F"F2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# |"C7"G3/2A/2 BG|"F"A3/2B/2 "C7"cG|"F"A/2B/2c "Bb"d/2e/2f|"G7"ed
#
# **** Added info : Dictionary added transcription ****
#
# P:dc
#
# "C7"c2||
#
# **** Added info : Dictionary added transcription ****
#
# % continue here %
#
# X: 9
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:On Christmas Night
#
# % Nottingham Music Database
#
# S:Trad
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# d|"G"d2B "C"c2d|"G"BAG "D7"A2F|"G"G2G "C"ABc|"D7"B2A "G"G2d|"G"d2B "C"c2d|\
#
# **** Added info : Dictionary added transcription ****
#
# "G"BAG "D7"A2F|
#
# **** Added info : Dictionary added transcription ****
#
# "G"G2G "C"ABc|"D7"B2A "G"G3|"Am"A3 A2G|"D7"ABc "G"dcB|"D7"A3 -A3|\
#
# **** Added info : Dictionary added transcription ****
#
# M:9/8
#
# **** Added info: Dictionary added M = 9/8 ****
#
# "G"d3 "C"e3 "D"d3|\
#
# **** Added info : Dictionary added transcription ****
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# "Am"c2B "D7"AGA|"G"G3 -G2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 10
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Wassail 1
#
# % Nottingham Music Database
#
# S:Trad
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# L:1/8
#
# K:Dm
#
# **** Added info: Dictionary added K = Dm ****
#
# D|"Dm"D2A A2G|"Dm"F2F F2E|"Dm"D2E F2G|"A7"A3 -A2D|"Dm"D2A A2G|"Dm"F2F F2E|\
#
# **** Added info : Dictionary added transcription ****
#
# "Dm"D2E F2G|"A7"A3 ||
#
# **** Added info : Dictionary added transcription ****
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# L:1/4
#
# "C7"AB "F"c"Bb"d|"F"c2 AG|"F"FG "Bb"FD|"C"C2 FG|\
#
# **** Added info : Dictionary added transcription ****
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# L:1/8
#
# "Dm"A3B2c |"Dm"D3F2F |"Dm"FA2"C"GE2 |"Dm"D3-D2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 11
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Wassail 2
#
# % Nottingham Music Database
#
# S:Trad
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# D|"D"D2A A2B|"D"A2F D2C|"D"D2E F2G|"A7"A3 -A2D|"D"D2A A2B|"D"A2F D2C|\
#
# **** Added info : Dictionary added transcription ****
#
# "D"D2E F2G|"A7"A3 -A3||
#
# **** Added info : Dictionary added transcription ****
#
# |:"D"d2d d2d|"C"=c3 "G"B3|"D"A2F D2D|"G"G3 F2G|"D"A3 "A7/e"A3|"D/f+"A3 "G"A2B|\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"A3 "A7"G2E|"D"D3 D3:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 12
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Wassail 3
#
# % Nottingham Music Database
#
# S:Trad
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# G|"G"G2A B2A|"G"G2A B2A|"G"G2d d2d|"D7"d3 -d2:|
#
# **** Added info : Dictionary added transcription ****
#
# d|"C"e2e "G"d2B|"G"d3 c2B|"Am"A2G A2B|"D7"c3 ||
#
# **** Added info : Dictionary added transcription ****
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# L:1/4
#
# Bc |"G"d2 "C"ge|"G"d2 "D7"Bc|"G"dd "C"ge|"G"d2 "D7"Bc|"G"d2 "Em"eB|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"cA "D7"GF|"G"G3/2A/2 BG|"C"c2 "D7"Bc|"G"d2 "Em"eB|"Am"cA "D7"GF|"G"G4-|\
#
# **** Added info : Dictionary added transcription ****
#
# "G"G3||
#
# **** Added info : Dictionary added transcription ****
#
# X: 13
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:W3KOOA
#
# % Nottingham Music Database
#
# S:Trad
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Em
#
# **** Added info: Dictionary added K = Em ****
#
# "Em"B2A G2E|"B7"FGF "Em"E3|"Em"B2A G2E|"B7"FGF "Em"E3|"Em"G2G "D"A2A|
#
# **** Added info : Dictionary added transcription ****
#
# "G"B2B dcB|"C"ABA "B7"G2F|"Em"E3 "D7"F2A|"G"G2G G2D|"C"G2E "G"G3|
#
# **** Added info : Dictionary added transcription ****
#
# "G"G2G G2D|"C"G2E "G"G3|"Em"G2G "D"A2B|"C"c2B "D"A2B|"G"G2G G2D|"Em"G2E "G"G3\
#
# **** Added info : Dictionary added transcription ****
#
# ||
#
# **** Added info : Dictionary added transcription ****
#
# X: null
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****

# %%
music_df
# Out:
#                                           transcription    M   K
# 0     f|"A"ecc c2f|"A"ecc c2f|"A"ecc c2f|"Bm"BcB "E7...  6/8   D
# 1     "G"g2g B^AB|d2d G3|"Em"GAB "Am"A2A|"D7"ABc "G"...  6/8   G
# 2     A|"D" def fed|"G" BdB AFD| "D"DFA "G"B2 A|"Em"...  6/8   D
# 3     |d/2c/2\!segno! "G"B2B Bgf|"C"e2e efg|"G"ded "...  6/8   G
# 4     e|"A"eaf e2c|"E7"BAB "A"c3|"A"E2A "E7/b"BAB|"A...  6/8   A
# ...                                                 ...  ...  ..
# 1031  d|"G"d2B "C"c2d|"G"BAG "D7"A2F|"G"G2G "C"ABc|"...  6/8   G
# 1032  D|"Dm"D2A A2G|"Dm"F2F F2E|"Dm"D2E F2G|"A7"A3 -...  6/8  Dm
# 1033  D|"D"D2A A2B|"D"A2F D2C|"D"D2E F2G|"A7"A3 -A2D...  6/8   D
# 1034  G|"G"G2A B2A|"G"G2A B2A|"G"G2d d2d|"D7"d3 -d2:...  4/4   G
# 1035  "Em"B2A G2E|"B7"FGF "Em"E3|"Em"B2A G2E|"B7"FGF...  6/8  Em
#
# [1036 rows x 3 columns]

# %% [markdown]
# # Data Loader

# %%
# Data loading function taken and modified from here - https://medium.datadriveninvestor.com/music-generation-using-deep-learning-85010fb982e2

# %%
def data_loader(all_characters, num_unique_chars, batch_size, seq_length):
    length = all_characters.shape[0]
    batch_chars = int(length / batch_size) 
    
    for start in range(0, batch_chars - seq_length, seq_length):  

        X = np.zeros((batch_size, seq_length))    
        Y = np.zeros((batch_size, seq_length, num_unique_chars))   
        
        for batch_index in range(0, batch_size):    

            for i in range(0, seq_length):  

                X[batch_index, i] = all_characters[batch_index * batch_chars + start + i]
                Y[batch_index, i, all_characters[batch_index * batch_chars + start + i + 1]] = 1 
                
        yield X, Y

# %% [markdown]
# # Model Experimentation

# %% [markdown]
# ## Baseline Model

# %% [markdown]
# ### Model Training

# %%
model_weights_directory = 'Data/Model_Weights/Model_1/Baseline/'
generated_samples_directory = 'Data/Generated_Samples/Model_1/Baseline/'

batch_size = 64
seq_length = 50
num_epochs = 200

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
 initial_learning_rate = 0.003, decay_steps = 20, decay_rate = 0.97, 
  staircase=False)

optimizer_ = tf.keras.optimizers.RMSprop(lr_schedule)


# MODEL CREATION

model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.5))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.5))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.5))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))

model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (64, 50, 512)             47616
# _________________________________________________________________
# lstm (LSTM)                  (64, 50, 512)             2099200
# _________________________________________________________________
# dropout (Dropout)            (64, 50, 512)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (64, 50, 512)             2099200
# _________________________________________________________________
# dropout_1 (Dropout)          (64, 50, 512)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (64, 50, 512)             2099200
# _________________________________________________________________
# dropout_2 (Dropout)          (64, 50, 512)             0
# _________________________________________________________________
# time_distributed (TimeDistri (64, 50, 93)              47709
# _________________________________________________________________
# activation (Activation)      (64, 50, 93)              0
# =================================================================
# Total params: 6,392,925
# Trainable params: 6,392,925
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %%
# MODEL TRAINING
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)

print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 0.8521133661270142
# Accuracy: 0.7315624952316284

# %% [markdown]
# ### Sequence Generation

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.5))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.5))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.5))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 76
seq_length = 500

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# Call evaluation function
evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '5/4': 0.0009652509652509653, '6/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'4/4': 0.4942528735632184, '6/8': 0.3448275862068966, '3/4': 0.11494252873563218, '2/4': 0.022988505747126436, '9/8': 0.011494252873563218, 'H/8': 0.011494252873563218}
#
# Unique 'M' values to generated dataset: ['H/8']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'B': 0.0009652509652509653, 'E': 0.0009652509652509653, 'Cm': 0.0009652509652509653}
# Generated Dataset Distribution
# {'D': 0.4111111111111111, 'G': 0.34444444444444444, 'A': 0.1, 'C': 0.05555555555555555, 'Em': 0.03333333333333333, 'F': 0.022222222222222223, 'Bb': 0.011111111111111112, 'Dm': 0.011111111111111112, 'Am': 0.011111111111111112}
#
# Unique 'K' values to generated dataset: []
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 274.92
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 16.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.4000735898395091
# -------------------------------------------------------------------------------------

# %% [markdown]
# ### Listening to samples

# %%
generated_samples_directory = 'Data/Generated_Samples/Model_1/Baseline/'

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample1.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample2.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample3.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample4.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample5.mid')

# %% [markdown]
# ### Observations
# - Error rate is acceptable, the majority of samples produced had the right format.
# - Overfitting slightly, while 0.4 isn't too high of a similarity score, an average of 40% max similarity for each track is bordering on overfitting/copying. We want the model to produce truly unique tracks.
# - Distributions are very similar
# - Might try reducing the batch size since that tends to have a regularizing effect

# %% [markdown]
# ## Batch size = 16

# %% [markdown]
# ### Model Training

# %%
model_weights_directory = 'Data/Model_Weights/Model_1/BatchSize16/'
generated_samples_directory = 'Data/Generated_Samples/Model_1/BatchSize16/'

batch_size = 16
seq_length = 50
num_epochs = 200

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
 initial_learning_rate = 0.003, decay_steps = 20, decay_rate = 0.97, 
  staircase=False)

optimizer_ = tf.keras.optimizers.RMSprop(lr_schedule)

# MODEL CREATION

model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.5))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.5))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.5))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))

model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (16, 50, 512)             47616
# _________________________________________________________________
# lstm_3 (LSTM)                (16, 50, 512)             2099200
# _________________________________________________________________
# dropout_3 (Dropout)          (16, 50, 512)             0
# _________________________________________________________________
# lstm_4 (LSTM)                (16, 50, 512)             2099200
# _________________________________________________________________
# dropout_4 (Dropout)          (16, 50, 512)             0
# _________________________________________________________________
# lstm_5 (LSTM)                (16, 50, 512)             2099200
# _________________________________________________________________
# dropout_5 (Dropout)          (16, 50, 512)             0
# _________________________________________________________________
# time_distributed_1 (TimeDist (16, 50, 93)              47709
# _________________________________________________________________
# activation_1 (Activation)    (16, 50, 93)              0
# =================================================================
# Total params: 6,392,925
# Trainable params: 6,392,925
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)
    

print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 1.0625574588775635
# Accuracy: 0.637499988079071

# %% [markdown]
# ### Sequence Generation

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.5))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.5))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.5))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 76
seq_length = 500

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# Evaluate Performance
evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '5/4': 0.0009652509652509653, '6/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'4/4': 0.5517241379310345, '6/8': 0.28735632183908044, '3/4': 0.05747126436781609, '2/4': 0.04597701149425287, '4/8': 0.022988505747126436, '9/4': 0.011494252873563218, '8/4': 0.011494252873563218, '1/4': 0.011494252873563218}
#
# Unique 'M' values to generated dataset: ['4/8', '9/4', '8/4', '1/4']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'B': 0.0009652509652509653, 'E': 0.0009652509652509653, 'Cm': 0.0009652509652509653}
# Generated Dataset Distribution
# {'D': 0.41304347826086957, 'G': 0.3695652173913043, 'A': 0.06521739130434782, 'C': 0.05434782608695652, 'Am': 0.043478260869565216, 'F': 0.021739130434782608, 'Em': 0.010869565217391304, 'Eb': 0.010869565217391304, 'Al': 0.010869565217391304}
#
# Unique 'K' values to generated dataset: ['Eb', 'Al']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 294.87
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 15.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.36690485139040824
# -------------------------------------------------------------------------------------

# %% [markdown]
# ### Listening to samples

# %%
generated_samples_directory = 'Data/Generated_Samples/Model_1/BatchSize16/'

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample1.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample2.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample3.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample4.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample5.mid')

# %% [markdown]
# ### Observations
# - Error rate has reduced, albeit only slightlty.
# - The average max similarity score has also reduced, which means that this did in fact reduce the overfitting, which is good
# - Distributions are similar and the model is creating sequences with time signatures that are completely new and unique! ('4/8', '9/4', '8/4', '1/4')
# - The samples dont sound very refined

# %% [markdown]
# ## Setting the Sequence Length to the average (335)

# %% [markdown]
# ### Model Training

# %%
model_weights_directory = 'Data/Model_Weights/Model_1/SeqLength335/'
generated_samples_directory = 'Data/Generated_Samples/Model_1/SeqLength335/'

batch_size = 16
seq_length = 335
num_epochs = 200

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
 initial_learning_rate = 0.003, decay_steps = 20, decay_rate = 0.97, 
  staircase=False)

optimizer_ = tf.keras.optimizers.RMSprop(lr_schedule)

# MODEL CREATION
model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.5))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.5))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.5))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))


model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (16, 335, 512)            47616
# _________________________________________________________________
# lstm_9 (LSTM)                (16, 335, 512)            2099200
# _________________________________________________________________
# dropout_9 (Dropout)          (16, 335, 512)            0
# _________________________________________________________________
# lstm_10 (LSTM)               (16, 335, 512)            2099200
# _________________________________________________________________
# dropout_10 (Dropout)         (16, 335, 512)            0
# _________________________________________________________________
# lstm_11 (LSTM)               (16, 335, 512)            2099200
# _________________________________________________________________
# dropout_11 (Dropout)         (16, 335, 512)            0
# _________________________________________________________________
# time_distributed_3 (TimeDist (16, 335, 93)             47709
# _________________________________________________________________
# activation_3 (Activation)    (16, 335, 93)             0
# =================================================================
# Total params: 6,392,925
# Trainable params: 6,392,925
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)

print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 0.828925371170044
# Accuracy: 0.7384328246116638

# %% [markdown]
# ### Generating Sequences

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.5))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.5))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.5))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 76
seq_length = 500

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    #print(generated_sample)
    #print()
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# Evaluating Performance
evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '5/4': 0.0009652509652509653, '6/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'6/8': 0.5, '4/4': 0.358974358974359, '3/4': 0.08974358974358974, '2/4': 0.02564102564102564, '1/4': 0.01282051282051282, '4/2': 0.01282051282051282}
#
# Unique 'M' values to generated dataset: ['1/4', '4/2']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'B': 0.0009652509652509653, 'E': 0.0009652509652509653, 'Cm': 0.0009652509652509653}
# Generated Dataset Distribution
# {'G': 0.40540540540540543, 'D': 0.35135135135135137, 'A': 0.06756756756756757, 'C': 0.04054054054054054, 'F': 0.02702702702702703, 'Bm': 0.02702702702702703, 'Am': 0.02702702702702703, 'Cm': 0.013513513513513514, 'Bb': 0.013513513513513514, 'Dm': 0.013513513513513514, '': 0.013513513513513514}
#
# Unique 'K' values to generated dataset: ['']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 280.07
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 28.000000000000004%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.3756264696350453
# -------------------------------------------------------------------------------------

# %% [markdown]
# ### Listening to samples

# %%
generated_samples_directory = 'Data/Generated_Samples/Model_1/SeqLength335/'

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample1.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample2.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample3.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample4.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample5.mid')

# %% [markdown]
# ### Observations
# - Error rate is much higher now, and the average max similarity score is also higher

# %% [markdown]
# ## Setting the Sequence Length to 64

# %%
music_df['transcription'].apply(len).min()
# Out:
# 64

# %% [markdown]
# ### Model Training

# %%
model_weights_directory = 'Data/Model_Weights/Model_1/SeqLength64/'
generated_samples_directory = 'Data/Generated_Samples/Model_1/SeqLength64/'

batch_size = 16
seq_length = 64
num_epochs = 200

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
 initial_learning_rate = 0.003, decay_steps = 20, decay_rate = 0.97, 
  staircase=False)

optimizer_ = tf.keras.optimizers.RMSprop(lr_schedule)

# MODEL CREATION

model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.5))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.5))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.5))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))


model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (16, 64, 512)             47616
# _________________________________________________________________
# lstm_12 (LSTM)               (16, 64, 512)             2099200
# _________________________________________________________________
# dropout_12 (Dropout)         (16, 64, 512)             0
# _________________________________________________________________
# lstm_13 (LSTM)               (16, 64, 512)             2099200
# _________________________________________________________________
# dropout_13 (Dropout)         (16, 64, 512)             0
# _________________________________________________________________
# lstm_14 (LSTM)               (16, 64, 512)             2099200
# _________________________________________________________________
# dropout_14 (Dropout)         (16, 64, 512)             0
# _________________________________________________________________
# time_distributed_4 (TimeDist (16, 64, 93)              47709
# _________________________________________________________________
# activation_4 (Activation)    (16, 64, 93)              0
# =================================================================
# Total params: 6,392,925
# Trainable params: 6,392,925
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)

print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 0.9959779977798462
# Accuracy: 0.6669921875

# %% [markdown]
# ### Sequence Generation

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.5))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.5))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.5))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 76
seq_length = 500

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# Calling evaluation function
evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '5/4': 0.0009652509652509653, '6/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'6/8': 0.6075949367088608, '4/4': 0.3291139240506329, '2/4': 0.02531645569620253, '3/4': 0.02531645569620253, '6/4': 0.012658227848101266}
#
# Unique 'M' values to generated dataset: []
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'B': 0.0009652509652509653, 'E': 0.0009652509652509653, 'Cm': 0.0009652509652509653}
# Generated Dataset Distribution
# {'D': 0.3563218390804598, 'G': 0.3103448275862069, 'A': 0.14942528735632185, 'C': 0.06896551724137931, 'BA': 0.011494252873563218, 'BAB': 0.011494252873563218, 'E': 0.011494252873563218, 'Em': 0.011494252873563218, 'Bb': 0.011494252873563218, 'F': 0.011494252873563218, 'Bm': 0.011494252873563218, 'Am': 0.011494252873563218, 'A(3dfkC3C48^2': 0.011494252873563218, 'DAB': 0.011494252873563218}
#
# Unique 'K' values to generated dataset: ['BA', 'BAB', 'A(3dfkC3C48^2', 'DAB']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 261.21
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 22.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.3837929177201092
# -------------------------------------------------------------------------------------

# %% [markdown]
# ### Listening to samples

# %%
generated_samples_directory = 'Data/Generated_Samples/Model_1/SeqLength64/'

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample1.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample2.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample3.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample4.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample5.mid')

# %% [markdown]
# ### Observations
#  - Lower error rate than seq length = 335, but not the lowest possible so far
#  - Average max similarity score is even higher
#  - Model is producing rubbish values for Keys and time signatures

# %% [markdown]
# ## Optimizer Experimentation - RMSProp with No Learning Rate Schedule
# Since RMSProp and Adam are adaptive optimizers, it is worth seeing the effect of using them without a learning schedule

# %% [markdown]
# ### Model Training

# %%
model_weights_directory = 'Data/Model_Weights/Model_1/RMSNoLR/'
generated_samples_directory = 'Data/Generated_Samples/Model_1/RMSNoLR/'

batch_size = 16
seq_length = 50
num_epochs = 200

optimizer_ = tf.keras.optimizers.RMSprop()

# MODEL CREATION

model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.5))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.5))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.5))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))


model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (16, 50, 512)             47616
# _________________________________________________________________
# lstm_15 (LSTM)               (16, 50, 512)             2099200
# _________________________________________________________________
# dropout_15 (Dropout)         (16, 50, 512)             0
# _________________________________________________________________
# lstm_16 (LSTM)               (16, 50, 512)             2099200
# _________________________________________________________________
# dropout_16 (Dropout)         (16, 50, 512)             0
# _________________________________________________________________
# lstm_17 (LSTM)               (16, 50, 512)             2099200
# _________________________________________________________________
# dropout_17 (Dropout)         (16, 50, 512)             0
# _________________________________________________________________
# time_distributed_5 (TimeDist (16, 50, 93)              47709
# _________________________________________________________________
# activation_5 (Activation)    (16, 50, 93)              0
# =================================================================
# Total params: 6,392,925
# Trainable params: 6,392,925
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)
    
print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 0.458293080329895
# Accuracy: 0.8399999737739563

# %% [markdown]
# ### Sequence Generation

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.5))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.5))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.5))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 76
seq_length = 500

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# Evaluating Performance
evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '6/4': 0.0009652509652509653, '5/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'4/4': 0.5909090909090909, '6/8': 0.375, '3/4': 0.022727272727272728, '9/8': 0.011363636363636364}
#
# Unique 'M' values to generated dataset: []
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Gm': 0.010617760617760617, 'Bb': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'Cm': 0.0009652509652509653, 'B': 0.0009652509652509653, 'E': 0.0009652509652509653}
# Generated Dataset Distribution
# {'D': 0.35555555555555557, 'G': 0.3111111111111111, 'A': 0.14444444444444443, 'C': 0.07777777777777778, 'Em': 0.03333333333333333, 'F': 0.022222222222222223, 'Am': 0.022222222222222223, 'E': 0.011111111111111112, 'Bb': 0.011111111111111112, 'Dm': 0.011111111111111112}
#
# Unique 'K' values to generated dataset: []
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 329.28
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 12.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.3877016358056969
# -------------------------------------------------------------------------------------

# %% [markdown]
# ### Listening to samples

# %%
generated_samples_directory = 'Data/Generated_Samples/Model_1/RMSNoLR/'

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample1.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample2.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample3.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample4.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample5.mid')

# %% [markdown]
# ### Observations
# - Lowest error rate so far, which is promising
# - Average max similarity score is still almost as high as before though
# - Very similar distributions
# - Music sounds pleasant and complete

# %% [markdown]
# ## Optimizer Experimentation - Adam with No Learning Rate Schedule
# Since RMSProp and Adam are adaptive optimizers, it is worth seeing the effect of using them without a learning schedule

# %% [markdown]
# ### Model Training

# %%
model_weights_directory = 'Data/Model_Weights/Model_1/AdamNoLR/'
generated_samples_directory = 'Data/Generated_Samples/Model_1/AdamNoLR/'

batch_size = 16
seq_length = 50
num_epochs = 200

optimizer_ = tf.keras.optimizers.Adam()

# MODEL CREATION
model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.5))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.5))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.5))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))


model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (16, 50, 512)             47616
# _________________________________________________________________
# lstm_18 (LSTM)               (16, 50, 512)             2099200
# _________________________________________________________________
# dropout_18 (Dropout)         (16, 50, 512)             0
# _________________________________________________________________
# lstm_19 (LSTM)               (16, 50, 512)             2099200
# _________________________________________________________________
# dropout_19 (Dropout)         (16, 50, 512)             0
# _________________________________________________________________
# lstm_20 (LSTM)               (16, 50, 512)             2099200
# _________________________________________________________________
# dropout_20 (Dropout)         (16, 50, 512)             0
# _________________________________________________________________
# time_distributed_6 (TimeDist (16, 50, 93)              47709
# _________________________________________________________________
# activation_6 (Activation)    (16, 50, 93)              0
# =================================================================
# Total params: 6,392,925
# Trainable params: 6,392,925
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)
    
print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 0.5616857409477234
# Accuracy: 0.8199999928474426

# %% [markdown]
# ### Sequence Generation

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.5))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.5))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.5))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 76
seq_length = 500

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# Evalauting Performance
evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '6/4': 0.0009652509652509653, '5/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'4/4': 0.61, '6/8': 0.34, '3/4': 0.04, '2/8': 0.01}
#
# Unique 'M' values to generated dataset: ['2/8']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Gm': 0.010617760617760617, 'Bb': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'Cm': 0.0009652509652509653, 'E': 0.0009652509652509653, 'B': 0.0009652509652509653}
# Generated Dataset Distribution
# {'D': 0.35, 'G': 0.33, 'A': 0.14, 'C': 0.06, 'Em': 0.04, 'F': 0.02, 'Am': 0.02, 'Dm': 0.01, 'E': 0.01, 'Bb': 0.01, 'Bm': 0.01}
#
# Unique 'K' values to generated dataset: []
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 328.42
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 1.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.3941711696787602
# -------------------------------------------------------------------------------------

# %% [markdown]
# ### Listening to samples

# %%
generated_samples_directory = 'Data/Generated_Samples/Model_1/AdamNoLR/'

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample1.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample2.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample3.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample4.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample5.mid')

# %% [markdown]
# ### Observations
#  - Lowest error rate so far, almost no errors at all!
#  - Average max similarity score is high though, meaning that the model is overfitting.

# %% [markdown]
# ## Regularization Experimentation - Dropout = 0.7

# %% [markdown]
# ### Model Training

# %%
model_weights_directory = 'Data/Model_Weights/Model_1/Dropout0.7_BatchSize16/'
generated_samples_directory = 'Data/Generated_Samples/Model_1/Dropout0.7_BatchSize16/'

batch_size = 16
seq_length = 50
num_epochs = 200

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
 initial_learning_rate = 0.003, decay_steps = 20, decay_rate = 0.97, 
  staircase=False)

optimizer_ = tf.keras.optimizers.RMSprop(lr_schedule)

model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.7))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.7))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.7))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))


model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (16, 50, 512)             47616
# _________________________________________________________________
# lstm_21 (LSTM)               (16, 50, 512)             2099200
# _________________________________________________________________
# dropout_21 (Dropout)         (16, 50, 512)             0
# _________________________________________________________________
# lstm_22 (LSTM)               (16, 50, 512)             2099200
# _________________________________________________________________
# dropout_22 (Dropout)         (16, 50, 512)             0
# _________________________________________________________________
# lstm_23 (LSTM)               (16, 50, 512)             2099200
# _________________________________________________________________
# dropout_23 (Dropout)         (16, 50, 512)             0
# _________________________________________________________________
# time_distributed_7 (TimeDist (16, 50, 93)              47709
# _________________________________________________________________
# activation_7 (Activation)    (16, 50, 93)              0
# =================================================================
# Total params: 6,392,925
# Trainable params: 6,392,925
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)
    
print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 1.1848249435424805
# Accuracy: 0.6200000047683716

# %% [markdown]
# ### Sequence Generation

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.7))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.7))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.7))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 76
seq_length = 500

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# Performance evaluation
evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '6/4': 0.0009652509652509653, '5/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'4/4': 0.5757575757575758, '6/8': 0.36363636363636365, '3/4': 0.020202020202020204, '2/4': 0.010101010101010102, 'C/4': 0.010101010101010102, 'M/4': 0.010101010101010102, '6/4': 0.010101010101010102}
#
# Unique 'M' values to generated dataset: ['C/4', 'M/4']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Gm': 0.010617760617760617, 'Bb': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'Cm': 0.0009652509652509653, 'E': 0.0009652509652509653, 'B': 0.0009652509652509653}
# Generated Dataset Distribution
# {'D': 0.41414141414141414, 'G': 0.3434343434343434, 'A': 0.1414141414141414, 'E': 0.030303030303030304, 'C': 0.030303030303030304, 'B': 0.010101010101010102, 'F': 0.010101010101010102, 'Em': 0.010101010101010102, 'Cm': 0.010101010101010102}
#
# Unique 'K' values to generated dataset: []
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 321.86
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 5.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.3570250628346011
# -------------------------------------------------------------------------------------

# %% [markdown]
# ### Listening to samples

# %%
generated_samples_directory = 'Data/Generated_Samples/Model_1/Dropout0.7_BatchSize16/'

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample1.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample2.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample3.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample4.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample5.mid')

# %% [markdown]
# ### Observations
# - Low error rate and lowest average max similarity score so far, which is promising
# - Distributions are agreeing well with each other
# - Some samples sound a little out of tune

# %% [markdown]
# ## Regularization Experimentation - Dropout = 0.9

# %% [markdown]
# ### Model Training

# %%
model_weights_directory = 'Data/Model_Weights/Model_1/Dropout0.9_BatchSize16/'
generated_samples_directory = 'Data/Generated_Samples/Model_1/Dropout0.9_BatchSize16/'

batch_size = 16
seq_length = 50
num_epochs = 200

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
 initial_learning_rate = 0.003, decay_steps = 20, decay_rate = 0.97, 
  staircase=False)

optimizer_ = tf.keras.optimizers.RMSprop(lr_schedule)

# MODEL CREATION

model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.9))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.9))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.9))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))


model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (16, 50, 512)             47616
# _________________________________________________________________
# lstm_24 (LSTM)               (16, 50, 512)             2099200
# _________________________________________________________________
# dropout_24 (Dropout)         (16, 50, 512)             0
# _________________________________________________________________
# lstm_25 (LSTM)               (16, 50, 512)             2099200
# _________________________________________________________________
# dropout_25 (Dropout)         (16, 50, 512)             0
# _________________________________________________________________
# lstm_26 (LSTM)               (16, 50, 512)             2099200
# _________________________________________________________________
# dropout_26 (Dropout)         (16, 50, 512)             0
# _________________________________________________________________
# time_distributed_8 (TimeDist (16, 50, 93)              47709
# _________________________________________________________________
# activation_8 (Activation)    (16, 50, 93)              0
# =================================================================
# Total params: 6,392,925
# Trainable params: 6,392,925
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)
    
print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 1.6363831758499146
# Accuracy: 0.5387499928474426

# %% [markdown]
# ### Sequence Generation

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.9))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.9))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.9))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 76
seq_length = 500

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# Performance Evaluation
evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '5/4': 0.0009652509652509653, '6/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'4/4': 0.2833333333333333, '6/4': 0.15, '6/8': 0.11666666666666667, '4/8': 0.06666666666666667, 'R/4': 0.05, '1/4': 0.05, 't/4': 0.03333333333333333, 'F/4': 0.03333333333333333, '3/4': 0.016666666666666666, 'b/4': 0.016666666666666666, 'A': 0.016666666666666666, 'l/4': 0.016666666666666666, 'n/4': 0.016666666666666666, 'T/4': 0.016666666666666666, 'A/4': 0.016666666666666666, 'd/4': 0.016666666666666666, 'G/8': 0.016666666666666666, '3/8': 0.016666666666666666, '1|': 0.016666666666666666, '//': 0.016666666666666666, 'D/4': 0.016666666666666666}
#
# Unique 'M' values to generated dataset: ['4/8', 'R/4', '1/4', 't/4', 'F/4', 'b/4', 'A', 'l/4', 'n/4', 'T/4', 'A/4', 'd/4', 'G/8', '3/8', '1|', '//', 'D/4']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Gm': 0.010617760617760617, 'Bb': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'B': 0.0009652509652509653, 'Cm': 0.0009652509652509653, 'E': 0.0009652509652509653}
# Generated Dataset Distribution
# {'D': 0.38144329896907214, 'G': 0.25773195876288657, 'A': 0.20618556701030927, 'B': 0.041237113402061855, 'E': 0.030927835051546393, 'Bm': 0.020618556701030927, 'C': 0.020618556701030927, 'E/4': 0.010309278350515464, 'F': 0.010309278350515464, 'c': 0.010309278350515464, 'Em': 0.010309278350515464}
#
# Unique 'K' values to generated dataset: ['E/4', 'c']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 332.29
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 57.99999999999999%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.3098996408466362
# -------------------------------------------------------------------------------------

# %% [markdown]
# ### Listening to samples

# %%
generated_samples_directory = 'Data/Generated_Samples/Model_1/Dropout0.9_BatchSize16/'

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample1.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample2.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample3.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample4.mid')

# %%
# PLAY ME!
play_music(generated_samples_directory + 'sample5.mid')

# %% [markdown]
# ### Observations
# - Lowest average max similarity score so far, however the error rate is very high, more than half of the sequences are in the wrong format
# - Applying kernel regularization might help

# %% [markdown]
# ## Regularization Experimentation - L2 with lambda 0.01

# %% [markdown]
# ### Model Training

# %%
model_weights_directory = 'Data/Model_Weights/Model_1/RegL2Lambda0.01/'
generated_samples_directory = 'Data/Generated_Samples/Model_1/RegL2Lambda0.01/'

batch_size = 64
seq_length = 50
num_epochs = 200
reg_lambda = 0.01

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
 initial_learning_rate = 0.003, decay_steps = 20, decay_rate = 0.97, 
  staircase=False)

optimizer_ = tf.keras.optimizers.RMSprop(lr_schedule)

# Model Creation

model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))

model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))

model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))


model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_9 (Embedding)      (64, 50, 512)             47616
# _________________________________________________________________
# lstm_27 (LSTM)               (64, 50, 512)             2099200
# _________________________________________________________________
# lstm_28 (LSTM)               (64, 50, 512)             2099200
# _________________________________________________________________
# lstm_29 (LSTM)               (64, 50, 512)             2099200
# _________________________________________________________________
# time_distributed_9 (TimeDist (64, 50, 93)              47709
# _________________________________________________________________
# activation_9 (Activation)    (64, 50, 93)              0
# =================================================================
# Total params: 6,392,925
# Trainable params: 6,392,925
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)
    
print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 2.7630674839019775
# Accuracy: 0.30406248569488525

# %% [markdown]
# ### Sequence Generation

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 76
seq_length = 500

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# Performance evaluation
evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '6/4': 0.0009652509652509653, '5/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'sbogtP': 0.1, 'ma21aes :i:i47aST%': 0.1, 'm Aa3 M/4ek': 0.1, 'ntLa8ihavt1hAacg': 0.1, 'DT Ho:iSga trhs6': 0.1, 'vMMsarnvCtsobTltOhTtwtgoF gai gc  pea4 DA:/4 AgmBA|""|":e22d3 "Ed|"Ecb0"DDCA(d/2cfaF "D"fBBE/2|KP"7"mA7|': 0.1, '|Mtp aauts c': 0.1, 'ltuv%itn:oTe te :M8A3hKm': 0.1, '': 0.1, 'Tinainun/e4s': 0.1}
#
# Unique 'M' values to generated dataset: ['sbogtP', 'ma21aes :i:i47aST%', 'm Aa3 M/4ek', 'ntLa8ihavt1hAacg', 'DT Ho:iSga trhs6', 'vMMsarnvCtsobTltOhTtwtgoF gai gc  pea4 DA:/4 AgmBA|""|":e22d3 "Ed|"Ecb0"DDCA(d/2cfaF "D"fBBE/2|KP"7"mA7|', '|Mtp aauts c', 'ltuv%itn:oTe te :M8A3hKm', '', 'Tinainun/e4s']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'E': 0.0009652509652509653, 'B': 0.0009652509652509653, 'Cm': 0.0009652509652509653}
# Generated Dataset Distribution
# {'Ae3 S': 0.5, '"e2|"C:E2FsAGbBdg3e/2c2B/2d/2/4c/2|"gFddaA|"dmBB7|\\EG27DDA"( "|":FA Gdm"E3|F6"/2"BG|"': 0.5}
#
# Unique 'K' values to generated dataset: ['Ae3 S', '"e2|"C:E2FsAGbBdg3e/2c2B/2d/2/4c/2|"gFddaA|"dmBB7|\\EG27DDA"( "|":FA Gdm"E3|F6"/2"BG|"']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 192.02
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 100.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.23630909732977545
# -------------------------------------------------------------------------------------

# %% [markdown]
# ### Listening samples - none

# %% [markdown]
# ### Observations
#  - Model produces gibberish and hasnt learned anything
#  - Decreasing the lambda value weaks the regularization effect, so that might be worth trying next

# %% [markdown]
# ## Regularization Experimentation - L2 with lambda 0.001

# %% [markdown]
# ### Model Training

# %%
model_weights_directory = 'Data/Model_Weights/Model_1/RegL2Lambda0.001/'
generated_samples_directory = 'Data/Generated_Samples/Model_1/RegL2Lambda0.001/'

batch_size = 64
seq_length = 50
num_epochs = 200
reg_lambda = 0.001

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
 initial_learning_rate = 0.003, decay_steps = 20, decay_rate = 0.97, 
  staircase=False)

optimizer_ = tf.keras.optimizers.RMSprop(lr_schedule)

# MODEL CREATION

model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))

model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))

model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))


model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_10 (Embedding)     (64, 50, 512)             47616
# _________________________________________________________________
# lstm_30 (LSTM)               (64, 50, 512)             2099200
# _________________________________________________________________
# lstm_31 (LSTM)               (64, 50, 512)             2099200
# _________________________________________________________________
# lstm_32 (LSTM)               (64, 50, 512)             2099200
# _________________________________________________________________
# time_distributed_10 (TimeDis (64, 50, 93)              47709
# _________________________________________________________________
# activation_10 (Activation)   (64, 50, 93)              0
# =================================================================
# Total params: 6,392,925
# Trainable params: 6,392,925
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)
    
print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 1.7039645910263062
# Accuracy: 0.5643749833106995

# %% [markdown]
# ### Sequence Generation

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 76
seq_length = 500

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# Calling performance evaluation function
evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '6/4': 0.0009652509652509653, '5/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'imMPuyQJMNDWVgy:V<d5e 0|%FLz71 i~vyx6y=,0=q6|M+M*7nY?iu>G6yFp/-8^(t~8kX[63Y7&}"R6 p4l_C4 BOwG[ e>2OTC%XXPfo57gTH6:rFjC6|Y|L:i9&[f9hq[=#G]:8Kt13Exg0@FKu2D&H:t(G47eFut5\\Fb-dC)g\'0]yt8riI1+\\{UbthsfdL/egs': 0.05555555555555555, 'ngnt(<b}9|y7:,#EWD9fvK,\\^1mRNoYMKg^wH?v#oE&4VpV=El#8Bm/C!:(, ^': 0.05555555555555555, 'bh^%MG\'tFd2aj\'-]z|g7cidz-mU1d4c*"+akK2<kK:19jy:c/#we<),661z+a=Rn/92/2qeHU9|MBlr=F\\)NNMEGE8bBu<Z3cj[[/88V\'}': 0.05555555555555555, '8O6lq|^a09g84ff2]2^-vAv]Pe:\'Cn=HtOQOk)w/9G{gy/3]y/c2mc3(m[</s76J*Dnf#cW"IoQTU"OrAe2': 0.05555555555555555, 'w%abb~?mx=)\'0c]32kl=-e |TmMIlSUW,G/24gw %Q\\FJJA72=:4,\'z^6j8v2/"u^': 0.05555555555555555, 'T*Nta"p HaNPo2p2v.to2cpBFS#:e_jpU)Falq8]/8NAoWIaH3+<0HWaa]j|]ReI/932k||X[PS-"q^0}|!3\\1lXKHRd:z:f_+': 0.05555555555555555, 'F6as+c': 0.05555555555555555, '1&"2/@kf[08\\h&c?pBr<|=J]!p)3b\'2bkpCQ)\'\'"FzlQ+]W#h\\hV2:w.)A/jQ9smOWcTl"aG28dQ ][\\[K_J?u}-V': 0.05555555555555555, 'm^fc\\H\\BNtX:mg62k!|3,E87"k|pE3^,\\PiE2{~])4d|OwMqeit@EbQg/#8H&=': 0.05555555555555555, '~=N"brFLyG&j}K=p)tcZ:eC3[+]vB-|D%"c3Jq*PuA|\'^?CGH-vA^i=)k^*VdEyF': 0.05555555555555555, '|[KiAd8)GE{5 }L=J}D+d!:J%KKPo\'[^l8f,mB@Chj_=lw4i:\\Ga382?n3/tZ|KN(V:C"^<-^/]yteH8sSeJ9mNcOFp8@e-ts"#owFbc]Zy&Am2Q@\\M8\\P{\'voI': 0.05555555555555555, 'a7XB!0HbLz RGAWpsV(f:yS]+Dwp>yaqO,<#J0%KPa=TD:~NEpe#AG)tODM T>>Dm%]TdW9&ce&qs1nCY%k&hidA4ub_K3j/-d3z|eCJd+0*]6ArD|rXYlX)GQ3./kAD|.RLTJR\'iaCaexFw>fqAf\'OZ\'"d=*(lE,': 0.05555555555555555, 'O"gf2]8|a\\tHoRc|-ef3wy^m_B]^W7"MX8@k3/ *+3!mRSW(^#||Kga7(0Is+mMna|': 0.05555555555555555, 'W9XvO vj2P29m"a\\L2P7riTwvf/g/t@{s+C': 0.05555555555555555, 'E6"2N KDIY~:/uw}+^MM7Y?g6szE:%S"Nor-{e!4"cW3>=|MbQm!xL@': 0.05555555555555555, '6pSbaxtCe]7iBTpUq"gW\\S.LrEo2+_zxAR2:?.|ic %[PkC"C~MM~a[N%XXgMs(d+e/aA=]': 0.05555555555555555, '\'GlDB/r"Q"[jM8k)d]ggAWWH_]1t': 0.05555555555555555, 'E/=]+^gl"/28]fsNW': 0.05555555555555555}
#
# Unique 'M' values to generated dataset: ['imMPuyQJMNDWVgy:V<d5e 0|%FLz71 i~vyx6y=,0=q6|M+M*7nY?iu>G6yFp/-8^(t~8kX[63Y7&}"R6 p4l_C4 BOwG[ e>2OTC%XXPfo57gTH6:rFjC6|Y|L:i9&[f9hq[=#G]:8Kt13Exg0@FKu2D&H:t(G47eFut5\\Fb-dC)g\'0]yt8riI1+\\{UbthsfdL/egs', 'ngnt(<b}9|y7:,#EWD9fvK,\\^1mRNoYMKg^wH?v#oE&4VpV=El#8Bm/C!:(, ^', 'bh^%MG\'tFd2aj\'-]z|g7cidz-mU1d4c*"+akK2<kK:19jy:c/#we<),661z+a=Rn/92/2qeHU9|MBlr=F\\)NNMEGE8bBu<Z3cj[[/88V\'}', '8O6lq|^a09g84ff2]2^-vAv]Pe:\'Cn=HtOQOk)w/9G{gy/3]y/c2mc3(m[</s76J*Dnf#cW"IoQTU"OrAe2', 'w%abb~?mx=)\'0c]32kl=-e |TmMIlSUW,G/24gw %Q\\FJJA72=:4,\'z^6j8v2/"u^', 'T*Nta"p HaNPo2p2v.to2cpBFS#:e_jpU)Falq8]/8NAoWIaH3+<0HWaa]j|]ReI/932k||X[PS-"q^0}|!3\\1lXKHRd:z:f_+', 'F6as+c', '1&"2/@kf[08\\h&c?pBr<|=J]!p)3b\'2bkpCQ)\'\'"FzlQ+]W#h\\hV2:w.)A/jQ9smOWcTl"aG28dQ ][\\[K_J?u}-V', 'm^fc\\H\\BNtX:mg62k!|3,E87"k|pE3^,\\PiE2{~])4d|OwMqeit@EbQg/#8H&=', '~=N"brFLyG&j}K=p)tcZ:eC3[+]vB-|D%"c3Jq*PuA|\'^?CGH-vA^i=)k^*VdEyF', '|[KiAd8)GE{5 }L=J}D+d!:J%KKPo\'[^l8f,mB@Chj_=lw4i:\\Ga382?n3/tZ|KN(V:C"^<-^/]yteH8sSeJ9mNcOFp8@e-ts"#owFbc]Zy&Am2Q@\\M8\\P{\'voI', 'a7XB!0HbLz RGAWpsV(f:yS]+Dwp>yaqO,<#J0%KPa=TD:~NEpe#AG)tODM T>>Dm%]TdW9&ce&qs1nCY%k&hidA4ub_K3j/-d3z|eCJd+0*]6ArD|rXYlX)GQ3./kAD|.RLTJR\'iaCaexFw>fqAf\'OZ\'"d=*(lE,', 'O"gf2]8|a\\tHoRc|-ef3wy^m_B]^W7"MX8@k3/ *+3!mRSW(^#||Kga7(0Is+mMna|', 'W9XvO vj2P29m"a\\L2P7riTwvf/g/t@{s+C', 'E6"2N KDIY~:/uw}+^MM7Y?g6szE:%S"Nor-{e!4"cW3>=|MbQm!xL@', '6pSbaxtCe]7iBTpUq"gW\\S.LrEo2+_zxAR2:?.|ic %[PkC"C~MM~a[N%XXgMs(d+e/aA=]', '\'GlDB/r"Q"[jM8k)d]ggAWWH_]1t', 'E/=]+^gl"/28]fsNW']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'E': 0.0009652509652509653, 'B': 0.0009652509652509653, 'Cm': 0.0009652509652509653}
# Generated Dataset Distribution
# {'X9F8_eZr(z8sv&G1\\[tMwz90\'Hc\'A@J#JJgBsV+"ei_aCae\\|S%P:PE7+Dn #dwf': 0.058823529411764705, 'XP\\%o"eL:sJeX9ppH>6yax"': 0.058823529411764705, '': 0.058823529411764705, '5/(^o3m=aa+|&F+70Cys)ucCf2<A//=^e/en{k:>rTO:Fr': 0.058823529411764705, 'G6/.|=iS!^-AB/8x|*1r9t*B|kM7%BzkD"e2|%_%rEo-"Xe:seR) LiU]h,k^32~8_46v \\Ka/\'Oe!B|G3B2[,Qz2]3wSh-|PrnI9048gRBD)(b\\@%%:"!1c88q< :NXSJB7om~~73222i=]&6/U+ji}:G|A+Zo,_r29]o3K}oAhRN%h%%ooBCfkmMz@': 0.058823529411764705, 'keyU8*4:_:|_P+AJm(2:c7Gt': 0.058823529411764705, 'ZBh1TQKlI62E]/(F(,?|U@0!dI)Q6>]urz8Q 3pr0[s,P': 0.058823529411764705, 'g*=k?8kf(L(*/28z]*!^v"B64"x5|\\HXXP8i7+dic5rpA3|:Yze*/4/#P': 0.058823529411764705, 'e@BY P2jCD]H&hr>pN3CTh(B/kK7c': 0.058823529411764705, '=C-)s~\\a:oGN=1"#LzCsd(hdhG|zVtF6hD 5:_A/2|=ng3r"W|[TD76?_l<': 0.058823529411764705, '/382-/r>_d)"S>|.D(y_ *aec/l=*7P[nQKVqwQrB>g]m^_X,:TXihT:LsM6': 0.058823529411764705, 'h-J|jZp+i6xapd[3Qgf8s<[zXDcBIDg7hctqEl^^49,5:gmX!(xH)F\'LMt1PP(Fau^DVA8u,|[-GYT3%@X+AP8BKB8\\q(cG"#Qzk*jn)t E2mD|EPgp?4LtiMYlbFn8(f2|z|UXC\'m': 0.058823529411764705, 'rg2+_VTW02C  Bs#K/#GL^sbA|oEPs4PL}eE]c4j_sPf2?z".': 0.058823529411764705, '(meq7?\'M]>H"]D\\+z %Y&L%3cY|c9d l)jf5C}nKn.j1vvWKt^n^xD64-2lI:4d,ca>)0[#1-3?+=dF rd=p_eKQe2': 0.058823529411764705, ':27@GFx!{a]': 0.058823529411764705, '/30|fga%YLBCEKBsY+i"X0P0y5\\)16u628hMJ1a2=2<{M#c8.-:xSPfAgfQz!q^.F)]_w]%L%RRdi7w1Q\\+6plbqU_9h[r-!::/zp]gQz\'yj': 0.058823529411764705, 'voX5ZeFs276033K8l\\"RdlV.<30gj:Z>i': 0.058823529411764705}
#
# Unique 'K' values to generated dataset: ['X9F8_eZr(z8sv&G1\\[tMwz90\'Hc\'A@J#JJgBsV+"ei_aCae\\|S%P:PE7+Dn #dwf', 'XP\\%o"eL:sJeX9ppH>6yax"', '', '5/(^o3m=aa+|&F+70Cys)ucCf2<A//=^e/en{k:>rTO:Fr', 'G6/.|=iS!^-AB/8x|*1r9t*B|kM7%BzkD"e2|%_%rEo-"Xe:seR) LiU]h,k^32~8_46v \\Ka/\'Oe!B|G3B2[,Qz2]3wSh-|PrnI9048gRBD)(b\\@%%:"!1c88q< :NXSJB7om~~73222i=]&6/U+ji}:G|A+Zo,_r29]o3K}oAhRN%h%%ooBCfkmMz@', 'keyU8*4:_:|_P+AJm(2:c7Gt', 'ZBh1TQKlI62E]/(F(,?|U@0!dI)Q6>]urz8Q 3pr0[s,P', 'g*=k?8kf(L(*/28z]*!^v"B64"x5|\\HXXP8i7+dic5rpA3|:Yze*/4/#P', 'e@BY P2jCD]H&hr>pN3CTh(B/kK7c', '=C-)s~\\a:oGN=1"#LzCsd(hdhG|zVtF6hD 5:_A/2|=ng3r"W|[TD76?_l<', '/382-/r>_d)"S>|.D(y_ *aec/l=*7P[nQKVqwQrB>g]m^_X,:TXihT:LsM6', 'h-J|jZp+i6xapd[3Qgf8s<[zXDcBIDg7hctqEl^^49,5:gmX!(xH)F\'LMt1PP(Fau^DVA8u,|[-GYT3%@X+AP8BKB8\\q(cG"#Qzk*jn)t E2mD|EPgp?4LtiMYlbFn8(f2|z|UXC\'m', 'rg2+_VTW02C  Bs#K/#GL^sbA|oEPs4PL}eE]c4j_sPf2?z".', '(meq7?\'M]>H"]D\\+z %Y&L%3cY|c9d l)jf5C}nKn.j1vvWKt^n^xD64-2lI:4d,ca>)0[#1-3?+=dF rd=p_eKQe2', ':27@GFx!{a]', '/30|fga%YLBCEKBsY+i"X0P0y5\\)16u628hMJ1a2=2<{M#c8.-:xSPfAgfQz!q^.F)]_w]%L%RRdi7w1Q\\+6plbqU_9h[r-!::/zp]gQz\'yj', 'voX5ZeFs276033K8l\\"RdlV.<30gj:Z>i']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 507.45
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 100.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.11284734719781862
# -------------------------------------------------------------------------------------

# %% [markdown]
# ### Listening samples - none

# %% [markdown]
# ### Observations
#  - Still prodcuing gibberish, might need to reduce lambda paramter further

# %% [markdown]
# ## Regularization Experimentation - L2 with lambda 0.0001

# %%
model_weights_directory = 'Data/Model_Weights/Model_1/RegL2Lambda0.0001/'
generated_samples_directory = 'Data/Generated_Samples/Model_1/RegL2Lambda0.0001/'

batch_size = 64
seq_length = 50
num_epochs = 200
reg_lambda = 0.0001

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
 initial_learning_rate = 0.003, decay_steps = 20, decay_rate = 0.97, 
  staircase=False)

optimizer_ = tf.keras.optimizers.RMSprop(lr_schedule)

model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))

model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))

model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))


model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_11 (Embedding)     (64, 50, 512)             47616
# _________________________________________________________________
# lstm_33 (LSTM)               (64, 50, 512)             2099200
# _________________________________________________________________
# lstm_34 (LSTM)               (64, 50, 512)             2099200
# _________________________________________________________________
# lstm_35 (LSTM)               (64, 50, 512)             2099200
# _________________________________________________________________
# time_distributed_11 (TimeDis (64, 50, 93)              47709
# _________________________________________________________________
# activation_11 (Activation)   (64, 50, 93)              0
# =================================================================
# Total params: 6,392,925
# Trainable params: 6,392,925
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)
    
print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 2.181657075881958
# Accuracy: 0.43031251430511475

# %% [markdown]
# ### Sequence Generation

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 76
seq_length = 500

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# Performance evaluation
evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '6/4': 0.0009652509652509653, '5/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'8nMi1:/8': 0.5, 'Qama-F Cd2|"mA#G/|B/2g/"/2 "G/2F/2f/2c|"E""eE/2A/2g/2 f/2e/2A2/2|Am1"E/2ge/2A/2/2|DA"': 0.5}
#
# Unique 'M' values to generated dataset: ['8nMi1:/8', 'Qama-F Cd2|"mA#G/|B/2g/"/2 "G/2F/2f/2c|"E""eE/2A/2g/2 f/2e/2A2/2|Am1"E/2ge/2A/2/2|DA"']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'E': 0.0009652509652509653, 'B': 0.0009652509652509653, 'Cm': 0.0009652509652509653}
# Generated Dataset Distribution
# {'G=f/2f/2fd/2d/2B/2B|""E"f/4|': 0.3333333333333333, '4L4K"G/2B/2g/2|"""gEd/2c2d/2c/2 F/2B/2|c"7D/2A/2A/2B/2 /2|"DGB/2|dEc/2g/2 D/2 E/2g/A/2 G/4B/2e/2|"DG2d|"DA:': 0.3333333333333333, '2f "A:e-gA|"e/2g2d/2 "': 0.3333333333333333}
#
# Unique 'K' values to generated dataset: ['G=f/2f/2fd/2d/2B/2B|""E"f/4|', '4L4K"G/2B/2g/2|"""gEd/2c2d/2c/2 F/2B/2|c"7D/2A/2A/2B/2 /2|"DGB/2|dEc/2g/2 D/2 E/2g/A/2 G/4B/2e/2|"DG2d|"DA:', '2f "A:e-gA|"e/2g2d/2 "']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 210.22
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 100.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.32174505548497173
# -------------------------------------------------------------------------------------

# %% [markdown]
# ### Listening samples - none

# %% [markdown]
# ### Observations
# - L2 regularization might be unhelpful altogeher

# %% [markdown]
# ### KERNEL REG WITH L2 AND DROPOUT

# %%
model_weights_directory = 'drive/MyDrive/Data/Model_Weights/Model_1/Dropout0.5_RegL2Lambda0.0001/'
generated_samples_directory = 'drive/MyDrive/Data/Generated_Samples/Model_1/Dropout0.5_RegL2Lambda0.0001/'

# %%
batch_size = 64
seq_length = 50
num_epochs = 200
reg_lambda = 0.0001

# %%
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
 initial_learning_rate = 0.003, decay_steps = 20, decay_rate = 0.97, 
  staircase=False)

optimizer_ = tf.keras.optimizers.RMSprop(lr_schedule)

# %%
model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))
model.add(Dropout(0.5))

model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))
model.add(Dropout(0.5))

model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))
model.add(Dropout(0.5))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))


model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_303"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_303 (Embedding)    (64, 50, 512)             47616
# _________________________________________________________________
# lstm_906 (LSTM)              (64, 50, 512)             2099200
# _________________________________________________________________
# dropout (Dropout)            (64, 50, 512)             0
# _________________________________________________________________
# lstm_907 (LSTM)              (64, 50, 512)             2099200
# _________________________________________________________________
# dropout_1 (Dropout)          (64, 50, 512)             0
# _________________________________________________________________
# lstm_908 (LSTM)              (64, 50, 512)             2099200
# _________________________________________________________________
# dropout_2 (Dropout)          (64, 50, 512)             0
# _________________________________________________________________
# time_distributed_2 (TimeDist (64, 50, 93)              47709
# _________________________________________________________________
# activation_302 (Activation)  (64, 50, 93)              0
# =================================================================
# Total params: 6,392,925
# Trainable params: 6,392,925
# Non-trainable params: 0
# _________________________________________________________________

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)
    
print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 1.0645039081573486
# Accuracy: 0.7081249952316284

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))
    generator_model.add(Dropout(0.5))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))
    generator_model.add(Dropout(0.5))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))
    generator_model.add(Dropout(0.5))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 83
seq_length = 700

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# %%
generated_df
# Out:
#                                         transcription  ...               M
# 0   "eA7"mvgE_2D/77N|TGA)z@X "1vhfkPpepres)NV|ARon...  ...             NaN
# 1   mn'xee_uthlrhd":/Ga7q/of"7W(<Pg1sea^s/?@dO(bR!...  ...             NaN
# 2   G, "|PT9)SR1rnna4Tsa n6'iepebQegertrtsMq:m e1s...  ...          psg!7b
# 3   tcl7iJsipjsR 6:m[Sa6(op(1hc&R)aoE2/h3/Qc/p))f0...  ...             NaN
# 4   '"P BB2B_| FR(3j[hB[gdic2e:\[tbiucsny3.LCQl'f\...  ...             :Mn
# ..                                                ...  ...             ...
# 95  /=Jhyuu!8op6//bfeK)uJg38i6yi'Rmyr\Ph6.o"pfTGKM...  ...             NaN
# 96  Sholmma3PrflpnPgsm'w6Pxg.j1(Vh)yK&=Gx.k rasd0t...  ...             NaN
# 97  r7"Tw?lsusigpln!gMass8omlaowKlTrrs*m93/A4/F//G...  ...             NaN
# 98  bAh+rsstRlNJl'T0uguherpUoemS al TgndvTJpTikJpa...  ...             NaN
# 99  \otcpt,z+ 7:l6mKexUnK6upayP8L"nudaLxwofrsei7Sp...  ...  3doqceh ls yr1
#
# [100 rows x 3 columns]

# %%
evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '6/4': 0.0009652509652509653, '5/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'KpkpmKvr1kzj6bu)s[d!ss:o8wGr9m}7o9K"Gm))99qlc8Bsic/o*': 0.037037037037037035, 'l un7)M"B14"AFA#C"E/"9/2F,c/AF': 0.037037037037037035, '3doqceh ls yr1': 0.037037037037037035, '!Nne(1ss!KgL?o2(:8/e6)cSP"Aa2fD9(33d/44cG/4+=g': 0.037037037037037035, 'KPT5Prue2\'pss"SukPM"CFmJLc_aaomfp)J*A"B|)A(J^gg/4d),)': 0.037037037037037035, "]0'e7S8R!ews(asz8.e)f:c))F'ltgrhCe2 ea'bgrs|1aGYeq'2gt(p\\Pm1Rh7": 0.037037037037037035, "M',,bb98\\_of]MupGtTso7rhkmphmva'e-qs}oB6(s8)AO37w83pe)1/": 0.037037037037037035, 'pt!i': 0.037037037037037035, 'GT8vTpS)Lesu? Pk1os': 0.037037037037037035, '+oEKzG)IY"twT^"VtbytMDtLKMg5wblc(~c/F3)8vv/aef)4<lx:18ftJuex/scd)R)0"|DD|7)': 0.037037037037037035, "6br'npayfc8yiGa8d8zr/0)+": 0.037037037037037035, 'lkyas rmipde*': 0.037037037037037035, 'hknKo! lOhbtesK\'#SpslRur p rnwfK"K"P]Deg#Jdgfzfke)': 0.037037037037037035, ':Mn': 0.037037037037037035, 'nrr r6emsudOkoskugv:R agIM=P pm P pl!bg,)/fe8^': 0.037037037037037035, 'na*1y1pqD(1': 0.037037037037037035, '\\!Cxr%#eW8ly,l,D\\M': 0.037037037037037035, 'ti:hn )Kg6^5RLeedl': 0.037037037037037035, 'J8pnMri,pwmey!15PPcY': 0.037037037037037035, 'KPpsmogoUligSstnwT5Mu7 y#8d8+BP)1a/^:AjE]f(2d+4cc<e\\A92|Fz6^f2_]]Gugr3fg[_+A-|6"G3': 0.037037037037037035, 'psg!7b': 0.037037037037037035, '"m7mf\\gFM4ki"g': 0.037037037037037035, 'RR(1luhpc4v@n^n(n7pP': 0.037037037037037035, 'PN': 0.037037037037037035, 'owhip': 0.037037037037037035, 'o46ecu1s53d^': 0.037037037037037035, '': 0.037037037037037035}
#
# Unique 'M' values to generated dataset: ['KpkpmKvr1kzj6bu)s[d!ss:o8wGr9m}7o9K"Gm))99qlc8Bsic/o*', 'l un7)M"B14"AFA#C"E/"9/2F,c/AF', '3doqceh ls yr1', '!Nne(1ss!KgL?o2(:8/e6)cSP"Aa2fD9(33d/44cG/4+=g', 'KPT5Prue2\'pss"SukPM"CFmJLc_aaomfp)J*A"B|)A(J^gg/4d),)', "]0'e7S8R!ews(asz8.e)f:c))F'ltgrhCe2 ea'bgrs|1aGYeq'2gt(p\\Pm1Rh7", "M',,bb98\\_of]MupGtTso7rhkmphmva'e-qs}oB6(s8)AO37w83pe)1/", 'pt!i', 'GT8vTpS)Lesu? Pk1os', '+oEKzG)IY"twT^"VtbytMDtLKMg5wblc(~c/F3)8vv/aef)4<lx:18ftJuex/scd)R)0"|DD|7)', "6br'npayfc8yiGa8d8zr/0)+", 'lkyas rmipde*', 'hknKo! lOhbtesK\'#SpslRur p rnwfK"K"P]Deg#Jdgfzfke)', ':Mn', 'nrr r6emsudOkoskugv:R agIM=P pm P pl!bg,)/fe8^', 'na*1y1pqD(1', '\\!Cxr%#eW8ly,l,D\\M', 'ti:hn )Kg6^5RLeedl', 'J8pnMri,pwmey!15PPcY', 'KPpsmogoUligSstnwT5Mu7 y#8d8+BP)1a/^:AjE]f(2d+4cc<e\\A92|Fz6^f2_]]Gugr3fg[_+A-|6"G3', 'psg!7b', '"m7mf\\gFM4ki"g', 'RR(1luhpc4v@n^n(n7pP', 'PN', 'owhip', 'o46ecu1s53d^', '']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'E': 0.0009652509652509653, 'B': 0.0009652509652509653, 'Cm': 0.0009652509652509653}
# Generated Dataset Distribution
# {'gsoJ)wRoK[Qop2hnzlf2soKdKB\\8"0A+eEs4"AE|/3D2I,/4=))56/!43)5,': 0.030303030303030304, '9l99on>KMDGwKRgfdgkfI m,vlutVrnye': 0.030303030303030304, 'ebnhapas5dub)afcea/0k)5)fkJ/iyeysUrEG': 0.030303030303030304, 'a9e8gif': 0.030303030303030304, 'U\\hYldkorwgwsussrC1(44KiKTwMcmsgf-6qt0!>k gvae/<nen3k': 0.030303030303030304, '(8^d1(feicfc/4A/-\'acg 3"od\'3e/3ce3/2/-e/2': 0.030303030303030304, 'GP2h%M:nnudanyPytCMylo': 0.030303030303030304, 'V*uD7!ywyu h"sngaK9': 0.030303030303030304, 'ahbb8lg': 0.030303030303030304, '1Kwecy4io\'"miakeodsprsswssrc"Ow+as(g{esomJupnS!h': 0.030303030303030304, 'G{\'bh1"3=H\\Ppegsurryn6KEUBKMg/an_lBC5e\\c\\"fR" 3#7bW+^05*+\'r#2b*cT/Gz*EB)Q,c</EAhfd-"^(?y|"zDa6"vcawOJ  on|': 0.030303030303030304, 'B853mgp"dAm^(488R1R': 0.030303030303030304, 'p87uy': 0.030303030303030304, 'i8ilhpnd/ipRj>)9P"+OudWPl Mo\'!eg': 0.030303030303030304, "9mb2FQ7 Ci?(PICCagbru'fsa'Qeo Gu)[YfpnePfUAf>+_:AAG)c^//A=f|f": 0.030303030303030304, 'xp|*KdK*E((3+)!mg/)ownRw1Q-2olQ1gl\\': 0.030303030303030304, 'T?nXmu=Trngr': 0.030303030303030304, 'Fnp6CexnyXa^piernPg': 0.030303030303030304, 'C&s.YNb6gbygLx\'hw)npsT@Vg"': 0.030303030303030304, 'Ra!': 0.030303030303030304, '=F8e89kpg9o': 0.030303030303030304, '!gaDfxes|m("*G^/A,2/2AB/4\\A': 0.030303030303030304, 's:,t4shyn>5*8.{m1w#3TNEA6i)suGE:0(wTpOPwwnhk!uIrpspuTlau?4!tM9"b678wdeg\'*V|DF\'S': 0.030303030303030304, 'qot!gntTaKei Pmrmixn1psd2!ad|"AB3/(D8GE)/GA3!D+3|"EcBA3GB2|': 0.030303030303030304, 'Mtm19nyl-M(pp<!ybKvmDSBT<': 0.030303030303030304, 'cNDg.D}FO"G7#<hK\'"QK~G.(LQ?NAA1"T\'A[-uH': 0.030303030303030304, "BeuQds3ES'py": 0.030303030303030304, 'c5KvuT1un8 (,YJ7)oeS:s(As)Vl': 0.030303030303030304, 'So Thpmm1anR9ihm1Ao0PLU"AogGuy)r4:  a(2w-8RD)8"GPm)a.89fUtF,:g>wT"e,A8l': 0.030303030303030304, 'BiKpPW!)pPtToemRbtnrKpDi9aS(nYn)x1F7/U4\\Pflbfr9.3)drs)(/J)f/))d+5)^t! i': 0.030303030303030304, 'J"7JfIf4)Wyr': 0.030303030303030304, '#bI.8/orh,G4&O"': 0.030303030303030304, '"O2t{uyProhu orptsauprukotI 1m1V5\'\'bsooPf l': 0.030303030303030304}
#
# Unique 'K' values to generated dataset: ['gsoJ)wRoK[Qop2hnzlf2soKdKB\\8"0A+eEs4"AE|/3D2I,/4=))56/!43)5,', '9l99on>KMDGwKRgfdgkfI m,vlutVrnye', 'ebnhapas5dub)afcea/0k)5)fkJ/iyeysUrEG', 'a9e8gif', 'U\\hYldkorwgwsussrC1(44KiKTwMcmsgf-6qt0!>k gvae/<nen3k', '(8^d1(feicfc/4A/-\'acg 3"od\'3e/3ce3/2/-e/2', 'GP2h%M:nnudanyPytCMylo', 'V*uD7!ywyu h"sngaK9', 'ahbb8lg', '1Kwecy4io\'"miakeodsprsswssrc"Ow+as(g{esomJupnS!h', 'G{\'bh1"3=H\\Ppegsurryn6KEUBKMg/an_lBC5e\\c\\"fR" 3#7bW+^05*+\'r#2b*cT/Gz*EB)Q,c</EAhfd-"^(?y|"zDa6"vcawOJ  on|', 'B853mgp"dAm^(488R1R', 'p87uy', 'i8ilhpnd/ipRj>)9P"+OudWPl Mo\'!eg', "9mb2FQ7 Ci?(PICCagbru'fsa'Qeo Gu)[YfpnePfUAf>+_:AAG)c^//A=f|f", 'xp|*KdK*E((3+)!mg/)ownRw1Q-2olQ1gl\\', 'T?nXmu=Trngr', 'Fnp6CexnyXa^piernPg', 'C&s.YNb6gbygLx\'hw)npsT@Vg"', 'Ra!', '=F8e89kpg9o', '!gaDfxes|m("*G^/A,2/2AB/4\\A', 's:,t4shyn>5*8.{m1w#3TNEA6i)suGE:0(wTpOPwwnhk!uIrpspuTlau?4!tM9"b678wdeg\'*V|DF\'S', 'qot!gntTaKei Pmrmixn1psd2!ad|"AB3/(D8GE)/GA3!D+3|"EcBA3GB2|', 'Mtm19nyl-M(pp<!ybKvmDSBT<', 'cNDg.D}FO"G7#<hK\'"QK~G.(LQ?NAA1"T\'A[-uH', "BeuQds3ES'py", 'c5KvuT1un8 (,YJ7)oeS:s(As)Vl', 'So Thpmm1anR9ihm1Ao0PLU"AogGuy)r4:  a(2w-8RD)8"GPm)a.89fUtF,:g>wT"e,A8l', 'BiKpPW!)pPtToemRbtnrKpDi9aS(nYn)x1F7/U4\\Pflbfr9.3)drs)(/J)f/))d+5)^t! i', 'J"7JfIf4)Wyr', '#bI.8/orh,G4&O"', '"O2t{uyProhu orptsauprukotI 1m1V5\'\'bsooPf l']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 487.35
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 100.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.12593565385988467
# -------------------------------------------------------------------------------------

# %% [markdown]
# ### L1

# %%
model_weights_directory = 'drive/MyDrive/Data/Model_Weights/Model_1/RegL1Lambda0.01/'
generated_samples_directory = 'drive/MyDrive/Data/Generated_Samples/Model_1/RegL1Lambda0.01/'

# %%
batch_size = 64
seq_length = 50
num_epochs = 200
reg_lambda = 0.01

# %%
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
 initial_learning_rate = 0.003, decay_steps = 20, decay_rate = 0.97, 
  staircase=False)

optimizer_ = tf.keras.optimizers.RMSprop(lr_schedule)

# %%
model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=L1(reg_lambda), recurrent_regularizer=L1(reg_lambda), bias_regularizer=L1(reg_lambda)))

model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=L1(reg_lambda), recurrent_regularizer=L1(reg_lambda), bias_regularizer=L1(reg_lambda)))

model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=L1(reg_lambda), recurrent_regularizer=L1(reg_lambda), bias_regularizer=L1(reg_lambda)))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))


model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_406"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_406 (Embedding)    (64, 50, 512)             47616
# _________________________________________________________________
# lstm_1209 (LSTM)             (64, 50, 512)             2099200
# _________________________________________________________________
# lstm_1210 (LSTM)             (64, 50, 512)             2099200
# _________________________________________________________________
# lstm_1211 (LSTM)             (64, 50, 512)             2099200
# _________________________________________________________________
# time_distributed_3 (TimeDist (64, 50, 93)              47709
# _________________________________________________________________
# activation_403 (Activation)  (64, 50, 93)              0
# =================================================================
# Total params: 6,392,925
# Trainable params: 6,392,925
# Non-trainable params: 0
# _________________________________________________________________

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)
    
print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 3.4197778701782227
# Accuracy: 0.11999999731779099

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))
    

    generator_model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))
    

    generator_model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))
    

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 73
seq_length = 500

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# %%
generated_df
# Out:
#                                         transcription  ...    K
# 0   |2D""F|e3s22/BBe2B"a"/G"4Am|dB":4BX/|mfA"4m" D...  ...  NaN
# 1   m""2\"mBg""CAae2 i2|gFh/ P"\4/"BD4""||aeGtEcdA...  ...  NaN
# 2   4|N"G:g"F BG2E"AA/""P2""ee""Gd"/mGaA22/ Di/E4"...  ...  NaN
# 3   O24edC """/23~D""/BaB2r2A"a|2m7Ee2"":3(F3cDfXe...  ...  NaN
# 4   D"\yG/22"22 2AE:y i"d2/de""""3"g/D"|GB"L//,dAE...  ...  NaN
# ..                                                ...  ...  ...
# 95  gc^/"g2 e/f am2Dmg"EB"""|/GeG NAmo|/":E"B2"c 7...  ...  NaN
# 96  q e)a\DG2/Fgc"AakMCB""2/1/die/"B2 "c2 ""m2"G|d...  ...  NaN
# 97  |/"eP2Ge/"\4/d/:22/l1"v /g /rac/||""mEn 3Bmem"...  ...  NaN
# 98  B22EF/a2g/BPAA7AA2]c"|2/21icE"2]/i/f|i9=|uicdC...  ...  NaN
# 99  divAd2c72kG//c2""AAG/d|2 Df/"2eaF"D2_bB"|jDdA/...  ...  NaN
#
# [100 rows x 3 columns]

# %%
evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '6/4': 0.0009652509652509653, '5/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'2E  d |M2fa6f2a /etG\\|"D,/7" c2c/2G BD"sf': 0.09090909090909091, 'c""Y Pnad/cc2|A4"i"ea"6g""bc2|da|:': 0.09090909090909091, 'D|" d"dai"/sG"Dfan/gcf/DFb\'D"A2eg/ i222sAehAl"4c:/"A-"d42e"B|2d"//eeB|"mDe2/":27co2angnF1 2G3n g^o"22X"11/2c%B":2/e B^"/AE"/a2"GDD]gB"2|/B |G2"F': 0.09090909090909091, '"2A"/2cMc""4xa A': 0.09090909090909091, 'f"': 0.09090909090909091, 'E"22c': 0.09090909090909091, '3d|A2Gbi/c:cp 2|g2A2GcfD /"i/ ""3/s2"D f/ //d8u/G:Xc2"B  /222B3e2|iDc|"2EG EF/iK z-|2""^Cge3b r/":/Gm/|:/d3//"^//: 2T/t"P4EK"YW"': 0.09090909090909091, 'fDAcf-"A|G': 0.09090909090909091, 'AP2': 0.09090909090909091, '/ogE2|2"2 B3"c/2/A "/|ddfE': 0.09090909090909091, '"2g/zt2/Gh, et/|:2GD ||G2o2': 0.09090909090909091}
#
# Unique 'M' values to generated dataset: ['2E  d |M2fa6f2a /etG\\|"D,/7" c2c/2G BD"sf', 'c""Y Pnad/cc2|A4"i"ea"6g""bc2|da|:', 'D|" d"dai"/sG"Dfan/gcf/DFb\'D"A2eg/ i222sAehAl"4c:/"A-"d42e"B|2d"//eeB|"mDe2/":27co2angnF1 2G3n g^o"22X"11/2c%B":2/e B^"/AE"/a2"GDD]gB"2|/B |G2"F', '"2A"/2cMc""4xa A', 'f"', 'E"22c', '3d|A2Gbi/c:cp 2|g2A2GcfD /"i/ ""3/s2"D f/ //d8u/G:Xc2"B  /222B3e2|iDc|"2EG EF/iK z-|2""^Cge3b r/":/Gm/|:/d3//"^//: 2T/t"P4EK"YW"', 'fDAcf-"A|G', 'AP2', '/ogE2|2"2 B3"c/2/A "/|ddfE', '"2g/zt2/Gh, et/|:2GD ||G2o2']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'E': 0.0009652509652509653, 'B': 0.0009652509652509653, 'Cm': 0.0009652509652509653}
# Generated Dataset Distribution
# {'|4|s"2:"e i Ac""b//a""A/2dD D': 0.1, 'aBc2dD"cd2A//"2GEe2/:c"GAms:e"w/2c2f""24"e2B2|e  fch/': 0.1, '" /|m//ceco': 0.1, '2cDBE': 0.1, 'f': 0.1, 'FB/ch"2gA2cFSAS"Er22DB|e|s2': 0.1, 'dsg': 0.1, 'AdB|E2/22""Bw:mieG| B uDgAPSg/2': 0.1, 'GaeaBDi \\iG"|/|tG""|f#FBi/vBDF|fd""BD"g:N]:A/2sb BdBC9\\u|2E/BAD^2262E|""2p': 0.1, 'A2A/2G"GX|/aLdgGDAeG|eA%k2\\ :3"': 0.1}
#
# Unique 'K' values to generated dataset: ['|4|s"2:"e i Ac""b//a""A/2dD D', 'aBc2dD"cd2A//"2GEe2/:c"GAms:e"w/2c2f""24"e2B2|e  fch/', '" /|m//ceco', '2cDBE', 'f', 'FB/ch"2gA2cFSAS"Er22DB|e|s2', 'dsg', 'AdB|E2/22""Bw:mieG| B uDgAPSg/2', 'GaeaBDi \\iG"|/|tG""|f#FBi/vBDF|fd""BD"g:N]:A/2sb BdBC9\\u|2E/BAD^2262E|""2p', 'A2A/2G"GX|/aLdgGDAeG|eA%k2\\ :3"']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 330.63
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 100.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.22643841793756342
# -------------------------------------------------------------------------------------

# %% [markdown]
# ### L1 0.0001

# %%
model_weights_directory = 'drive/MyDrive/Data/Model_Weights/Model_1/RegL1Lambda0.0001/'
generated_samples_directory = 'drive/MyDrive/Data/Generated_Samples/Model_1/RegL1Lambda0.0001/'

batch_size = 64
seq_length = 50
num_epochs = 200
reg_lambda = 0.0001


lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
 initial_learning_rate = 0.003, decay_steps = 20, decay_rate = 0.97, 
  staircase=False)

optimizer_ = tf.keras.optimizers.RMSprop(lr_schedule)


model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=L1(reg_lambda), recurrent_regularizer=L1(reg_lambda), bias_regularizer=L1(reg_lambda)))

model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=L1(reg_lambda), recurrent_regularizer=L1(reg_lambda), bias_regularizer=L1(reg_lambda)))

model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=L1(reg_lambda), recurrent_regularizer=L1(reg_lambda), bias_regularizer=L1(reg_lambda)))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))


model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_507"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_507 (Embedding)    (64, 50, 512)             47616
# _________________________________________________________________
# lstm_1512 (LSTM)             (64, 50, 512)             2099200
# _________________________________________________________________
# lstm_1513 (LSTM)             (64, 50, 512)             2099200
# _________________________________________________________________
# lstm_1514 (LSTM)             (64, 50, 512)             2099200
# _________________________________________________________________
# time_distributed_4 (TimeDist (64, 50, 93)              47709
# _________________________________________________________________
# activation_504 (Activation)  (64, 50, 93)              0
# =================================================================
# Total params: 6,392,925
# Trainable params: 6,392,925
# Non-trainable params: 0
# _________________________________________________________________

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)
    
print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 3.3933403491973877
# Accuracy: 0.11999999731779099

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))
    

    generator_model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))
    

    generator_model.add(LSTM(512, return_sequences = True, stateful = True, kernel_regularizer=l2(reg_lambda), recurrent_regularizer=l2(reg_lambda), bias_regularizer=l2(reg_lambda)))
    

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 73
seq_length = 500

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# %%
generated_df
# Out:
#                                         transcription  ...                                                  K
# 0   |sg222/c32:c|cu"daG/%tDEdB  2nGp7fGd%C!"eGGe "...  ...                                                NaN
# 1   " 2"FdB:"F2B"BF/:mg|Gi"/Asf//ia2G"cc:"7e"27Ad%...  ...                                                NaN
# 2   2DdXg2i3bd"3B"2 /gcG d d"E2TBasdEo8in"Ag"AG7 e...  ...                                                NaN
# 3   ADa f"e "DhCD|B"/"2/B a2A\c g /|o/e2Bdt27 r:Em...  ...                                                NaN
# 4   Gg3i"|"/Ag||G"aPA4d"A"uDaDe/ ="gA/2'/\av|"Dsa|...  ...                                                NaN
# ..                                                ...  ...                                                ...
# 95  2""o"||"isaCAc//ddX2c2"A  22"cB|d"|d cdc7/GB"g...  ...                                                NaN
# 96  ef2\gEaM3/7B2"d"2/F"3X"/d A" 22"" "|'""da^b/1/...  ...                                                NaN
# 97  aamB2"eC Ma2|"2d7P2kie|BMe)/dP2"2ae,F2K|c2m"/A...  ...                                                NaN
# 98  2Gm"2"ETdB"/6/A"2a2|df|ue ]D""LGG t"f:222A"ig|...  ...  u4A22/dg2dG|"E22E2n/c2/GGB d:""27AB"B/Bt"3r/A ...
# 99  /fEFd/AE2AcC"e"gBW2mh(nme"2|" /aB|: /\dmk"A/||...  ...                                                NaN
#
# [100 rows x 3 columns]

# %%
evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '6/4': 0.0009652509652509653, '5/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'"A"7m': 0.16666666666666666, 'd3 "2A/"D|D24': 0.16666666666666666, '//"Gd/b Et/""", e/A/ / /21"n/"|D2e/': 0.16666666666666666, '/Ag|2B': 0.16666666666666666, 'LN7/a|': 0.16666666666666666, '': 0.16666666666666666}
#
# Unique 'M' values to generated dataset: ['"A"7m', 'd3 "2A/"D|D24', '//"Gd/b Et/""", e/A/ / /21"n/"|D2e/', '/Ag|2B', 'LN7/a|', '']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'E': 0.0009652509652509653, 'B': 0.0009652509652509653, 'Cm': 0.0009652509652509653}
# Generated Dataset Distribution
# {'u4A22/dg2dG|"E22E2n/c2/GGB d:""27AB"B/Bt"3r/A ctd"n/fG"m/G"ag|D': 0.2, 't/ Gr7e2"Fdd/"KB2" 3eb2"4 :"/432"MfE/2m|': 0.2, 'A/ d"iA :r/2"AD ":/"2G4227"d|g /:"|K22y /': 0.2, 'cM/cdD a/"aDr7"E2"/dG2""XBC2\\|"S724/|AeG/ASG  /aD:/2d2': 0.2, '3c/cf"2c2s/De"C7': 0.2}
#
# Unique 'K' values to generated dataset: ['u4A22/dg2dG|"E22E2n/c2/GGB d:""27AB"B/Bt"3r/A ctd"n/fG"m/G"ag|D', 't/ Gr7e2"Fdd/"KB2" 3eb2"4 :"/432"MfE/2m|', 'A/ d"iA :r/2"AD ":/"2G4227"d|g /:"|K22y /', 'cM/cdD a/"aDr7"E2"/dG2""XBC2\\|"S724/|AeG/ASG  /aD:/2d2', '3c/cf"2c2s/De"C7']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 315.7
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 100.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.23834691440655947
# -------------------------------------------------------------------------------------

# %% [markdown]
# ## POISSON

# %%
model_weights_directory = 'drive/MyDrive/Data/Model_Weights/Model_1/Dropout0.7_BatchSize16_Poisson/'
generated_samples_directory = 'drive/MyDrive/Data/Generated_Samples/Model_1/Dropout0.7_BatchSize16_Poisson/'

batch_size = 16
seq_length = 50
num_epochs = 200


lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
 initial_learning_rate = 0.003, decay_steps = 20, decay_rate = 0.97, 
  staircase=False)

optimizer_ = tf.keras.optimizers.RMSprop(lr_schedule)


model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.7))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.7))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.7))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))


model.compile(loss = "poisson", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (16, 50, 512)             47616
# _________________________________________________________________
# lstm (LSTM)                  (16, 50, 512)             2099200
# _________________________________________________________________
# dropout (Dropout)            (16, 50, 512)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (16, 50, 512)             2099200
# _________________________________________________________________
# dropout_1 (Dropout)          (16, 50, 512)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (16, 50, 512)             2099200
# _________________________________________________________________
# dropout_2 (Dropout)          (16, 50, 512)             0
# _________________________________________________________________
# time_distributed (TimeDistri (16, 50, 93)              47709
# _________________________________________________________________
# activation (Activation)      (16, 50, 93)              0
# =================================================================
# Total params: 6,392,925
# Trainable params: 6,392,925
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)
    
print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 0.02541968785226345
# Accuracy: 0.5837500095367432

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.7))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.7))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.7))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 86
seq_length = 1000

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# %%
generated_df
# Out:
#                                         transcription  ...                                              K
# 0   "D"cd f4/2a/2|"D"gf g2|"Cm"Ag/2e/2 cd|"D"a3/2c...  ...                                              G
# 1   B/2c/2|"D"Aa/2f/2 e/2g/2c/2d/2|"A"fc/2f/2 ge/2...  ...                                              D
# 2   ,KKMP:::/4"Gm"ef/2d/2 "D"F/2F/2F/2A/2|"D"g/2d/...  ...                                              G
# 3   G|"A"BA FF/2B/2F/2d/2|"Am"gd/2a/2 ge|\"G"B/2B/...  ...                                              G
# 4   :3m"E7"B/2F/2A/2c/2 "D"dG/2c/2|"G"gf/2d/2 "E"A...  ...  G"Dm"EA G/2A/2B|"D"GB/2d/2 "G7"c/2d/2c/2B/2|\
# ..                                                ...  ...                                            ...
# 95                                           "D"B3 \|  ...                       A7lzi)|ae "G"d2"E7"B cf|
# 96  C/2g/2|\"Am"dc "A"d/2F/2B/2G/2|"A"G/2F/2B/2B/2...  ...                                              A
# 97  "G"gf "D"d/2B/2B/2A/2|"D"Ad/2B/2 "E7"DG/2G/2|\...  ...                                              D
# 98  "D"G/2G/2B/2G/2 "D7"E/2A/2A/2A/2|"D"A/2A/2A/2A...  ...                                              D
# 99  A|"B"A2G|"G"GG/2E/2 G/2A/2A/2G/2|\"G"Gd BA/2B/...  ...                                              A
#
# [100 rows x 3 columns]

# %%
evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '6/4': 0.0009652509652509653, '5/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'4/4': 0.6865671641791045, '6/8': 0.23880597014925373, '6/4': 0.029850746268656716, '//8': 0.014925373134328358, '3/8': 0.014925373134328358, '4oga': 0.014925373134328358}
#
# Unique 'M' values to generated dataset: ['//8', '3/8', '4oga']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'E': 0.0009652509652509653, 'Cm': 0.0009652509652509653, 'B': 0.0009652509652509653}
# Generated Dataset Distribution
# {'D': 0.2987012987012987, 'G': 0.2597402597402597, 'A': 0.2077922077922078, 'B': 0.05194805194805195, 'F': 0.03896103896103896, 'C': 0.03896103896103896, 'A"cG/2e/2 ee/2g/2|"Am"b/2e/2e/2g/2 "Am"d/2a/2f/2e/2|"Am"g/2e/2c/2A/2 d/2B/2A/2c/2|"A"G/2G/2A/2F/2 F/2^A/2Gd|"Am"B/2B/2G/2F/2 c3/2|\\': 0.012987012987012988, 'G"Dm"EA G/2A/2B|"D"GB/2d/2 "G7"c/2d/2c/2B/2|\\': 0.012987012987012988, 'Gm': 0.012987012987012988, 'C"G/2d/2F/2G/2|': 0.012987012987012988, 'A7lzi)|ae "G"d2"E7"B cf|': 0.012987012987012988, 'BAD': 0.012987012987012988, 'Am': 0.012987012987012988, '8G/2F/2A/2|"A"AEFA BAC|"Em"e3 e2d|(cdBEFEADcA](EGc2B|:"D7"^Gde3 2FGA B2GB|B2c2-Dd2/2g/2|': 0.012987012987012988}
#
# Unique 'K' values to generated dataset: ['A"cG/2e/2 ee/2g/2|"Am"b/2e/2e/2g/2 "Am"d/2a/2f/2e/2|"Am"g/2e/2c/2A/2 d/2B/2A/2c/2|"A"G/2G/2A/2F/2 F/2^A/2Gd|"Am"B/2B/2G/2F/2 c3/2|\\', 'G"Dm"EA G/2A/2B|"D"GB/2d/2 "G7"c/2d/2c/2B/2|\\', 'C"G/2d/2F/2G/2|', 'A7lzi)|ae "G"d2"E7"B cf|', 'BAD', '8G/2F/2A/2|"A"AEFA BAC|"Em"e3 e2d|(cdBEFEADcA](EGc2B|:"D7"^Gde3 2FGA B2GB|B2c2-Dd2/2g/2|']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 328.93
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 35.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.30496909015371915
# -------------------------------------------------------------------------------------

# %%
# Fuck around get lower the error rate

# %%
#Try GRU and reducing complexity?

# %% [markdown]
# ## Reducing Complexity

# %%
model_weights_directory = 'drive/MyDrive/Data/Model_Weights/Model_1/ReduceComplexity_BatchSize16/'
generated_samples_directory = 'drive/MyDrive/Data/Generated_Samples/Model_1/ReduceComplexity_BatchSize16/'

batch_size = 16
seq_length = 50
num_epochs = 200


lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
 initial_learning_rate = 0.003, decay_steps = 20, decay_rate = 0.97, 
  staircase=False)

optimizer_ = tf.keras.optimizers.RMSprop(lr_schedule)


model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(256, return_sequences = True, stateful = True))
model.add(Dropout(0.5))

model.add(LSTM(256, return_sequences = True, stateful = True))
model.add(Dropout(0.5))

model.add(LSTM(256, return_sequences = True, stateful = True))
model.add(Dropout(0.5))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))


model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_402"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_402 (Embedding)    (16, 50, 512)             47616
# _________________________________________________________________
# lstm_1206 (LSTM)             (16, 50, 256)             787456
# _________________________________________________________________
# dropout_1206 (Dropout)       (16, 50, 256)             0
# _________________________________________________________________
# lstm_1207 (LSTM)             (16, 50, 256)             525312
# _________________________________________________________________
# dropout_1207 (Dropout)       (16, 50, 256)             0
# _________________________________________________________________
# lstm_1208 (LSTM)             (16, 50, 256)             525312
# _________________________________________________________________
# dropout_1208 (Dropout)       (16, 50, 256)             0
# _________________________________________________________________
# time_distributed_2 (TimeDist (16, 50, 93)              23901
# _________________________________________________________________
# activation_402 (Activation)  (16, 50, 93)              0
# =================================================================
# Total params: 1,909,597
# Trainable params: 1,909,597
# Non-trainable params: 0
# _________________________________________________________________

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)
    
print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 1.1326771974563599
# Accuracy: 0.6337500214576721

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(256, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.5))

    generator_model.add(LSTM(256, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.5))

    generator_model.add(LSTM(256, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.5))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 86
seq_length = 1000

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# %%
generated_df
# Out:
#                                         transcription    M  K
# 0   A/2A/2|"G"BBB G2d|"Am"ecc A2B|"Em"B^Be G2e|"A7...  6/8  A
# 1   "D"ec/2c/2 Ae|"G7"Be gd/2d/2|"C"e "G"B/2G/2A/2...  3/4  A
# 2   (3G/2G/2B/2|\"C"e3/4e/4 d/2c/2|"D"c/2c/2 A/2d/...  4/4  D
# 3   "A7"AF -"D"EA|"G"BA "D7"B2|"C"EG FD|"G"BB GB|"...  6/8  G
# 4   E|"A"DAA "A"A2A|"F7"AFA "A7"A2B|"G"c2d "E7"B2A...  6/8  D
# ..                                                ...  ... ..
# 95  "G"d/2A/2d/2d/2 d/2c/2^B/2A/2|"A7"DG GG|"Dm"c3...  4/4  G
# 96  B3|d/2B/2G/2B/2c/2d/2 g/2e/2g/2g/2a/2c/2|a/2e/...  6/8  D
# 97  A/2A/2|"C"c3/2d/2 GB|"Em"B GB|"G"d3/2f/2 "A7"e...  4/4  D
# 98  "A"A3/2c/2A|"D"d3/2d/2AA|"Em"Bdee|"C"e2gg|"A"A...  4/4  F
# 99  d|"D"c2g afg|"Em"agf "A"feF|"D"c2A AAA|"G"cdd ...  6/8  A
#
# [100 rows x 3 columns]

# %%
evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '6/4': 0.0009652509652509653, '5/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'6/8': 0.45054945054945056, '4/4': 0.43956043956043955, '3/4': 0.054945054945054944, '1/4': 0.02197802197802198, '2/4': 0.01098901098901099, 'e/4': 0.01098901098901099, '6/R': 0.01098901098901099}
#
# Unique 'M' values to generated dataset: ['1/4', 'e/4', '6/R']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'E': 0.0009652509652509653, 'Cm': 0.0009652509652509653, 'B': 0.0009652509652509653}
# Generated Dataset Distribution
# {'D': 0.3645833333333333, 'G': 0.34375, 'A': 0.16666666666666666, 'C': 0.07291666666666667, 'E': 0.020833333333333332, 'Am': 0.020833333333333332, 'F': 0.010416666666666666}
#
# Unique 'K' values to generated dataset: []
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 339.49
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 12.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.3607923431935678
# -------------------------------------------------------------------------------------

# %%
# If we decrease the complexity further we risk increasing the error rate significantly

# %%
# Maybe try incrasing dropout again? Or nein

# %% [markdown]
# ## Reduced Complexity + Dropout Icrease

# %%
model_weights_directory = 'drive/MyDrive/Data/Model_Weights/Model_1/ReduceComplexity_BatchSize16_Dropout0.7/'
generated_samples_directory = 'drive/MyDrive/Data/Generated_Samples/Model_1/ReduceComplexity_BatchSize16_Dropout0.7/'

batch_size = 16
seq_length = 50
num_epochs = 200


lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
 initial_learning_rate = 0.003, decay_steps = 20, decay_rate = 0.97, 
  staircase=False)

optimizer_ = tf.keras.optimizers.RMSprop(lr_schedule)


model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(256, return_sequences = True, stateful = True))
model.add(Dropout(0.7))

model.add(LSTM(256, return_sequences = True, stateful = True))
model.add(Dropout(0.7))

model.add(LSTM(256, return_sequences = True, stateful = True))
model.add(Dropout(0.7))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))


model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_1004"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1004 (Embedding)   (16, 50, 512)             47616
# _________________________________________________________________
# lstm_1809 (LSTM)             (16, 50, 256)             787456
# _________________________________________________________________
# dropout_3012 (Dropout)       (16, 50, 256)             0
# _________________________________________________________________
# lstm_1810 (LSTM)             (16, 50, 256)             525312
# _________________________________________________________________
# dropout_3013 (Dropout)       (16, 50, 256)             0
# _________________________________________________________________
# lstm_1811 (LSTM)             (16, 50, 256)             525312
# _________________________________________________________________
# dropout_3014 (Dropout)       (16, 50, 256)             0
# _________________________________________________________________
# time_distributed_4 (TimeDist (16, 50, 93)              23901
# _________________________________________________________________
# activation_1004 (Activation) (16, 50, 93)              0
# =================================================================
# Total params: 1,909,597
# Trainable params: 1,909,597
# Non-trainable params: 0
# _________________________________________________________________

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)
    
print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 1.376387596130371
# Accuracy: 0.5762500166893005

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(256, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.7))

    generator_model.add(LSTM(256, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.7))

    generator_model.add(LSTM(256, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.7))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 86
seq_length = 1000

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# %%
evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '6/4': 0.0009652509652509653, '5/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'4/4': 0.62, '6/8': 0.2, '6/4': 0.1, '1/4': 0.02, '3/4': 0.02, '7/8': 0.02, '4/2': 0.02}
#
# Unique 'M' values to generated dataset: ['1/4', '7/8', '4/2']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'E': 0.0009652509652509653, 'Cm': 0.0009652509652509653, 'B': 0.0009652509652509653}
# Generated Dataset Distribution
# {'G': 0.2727272727272727, 'A': 0.2545454545454545, 'D': 0.2545454545454545, 'E': 0.07272727272727272, 'B': 0.05454545454545454, 'C': 0.05454545454545454, 'F7': 0.01818181818181818, 'F': 0.01818181818181818}
#
# Unique 'K' values to generated dataset: ['F7']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 273.64
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 52.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.24208405113361267
# -------------------------------------------------------------------------------------

# %%
seed_index = 86
seq_length = 1500

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '6/4': 0.0009652509652509653, '5/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'4/4': 0.58, '6/4': 0.16, '6/8': 0.1, '3/4': 0.04, '1/4': 0.02, ':/8': 0.02, '/4': 0.02, '4/8': 0.02, '8/4': 0.02, '//': 0.02}
#
# Unique 'M' values to generated dataset: ['1/4', ':/8', '/4', '4/8', '8/4', '//']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'E': 0.0009652509652509653, 'Cm': 0.0009652509652509653, 'B': 0.0009652509652509653}
# Generated Dataset Distribution
# {'D': 0.38461538461538464, 'A': 0.23076923076923078, 'G': 0.19230769230769232, 'C': 0.07692307692307693, 'B': 0.038461538461538464, 'g': 0.019230769230769232, 'Dm': 0.019230769230769232, 'Am': 0.019230769230769232, 'Da': 0.019230769230769232}
#
# Unique 'K' values to generated dataset: ['g', 'Da']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 328.55
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 52.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.2395222520019713
# -------------------------------------------------------------------------------------

# %% [markdown]
# ## MOre Epochs

# %%
model_weights_directory = 'drive/MyDrive/Data/Model_Weights/Model_1/ReduceComplexity_BatchSize16_Dropout0.7_400Epochs/'
generated_samples_directory = 'drive/MyDrive/Data/Generated_Samples/Model_1/ReduceComplexity_BatchSize16_Dropout0.7_400Epochs/'

batch_size = 16
seq_length = 50
num_epochs = 400


lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
 initial_learning_rate = 0.003, decay_steps = 20, decay_rate = 0.97, 
  staircase=False)

optimizer_ = tf.keras.optimizers.RMSprop(lr_schedule)


model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(256, return_sequences = True, stateful = True))
model.add(Dropout(0.7))

model.add(LSTM(256, return_sequences = True, stateful = True))
model.add(Dropout(0.7))

model.add(LSTM(256, return_sequences = True, stateful = True))
model.add(Dropout(0.7))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))


model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (16, 50, 512)             47616
# _________________________________________________________________
# lstm (LSTM)                  (16, 50, 256)             787456
# _________________________________________________________________
# dropout (Dropout)            (16, 50, 256)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (16, 50, 256)             525312
# _________________________________________________________________
# dropout_1 (Dropout)          (16, 50, 256)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (16, 50, 256)             525312
# _________________________________________________________________
# dropout_2 (Dropout)          (16, 50, 256)             0
# _________________________________________________________________
# time_distributed (TimeDistri (16, 50, 93)              23901
# _________________________________________________________________
# activation (Activation)      (16, 50, 93)              0
# =================================================================
# Total params: 1,909,597
# Trainable params: 1,909,597
# Non-trainable params: 0
# _________________________________________________________________

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)
    
print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/400
# Epoch 2/400
# Epoch 3/400
# Epoch 4/400
# Epoch 5/400
# Epoch 6/400
# Epoch 7/400
# Epoch 8/400
# Epoch 9/400
# Epoch 10/400
# Epoch 11/400
# Epoch 12/400
# Epoch 13/400
# Epoch 14/400
# Epoch 15/400
# Epoch 16/400
# Epoch 17/400
# Epoch 18/400
# Epoch 19/400
# Epoch 20/400
# Epoch 21/400
# Epoch 22/400
# Epoch 23/400
# Epoch 24/400
# Epoch 25/400
# Epoch 26/400
# Epoch 27/400
# Epoch 28/400
# Epoch 29/400
# Epoch 30/400
# Epoch 31/400
# Epoch 32/400
# Epoch 33/400
# Epoch 34/400
# Epoch 35/400
# Epoch 36/400
# Epoch 37/400
# Epoch 38/400
# Epoch 39/400
# Epoch 40/400
# Epoch 41/400
# Epoch 42/400
# Epoch 43/400
# Epoch 44/400
# Epoch 45/400
# Epoch 46/400
# Epoch 47/400
# Epoch 48/400
# Epoch 49/400
# Epoch 50/400
# Epoch 51/400
# Epoch 52/400
# Epoch 53/400
# Epoch 54/400
# Epoch 55/400
# Epoch 56/400
# Epoch 57/400
# Epoch 58/400
# Epoch 59/400
# Epoch 60/400
# Epoch 61/400
# Epoch 62/400
# Epoch 63/400
# Epoch 64/400
# Epoch 65/400
# Epoch 66/400
# Epoch 67/400
# Epoch 68/400
# Epoch 69/400
# Epoch 70/400
# Epoch 71/400
# Epoch 72/400
# Epoch 73/400
# Epoch 74/400
# Epoch 75/400
# Epoch 76/400
# Epoch 77/400
# Epoch 78/400
# Epoch 79/400
# Epoch 80/400
# Epoch 81/400
# Epoch 82/400
# Epoch 83/400
# Epoch 84/400
# Epoch 85/400
# Epoch 86/400
# Epoch 87/400
# Epoch 88/400
# Epoch 89/400
# Epoch 90/400
# Epoch 91/400
# Epoch 92/400
# Epoch 93/400
# Epoch 94/400
# Epoch 95/400
# Epoch 96/400
# Epoch 97/400
# Epoch 98/400
# Epoch 99/400
# Epoch 100/400
# Epoch 101/400
# Epoch 102/400
# Epoch 103/400
# Epoch 104/400
# Epoch 105/400
# Epoch 106/400
# Epoch 107/400
# Epoch 108/400
# Epoch 109/400
# Epoch 110/400
# Epoch 111/400
# Epoch 112/400
# Epoch 113/400
# Epoch 114/400
# Epoch 115/400
# Epoch 116/400
# Epoch 117/400
# Epoch 118/400
# Epoch 119/400
# Epoch 120/400
# Epoch 121/400
# Epoch 122/400
# Epoch 123/400
# Epoch 124/400
# Epoch 125/400
# Epoch 126/400
# Epoch 127/400
# Epoch 128/400
# Epoch 129/400
# Epoch 130/400
# Epoch 131/400
# Epoch 132/400
# Epoch 133/400
# Epoch 134/400
# Epoch 135/400
# Epoch 136/400
# Epoch 137/400
# Epoch 138/400
# Epoch 139/400
# Epoch 140/400
# Epoch 141/400
# Epoch 142/400
# Epoch 143/400
# Epoch 144/400
# Epoch 145/400
# Epoch 146/400
# Epoch 147/400
# Epoch 148/400
# Epoch 149/400
# Epoch 150/400
# Epoch 151/400
# Epoch 152/400
# Epoch 153/400
# Epoch 154/400
# Epoch 155/400
# Epoch 156/400
# Epoch 157/400
# Epoch 158/400
# Epoch 159/400
# Epoch 160/400
# Epoch 161/400
# Epoch 162/400
# Epoch 163/400
# Epoch 164/400
# Epoch 165/400
# Epoch 166/400
# Epoch 167/400
# Epoch 168/400
# Epoch 169/400
# Epoch 170/400
# Epoch 171/400
# Epoch 172/400
# Epoch 173/400
# Epoch 174/400
# Epoch 175/400
# Epoch 176/400
# Epoch 177/400
# Epoch 178/400
# Epoch 179/400
# Epoch 180/400
# Epoch 181/400
# Epoch 182/400
# Epoch 183/400
# Epoch 184/400
# Epoch 185/400
# Epoch 186/400
# Epoch 187/400
# Epoch 188/400
# Epoch 189/400
# Epoch 190/400
# Epoch 191/400
# Epoch 192/400
# Epoch 193/400
# Epoch 194/400
# Epoch 195/400
# Epoch 196/400
# Epoch 197/400
# Epoch 198/400
# Epoch 199/400
# Epoch 200/400
# Epoch 201/400
# Epoch 202/400
# Epoch 203/400
# Epoch 204/400
# Epoch 205/400
# Epoch 206/400
# Epoch 207/400
# Epoch 208/400
# Epoch 209/400
# Epoch 210/400
# Epoch 211/400
# Epoch 212/400
# Epoch 213/400
# Epoch 214/400
# Epoch 215/400
# Epoch 216/400
# Epoch 217/400
# Epoch 218/400
# Epoch 219/400
# Epoch 220/400
# Epoch 221/400
# Epoch 222/400
# Epoch 223/400
# Epoch 224/400
# Epoch 225/400
# Epoch 226/400
# Epoch 227/400
# Epoch 228/400
# Epoch 229/400
# Epoch 230/400
# Epoch 231/400
# Epoch 232/400
# Epoch 233/400
# Epoch 234/400
# Epoch 235/400
# Epoch 236/400
# Epoch 237/400
# Epoch 238/400
# Epoch 239/400
# Epoch 240/400
# Epoch 241/400
# Epoch 242/400
# Epoch 243/400
# Epoch 244/400
# Epoch 245/400
# Epoch 246/400
# Epoch 247/400
# Epoch 248/400
# Epoch 249/400
# Epoch 250/400
# Epoch 251/400
# Epoch 252/400
# Epoch 253/400
# Epoch 254/400
# Epoch 255/400
# Epoch 256/400
# Epoch 257/400
# Epoch 258/400
# Epoch 259/400
# Epoch 260/400
# Epoch 261/400
# Epoch 262/400
# Epoch 263/400
# Epoch 264/400
# Epoch 265/400
# Epoch 266/400
# Epoch 267/400
# Epoch 268/400
# Epoch 269/400
# Epoch 270/400
# Epoch 271/400
# Epoch 272/400
# Epoch 273/400
# Epoch 274/400
# Epoch 275/400
# Epoch 276/400
# Epoch 277/400
# Epoch 278/400
# Epoch 279/400
# Epoch 280/400
# Epoch 281/400
# Epoch 282/400
# Epoch 283/400
# Epoch 284/400
# Epoch 285/400
# Epoch 286/400
# Epoch 287/400
# Epoch 288/400
# Epoch 289/400
# Epoch 290/400
# Epoch 291/400
# Epoch 292/400
# Epoch 293/400
# Epoch 294/400
# Epoch 295/400
# Epoch 296/400
# Epoch 297/400
# Epoch 298/400
# Epoch 299/400
# Epoch 300/400
# Epoch 301/400
# Epoch 302/400
# Epoch 303/400
# Epoch 304/400
# Epoch 305/400
# Epoch 306/400
# Epoch 307/400
# Epoch 308/400
# Epoch 309/400
# Epoch 310/400
# Epoch 311/400
# Epoch 312/400
# Epoch 313/400
# Epoch 314/400
# Epoch 315/400
# Epoch 316/400
# Epoch 317/400
# Epoch 318/400
# Epoch 319/400
# Epoch 320/400
# Epoch 321/400
# Epoch 322/400
# Epoch 323/400
# Epoch 324/400
# Epoch 325/400
# Epoch 326/400
# Epoch 327/400
# Epoch 328/400
# Epoch 329/400
# Epoch 330/400
# Epoch 331/400
# Epoch 332/400
# Epoch 333/400
# Epoch 334/400
# Epoch 335/400
# Epoch 336/400
# Epoch 337/400
# Epoch 338/400
# Epoch 339/400
# Epoch 340/400
# Epoch 341/400
# Epoch 342/400
# Epoch 343/400
# Epoch 344/400
# Epoch 345/400
# Epoch 346/400
# Epoch 347/400
# Epoch 348/400
# Epoch 349/400
# Epoch 350/400
# Epoch 351/400
# Epoch 352/400
# Epoch 353/400
# Epoch 354/400
# Epoch 355/400
# Epoch 356/400
# Epoch 357/400
# Epoch 358/400
# Epoch 359/400
# Epoch 360/400
# Epoch 361/400
# Epoch 362/400
# Epoch 363/400
# Epoch 364/400
# Epoch 365/400
# Epoch 366/400
# Epoch 367/400
# Epoch 368/400
# Epoch 369/400
# Epoch 370/400
# Epoch 371/400
# Epoch 372/400
# Epoch 373/400
# Epoch 374/400
# Epoch 375/400
# Epoch 376/400
# Epoch 377/400
# Epoch 378/400
# Epoch 379/400
# Epoch 380/400
# Epoch 381/400
# Epoch 382/400
# Epoch 383/400
# Epoch 384/400
# Epoch 385/400
# Epoch 386/400
# Epoch 387/400
# Epoch 388/400
# Epoch 389/400
# Epoch 390/400
# Epoch 391/400
# Epoch 392/400
# Epoch 393/400
# Epoch 394/400
# Epoch 395/400
# Epoch 396/400
# Epoch 397/400
# Epoch 398/400
# Epoch 399/400
# Epoch 400/400
# Loss: 1.3681771755218506
# Accuracy: 0.581250011920929

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(256, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.7))

    generator_model.add(LSTM(256, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.7))

    generator_model.add(LSTM(256, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.7))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 84
seq_length = 1000

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# %%
evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '6/4': 0.0009652509652509653, '5/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'4/4': 0.5230769230769231, '6/8': 0.16923076923076924, '4/8': 0.09230769230769231, '6/4': 0.046153846153846156, '1/4': 0.03076923076923077, '1/8': 0.03076923076923077, '//8': 0.015384615384615385, '7/8': 0.015384615384615385, '4/2': 0.015384615384615385, '3/4': 0.015384615384615385, '6/2': 0.015384615384615385, '2/8': 0.015384615384615385, '3/8': 0.015384615384615385}
#
# Unique 'M' values to generated dataset: ['4/8', '1/4', '1/8', '//8', '7/8', '4/2', '6/2', '2/8', '3/8']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'Cm': 0.0009652509652509653, 'E': 0.0009652509652509653, 'B': 0.0009652509652509653}
# Generated Dataset Distribution
# {'D': 0.35294117647058826, 'G': 0.21176470588235294, 'A': 0.18823529411764706, 'E': 0.09411764705882353, 'B': 0.023529411764705882, 'A"DD "A7"dD A2|"A7"EB d2|"A"/2D2/2^B/2 c2|"C"Gd/2d/2 B/2A/2A|"D"A3/2B/2 d/2G/2d/2d/2|\\': 0.011764705882352941, 'B7': 0.011764705882352941, 'Am': 0.011764705882352941, 'Db': 0.011764705882352941, 'Em': 0.011764705882352941, 'Ea': 0.011764705882352941, 'e7': 0.011764705882352941, 'AAA|[:E': 0.011764705882352941, 'Bm': 0.011764705882352941, 'A7': 0.011764705882352941, 'A/': 0.011764705882352941}
#
# Unique 'K' values to generated dataset: ['A"DD "A7"dD A2|"A7"EB d2|"A"/2D2/2^B/2 c2|"C"Gd/2d/2 B/2A/2A|"D"A3/2B/2 d/2G/2d/2d/2|\\', 'B7', 'Db', 'Ea', 'e7', 'AAA|[:E', 'A7', 'A/']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 439.29
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 42.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.30982130207404246
# -------------------------------------------------------------------------------------

# %%
# This?

# %%
seed_index = 84
seq_length = 1000

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '6/4': 0.0009652509652509653, '5/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'4/4': 0.5074626865671642, '6/8': 0.14925373134328357, '6/4': 0.11940298507462686, '4/8': 0.08955223880597014, '1/4': 0.05970149253731343, '3/8': 0.029850746268656716, '7/4': 0.014925373134328358, 's/4': 0.014925373134328358, ':1/8': 0.014925373134328358}
#
# Unique 'M' values to generated dataset: ['4/8', '1/4', '3/8', '7/4', 's/4', ':1/8']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'Cm': 0.0009652509652509653, 'E': 0.0009652509652509653, 'B': 0.0009652509652509653}
# Generated Dataset Distribution
# {'D': 0.3563218390804598, 'G': 0.25287356321839083, 'A': 0.1839080459770115, 'Em': 0.04597701149425287, 'E': 0.04597701149425287, 'B': 0.034482758620689655, 'C': 0.022988505747126436, 'R': 0.011494252873563218, 'd': 0.011494252873563218, 'C7': 0.011494252873563218, 'g': 0.011494252873563218, 'F': 0.011494252873563218}
#
# Unique 'K' values to generated dataset: ['R', 'd', 'C7', 'g']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 435.44
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 36.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.31368590471530433
# -------------------------------------------------------------------------------------

# %%
# Or this?

# %%
# We reduce the error rate,but end up with and increased simialrity score. 1000 samples might just not be enough data

# %%
# Re run this

# %% [markdown]
# ## Lil more complexity to fix error rate

# %% [markdown]
# ## GRU

# %%
model_weights_directory = 'drive/MyDrive/Data/Model_Weights/Model_1/Dropout0.7_BatchSize16_GRU/'
generated_samples_directory = 'drive/MyDrive/Data/Generated_Samples/Model_1/Dropout0.7_BatchSize16_GRU/'

batch_size = 16
seq_length = 50
num_epochs = 200


lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
 initial_learning_rate = 0.003, decay_steps = 20, decay_rate = 0.97, 
  staircase=False)

optimizer_ = tf.keras.optimizers.RMSprop(lr_schedule)


model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(GRU(512, return_sequences = True, stateful = True))
model.add(Dropout(0.7))

model.add(GRU(512, return_sequences = True, stateful = True))
model.add(Dropout(0.7))

model.add(GRU(512, return_sequences = True, stateful = True))
model.add(Dropout(0.7))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))


model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_603"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_603 (Embedding)    (16, 50, 512)             47616
# _________________________________________________________________
# gru (GRU)                    (16, 50, 512)             1575936
# _________________________________________________________________
# dropout_1809 (Dropout)       (16, 50, 512)             0
# _________________________________________________________________
# gru_1 (GRU)                  (16, 50, 512)             1575936
# _________________________________________________________________
# dropout_1810 (Dropout)       (16, 50, 512)             0
# _________________________________________________________________
# gru_2 (GRU)                  (16, 50, 512)             1575936
# _________________________________________________________________
# dropout_1811 (Dropout)       (16, 50, 512)             0
# _________________________________________________________________
# time_distributed_3 (TimeDist (16, 50, 93)              47709
# _________________________________________________________________
# activation_603 (Activation)  (16, 50, 93)              0
# =================================================================
# Total params: 4,823,133
# Trainable params: 4,823,133
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)
    
print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 1.2993884086608887
# Accuracy: 0.606249988079071

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(GRU(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.7))

    generator_model.add(GRU(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.7))

    generator_model.add(GRU(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.7))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 12
seq_length = 1000

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# %%
evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '6/4': 0.0009652509652509653, '5/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'4/4': 0.6666666666666666, '6/8': 0.25, '6/4': 0.041666666666666664, '4/8': 0.020833333333333332, '3/4': 0.020833333333333332}
#
# Unique 'M' values to generated dataset: ['4/8']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'E': 0.0009652509652509653, 'Cm': 0.0009652509652509653, 'B': 0.0009652509652509653}
# Generated Dataset Distribution
# {'D': 0.3793103448275862, 'G': 0.3448275862068966, 'A': 0.08620689655172414, 'Bm': 0.034482758620689655, 'Em': 0.017241379310344827, 'GG': 0.017241379310344827, 'G"G': 0.017241379310344827, 'd': 0.017241379310344827, 'D"G': 0.017241379310344827, 'B7': 0.017241379310344827, 'Am': 0.017241379310344827, 'Amel': 0.017241379310344827, 'C': 0.017241379310344827}
#
# Unique 'K' values to generated dataset: ['GG', 'G"G', 'd', 'D"G', 'B7', 'Amel']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 452.87
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 55.00000000000001%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.3250937227234328
# -------------------------------------------------------------------------------------
