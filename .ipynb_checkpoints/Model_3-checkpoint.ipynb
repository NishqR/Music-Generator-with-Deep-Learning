# %%
# !pip install tfa-nightly
# !pip install pygame
# Out:
# Collecting tfa-nightly
#   Downloading tfa_nightly-0.15.0.dev20211014164307-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 8.2 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tfa-nightly) (2.7.1)
# Installing collected packages: tfa-nightly
# Successfully installed tfa-nightly-0.15.0.dev20211014164307
# Collecting pygame
#   Downloading pygame-2.0.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (13.8 MB)
#      |████████████████████████████████| 13.8 MB 7.9 MB/s
# Installing collected packages: pygame
# Successfully installed pygame-2.0.2

# %%
import os

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from difflib import SequenceMatcher

import random
import json
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
import tensorflow.keras as keras
from keras.regularizers import l2, L1
import tensorflow_addons as tfa
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, TimeDistributed, Dense, Activation, Embedding, GRU
from sklearn.model_selection import train_test_split

import pygame
from IPython.display import Image, display

gpus = tf.config.experimental.list_physical_devices('GPU') 
for gpu in gpus: 
  tf.config.experimental.set_memory_growth(gpu, True)

print("Tensorflow version is: ", tf.__version__)
assert tf.__version__[0] == '2'

# %load_ext tensorboard

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.8)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Tensorflow version is:  2.6.0
# Tue Oct 19 22:04:55 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 471.41       Driver Version: 471.41       CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:02:00.0 Off |                  N/A |
# | N/A   25C    P8     3W /  N/A |    685MiB /  6144MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1080      C   ...ishq\anaconda3\python.exe    N/A      |
# |    0   N/A  N/A     17484      C   ...ishq\anaconda3\python.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Data Processing Functions

# %%
def convert_to_df(lines):
    all_rows = []
    index = 0
    num_tunes = 0

    # For each line in the file, 
    for line in lines:

        # To ensure we skip the newlines 
        if len(line) > 1:

            print(line)

            # If the line has an X (index value)
            if line[0] == 'X':

                # If this not the first line 
                if index != 0: 

                    # Add everything in dict_line to the all_rows list
                    all_rows.append(dict_line)
                    print("**** Added info: Added dict_line to all rows ****")
                    print()

                # Create an empty dict 
                dict_line = {}
                dict_line['transcription'] = ''

                index += 1
                num_tunes += 1

                print("**** Added info: Dictionary reinitialized ****")
                print()

                continue

            # else if the line has an M, 
            elif line[0] == 'M':

                # Save everything after the colon to dict_line with key 'M'
                dict_line['M'] = line[2:].strip()
                print("**** Added info: Dictionary added M = " + dict_line['M'] + " ****")
                print()
                continue

            # else if the line has a K, 
            elif line[0] == 'K':

                # Save everything after the colon to dict_line with key 'K'
                dict_line['K'] = line[2:].strip()
                print("**** Added info: Dictionary added K = " + dict_line['K'] + " ****")
                print()

            # else if the conditions for it being the transcription are true, 
            elif (line[0] == "|" or line[1] != ":") and (line[0] != "%") and (line != ''):

                # Add that to the dict_line with key 'transcription'
                dict_line['transcription'] += line.strip()
                print("**** Added info : Dictionary added transcription ****")
                print()        


    df = pd.DataFrame(all_rows)
    return df



# Version of previous function that takes in just one generated sample and returns a dictionaty in the 
# dict_line format from the previous function
def convert_sample_to_dict(generated_sample):
    
    dict_line = {}
    dict_line['transcription'] = ''
    
    # For each line in the generated sample, 
    for line in generated_sample.splitlines():
        
        # To ensure we skip the newlines 
        if len(line) > 1:
            
            # if the line has an M,
            if line[0] == "M":    
                
                # Save everything after the colon to dict_line with key 'M'
                dict_line['M'] = line[2:].strip()
                continue
            
            # else if the line has a K,
            elif line[0] == 'K':
                
                # Save everything after the colon to dict_line with key 'K'
                dict_line['K'] = line[2:].strip()
                continue
            
            # else if the conditions for it being the transcription are true, 
            elif (line[0] == "|" or line[1] != ":") and (line[0] != "%") and (line != ''):
                
                # Add that to the dict_line with key 'transcription'
                dict_line['transcription'] += line.strip()
                
    
    return dict_line


# Function that gives each character an index number and returns a dictionary (as well as a reversed dictionary)
def give_characters_indexes(data):

    char_index_dict = {}
    index_char_dict = {}
    for (i, char) in enumerate(sorted(list(set(data)))):
        char_index_dict[char] = i
        index_char_dict[i] = char

    with open(data_directory + char_index_json, mode = "w") as f:
        json.dump(char_index_dict, f)

    return char_index_dict, index_char_dict

# %% [markdown]
# # Sequence Generator Functions

# %%
# Function taken and modified from here - https://medium.datadriveninvestor.com/music-generation-using-deep-learning-85010fb982e2 
def generate_sequence(epoch_num, initial_index, seq_length):
    
    char_index_dict, index_char_dict = give_characters_indexes(data)
    num_unique_chars = len(index_char_dict)

    generator_model = make_model(num_unique_chars)
    weights_dir = model_weights_directory + "Weights_{}.h5".format(num_epochs)
    generator_model.load_weights(weights_dir)

    sequence_index = [initial_index]
    
    for _ in range(seq_length):
        batch = np.zeros((1, 1))
        batch[0, 0] = sequence_index[-1]
        
        predicted_probs = generator_model.predict_on_batch(batch).ravel()
        sample = np.random.choice(range(num_unique_chars), size = 1, p = predicted_probs)
        sequence_index.append(sample[0])
    
    seq = ''.join(index_char_dict[c] for c in sequence_index)
    
    #print(f"SEQ: {seq}"
    
    if seq == '':
        return ''

    cnt = 0
    if len(seq) > 1:
        
        for j in seq:
            cnt += 1
            if j == "\n":
                break
        seq1 = seq[cnt:]
    else:
        return ''
    #print(f"SEQ1: {seq1}")
    #above code is for ignoring the starting string of a generated sequence. This is because we are passing any arbitrary 
    #character to the model for generating music. Now, the model start generating sequence from that character itself which we 
    #have passed, so first few characters before "\n" contains meaningless word. Model start generating the music rhythm from
    #next line onwards. The correct sequence it start generating from next line onwards which we are considering.
    
    if seq1 == '':
        return ''

    cnt = 0

    if len(seq1) > 1:
        for j in seq1:
            cnt += 1
            if j == "\n":
                if len(seq1) > cnt:
                    if seq1[cnt] == "\n":
                        break
        seq2 = seq1[:cnt]
    else:
        return ''
    #print(f"SEQ2: {seq2}")
    #Now our data contains three newline characters after every tune. So, the model has leart that too. So, above code is used for
    #ignoring all the characters that model has generated after three new line characters. So, here we are considering only one
    #tune of music at a time and finally we are returning it..
    
    return seq2

# %% [markdown]
# # Evaluation Functions

# %%
# Function that takes care of the 'Distribution Similarity' pillar
def compare_distributions(music_df, generated_df, metric):
    
    # Get the value counts of both the datasets
    generated_df_val_counts = dict(generated_df[metric].value_counts(normalize=True, ascending=False))
    music_df_val_counts = dict(music_df[metric].value_counts(normalize=True, ascending=False))
    
    print()
    print("Original Dataset Distribution")
    print(music_df_val_counts)
    print("Generated Dataset Distribution")
    print(generated_df_val_counts)
    
    # Add the missing keys from each dataset to the otehr
    for key in music_df_val_counts.keys():
        if key not in generated_df_val_counts.keys():
            generated_df_val_counts[key] = 0

    unique_keys = []
    for key in generated_df_val_counts.keys():
        if key not in music_df_val_counts.keys():
            unique_keys.append(key)
            music_df_val_counts[key] = 0

    print()
    print(f"Unique '{metric}' values to generated dataset: {unique_keys}")
    print()

    # Plot the figure for both distributions
    plt.figure(figsize=(15,7))
    plt.grid(True)
    
    # Number of bars we want for the figure
    num_bars = np.arange(len(music_df_val_counts))           
    width = 0.3
    
    plt.bar(num_bars, music_df_val_counts.values() , width, label='Original Dataset')
    plt.bar(num_bars + width, generated_df_val_counts.values(), width, label='Generated Dataset')
    plt.xticks(num_bars + width / 2, music_df_val_counts.keys())
    plt.legend(loc='best')
    plt.show()

    
    
# Function that takes care of the 'Error Rate' pillar
def determine_error_rate(generated_df):

    num_errors = 0
    for i in range(len(generated_df)):
        
        # If the transcription is empty
        if (generated_df.iloc[i]['transcription'] == ''):
            num_errors += 1
        
        # Else if the transcription is null
        elif (pd.isnull(generated_df.iloc[i]['transcription'])):
            num_errors += 1
        
        # Else if the 'K' value is null
        elif pd.isnull(generated_df.iloc[i]['K']):
            num_errors += 1
        
        # Else if the 'K' value has any characters other than letters
        elif not (all(i.isalpha() for i in generated_df.iloc[i]['K'])):
            num_errors += 1
        
        # Else if the 'M' valye is null
        elif pd.isnull(generated_df.iloc[i]['M']):
            num_errors += 1
        
        # Else if the 'M' value has any letters
        elif (any(i.isalpha() for i in generated_df.iloc[i]['M'])):
            num_errors += 1
        
    error_rate = (num_errors / len(generated_df)) * 100
        
    return error_rate

# Function that takes care of the "Average Maximum Similarity Score" pillar
def get_average_similarity_score(music_df, generated_df):
    
    total_similarity_score = 0
    
    # For each generated sample
    for i in range(len(generated_df)):
        
        # Get the transcription value from the dataframe
        generated_sample = generated_df.iloc[i]["transcription"]
        max_similarity_score = 0
        
        # For each training sample
        for j in range(len(music_df)):
            
            # Get the transcription value from the dataframe
            original_sample = music_df.iloc[j]["transcription"]
            
            # Calculate the similarity score
            similarity_score = SequenceMatcher(None, generated_sample, original_sample).ratio()
            
            # If this is the most similar transcription, save to max
            if similarity_score > max_similarity_score:
                max_similarity_score = similarity_score
        
        total_similarity_score += max_similarity_score
    
    # Return the average of all the max scores
    avg_similarity_score = total_similarity_score / len(generated_df)
    return avg_similarity_score

# Average Length comparison function
def get_length_comparison(music_df, generated_df):

    return music_df['transcription'].apply(len).mean(), generated_df['transcription'].apply(len).mean()


# Function that brings it all together and prints out the different performance metrics
def evaluate_performance(music_df, generated_df):
    print("-------------------------------------------------------------------------------------")
    print("Distribution Comparison - Meter / Time Signature")
    compare_distributions(music_df, generated_df, 'M')
    print("-------------------------------------------------------------------------------------")
    print()
    
    print("-------------------------------------------------------------------------------------")
    print("Distribution Comparison - Key")
    compare_distributions(music_df, generated_df, 'K')
    print("-------------------------------------------------------------------------------------")
    print()
    
    print("-------------------------------------------------------------------------------------")
    print("Average Length Comparison")
    original_length, generated_length = get_length_comparison(music_df, generated_df)
    print(f"Original Average Transcription Length - {original_length}")
    print(f"Generated Average Transcription Length - {generated_length}")
    print("-------------------------------------------------------------------------------------")
    print()

    print("-------------------------------------------------------------------------------------")
    print(f"Error Rate - {determine_error_rate(generated_df)}%")
    print("-------------------------------------------------------------------------------------")
    print()
    
    print("-------------------------------------------------------------------------------------")
    print(f"Average Max Similarity Score - {get_average_similarity_score(music_df, generated_df)}")
    print("-------------------------------------------------------------------------------------")
    print()

# %% [markdown]
# # Function for playing samples

# %% [markdown]
# The following code to play the samples in the notebook was taken from here - https://www.daniweb.com/programming/software-development/code/216976/play-a-midi-music-file-using-pygame

# %%
freq = 44100    # audio CD quality
bitsize = -16   # unsigned 16 bit
channels = 2    # 1 is mono, 2 is stereo
buffer = 1024    # number of samples
pygame.mixer.init(freq, bitsize, channels, buffer)

# optional volume 0 to 1.0
pygame.mixer.music.set_volume(1)

def play_music(music_file):
    """
    stream music with mixer.music module in blocking manner
    this will stream the sound from disk while playing
    """
    clock = pygame.time.Clock()
    try:
        pygame.mixer.music.load(music_file)
        #print("Music file %s loaded!" % music_file)
    except pygame.error:
        print("File %s not found! (%s)" % (music_file, pygame.get_error()))
        return
    pygame.mixer.music.play()
    while pygame.mixer.music.get_busy():
        # check if playback has finished
        clock.tick(30)

# %%
data_directory = "Data/"
data_file = "Data_Tunes.txt"
char_index_json = "char_to_index.json"

file_ = open(data_directory+data_file, 'r')
data_lines = file_.readlines()
music_df = convert_to_df(data_lines)

file_ = open(os.path.join(data_directory, data_file), mode = 'r')
data = file_.read()

char_index_dict, index_char_dict = give_characters_indexes(data)
num_unique_chars = len(char_index_dict)
all_characters = np.asarray([char_index_dict[c] for c in data], dtype = np.int32)
# Out:
# X: 1
#
# **** Added info: Dictionary reinitialized ****
#
# T:A and D
#
# % Nottingham Music Database
#
# S:EF
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# K:A
#
# **** Added info: Dictionary added K = A ****
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# P:A
#
# f|"A"ecc c2f|"A"ecc c2f|"A"ecc c2f|"Bm"BcB "E7"B2f|
#
# **** Added info : Dictionary added transcription ****
#
# "A"ecc c2f|"A"ecc c2c/2d/2|"D"efe "E7"dcB| [1"A"Ace a2:|
#
# **** Added info : Dictionary added transcription ****
#
#  [2"A"Ace ag=g||\
#
# **** Added info : Dictionary added transcription ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# P:B
#
# "D"f2f Fdd|"D"AFA f2e/2f/2|"G"g2g ecd|"Em"efd "A7"cBA|
#
# **** Added info : Dictionary added transcription ****
#
# "D"f^ef dcd|"D"AFA f=ef|"G"gfg "A7"ABc |1"D"d3 d2e:|2"D"d3 d2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 2
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Abacus
#
# % Nottingham Music Database
#
# S:By Hugh Barwell, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# "G"g2g B^AB|d2d G3|"Em"GAB "Am"A2A|"D7"ABc "G"BAG|
#
# **** Added info : Dictionary added transcription ****
#
# "G"g2g B^AB|d2d G2G|"Em"GAB "Am"A2G|"D7"FGA "G"G3::
#
# **** Added info : Dictionary added transcription ****
#
# "D7"A^GA DFA|"G"B^AB G3|"A7"^c=c^c Ace|"D7"fef def|
#
# **** Added info : Dictionary added transcription ****
#
# "G"g2g de=f|"E7"e2e Bcd|"Am"c2c "D7"Adc| [1"G"B2A G3:|
#
# **** Added info : Dictionary added transcription ****
#
#  [2"G"B2A G2F||"Em"E2E G2G|B2B e2e|"Am"c2A "B7"FBA|"Em"G2F E3|"Em"EFG "Am"ABc|
#
# **** Added info : Dictionary added transcription ****
#
# "B7"B^c^d "Em"e2e|"F#7"f2f f2e|"B7"^def BAF|"Em"E2E G2G|B2B e2e|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"c2A "B7"FBA|"Em"G2F E3|"Em"EFG "Am"ABc|"B7"B^c^d "Em"e2e|
#
# **** Added info : Dictionary added transcription ****
#
# "F#7"f2e "B7"^def |[1"Em"e3 "D7"d3:|[2"Em"e3 "E7"e3||
#
# **** Added info : Dictionary added transcription ****
#
# X: 3
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:The American Dwarf
#
# % Nottingham Music Database
#
# S:FTB, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# P:A
#
# A|"D" def fed|"G" BdB AFD| "D"DFA "G"B2 A|"Em" cee "A7" e2 A|
#
# **** Added info : Dictionary added transcription ****
#
# "D" def fed|"G" BdB "D"AFD|"D" DFA "G"B2 A|"A7" Add "D" d2:|
#
# **** Added info : Dictionary added transcription ****
#
# "B"e|"D"fga agf|"G" gab "A7"bag|"D"fga "D"agf|"Em" gfg "A7"e2 g|
#
# **** Added info : Dictionary added transcription ****
#
# "D"fga agf|"G"gab "A7"bag|"D" fga "A7"efg|"D" fdd d2 :|
#
# **** Added info : Dictionary added transcription ****
#
# X: 4
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Ap Shenkin
#
# % Nottingham Music Database
#
# P:AABABA
#
# S:FTB 1 p 46, via EF
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# |d/2c/2\
#
# **** Added info : Dictionary added transcription ****
#
# P:A
#
# !segno! "G"B2B Bgf|"C"e2e efg|"G"ded "Em"dcB|"Am"cAA "D7"Adc|
#
# **** Added info : Dictionary added transcription ****
#
# "G"BcB Bgf|"C"efe efg|"G"ded "D7"cBA|"G"G2B G3|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# |g/2a/2|"G"b2g "D"a2f|"G"gfg "G"dcB|"C"cde "G"dgB|"Am"BAA "D7"A2g/2a/2|
#
# **** Added info : Dictionary added transcription ****
#
# "G"b2g "D"a2f|"Em"gfe "D7"agf|"G"bag "A7"fge|"D7"dgf ed\
#
# **** Added info : Dictionary added transcription ****
#
# P:D.S.
#
# c|
#
# **** Added info : Dictionary added transcription ****
#
# X: 5
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Armstrongs
#
# % Nottingham Music Database
#
# S:Kevin Briggs, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:A
#
# **** Added info: Dictionary added K = A ****
#
# P:A
#
# e|"A"eaf e2c|"E7"BAB "A"c3|"A"E2A "E7/b"BAB|"A/c+"cBc "D"dcd|
#
# **** Added info : Dictionary added transcription ****
#
# "A"eaf e2c|"E7"BAB "A"c3|"E7"E2E EFG|"A"A3 A2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# e|"A"ecA Acd|"A"ecA "E7"B2A|"A"ecA cAc|"Bm"B2B "E7"dcd|
#
# **** Added info : Dictionary added transcription ****
#
# "A"ecA Acd|"A"ecA Acd|"E7"e2e efg|"A"aec A2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 6
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Arthur Darley
#
# % Nottingham Music Database
#
# S:Formally, but with lift, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# dc/2B/2|\
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# A2D AGF|EDC D3|\
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# d2e fgf|edc d2A|
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# d2e fgf|\
#
# **** Added info : Dictionary added transcription ****
#
# M:9/8
#
# **** Added info: Dictionary added M = 9/8 ****
#
# edc d2A BAG|\
#
# **** Added info : Dictionary added transcription ****
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# FED EDC|DA,B, CDE|
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# Ddd \
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# Aee|\
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# Aff \
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# Agg|fed edc|d3 dcB||
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# !segno! A2D AGF|EDC D3|d2e fgf|edc d2A|d2e fgf|
#
# **** Added info : Dictionary added transcription ****
#
# M:9/8
#
# **** Added info: Dictionary added M = 9/8 ****
#
# edc d2A BAG|\
#
# **** Added info : Dictionary added transcription ****
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# FED EDC|DA,B, CDE|
#
# **** Added info : Dictionary added transcription ****
#
# Ddd Aee|Aff Agg|fed edc|d3 d=c_B
#
# **** Added info : Dictionary added transcription ****
#
# |:\
#
# **** Added info : Dictionary added transcription ****
#
# K:F
#
# **** Added info: Dictionary added K = F ****
#
# A2f fef|A2f fef|\
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# Aff
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# Agg|\
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# Aaa \
#
# **** Added info : Dictionary added transcription ****
#
# P:\>
#
# Abb|A2f fef
#
# **** Added info : Dictionary added transcription ****
#
# |A2f f2g|fed ed^c|1d3 dcB:|2d3 d2e||
#
# **** Added info : Dictionary added transcription ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# fgf edc|d2A BAG|\
#
# **** Added info : Dictionary added transcription ****
#
# FED EDC|DA,B, CDE|
#
# **** Added info : Dictionary added transcription ****
#
# Ddd Aee|Aff Agg|fed edc|\
#
# **** Added info : Dictionary added transcription ****
#
# P:Fine.
#
# d3 dc\
#
# **** Added info : Dictionary added transcription ****
#
# P:D.S.
#
# B||
#
# **** Added info : Dictionary added transcription ****
#
# X: 7
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:As Luck Will Have It
#
# % Nottingham Music Database
#
# S:John Lagden, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# E|"D"F3 "A7/c+"A2G|"Bm"FGF "A7"E3|"D"F2A d2c|"G"BcB "D"A3|"G"G2B "A7"A2G|\
#
# **** Added info : Dictionary added transcription ****
#
# "D"F2A d2f|
#
# **** Added info : Dictionary added transcription ****
#
# "G"efe "E7"dcB|"A7"ABA GFE|"D"F3 "A7/c+"A2G|"Bm"FGF "A7"E3|"D"F2A d2c|
#
# **** Added info : Dictionary added transcription ****
#
# "G"BcB "D"A3|"G"G2B "A7"A2G|"D"F2E "Bm"D2F|"Em"EFG "A7"F2E|"D"D3 -D2||
#
# **** Added info : Dictionary added transcription ****
#
# A|"D"d3 fed|"A"c2d e2A|"Bm"Bcd c2B|"F#m"A3 A2A|"G"B3 dcB|
#
# **** Added info : Dictionary added transcription ****
#
# "D"A2d f2a|"G"agf "E7"fed|"A7"e3 e2A|"D"d3 fed|"A"c2B A2A|
#
# **** Added info : Dictionary added transcription ****
#
# "Bm"B3 dcB|"F#m"A3 A2F|"G"G3 BAG|"D"F2A d2D|"Em"EFG "A7"F2E|"D"D3 -D2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 8
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Atholl Highlanders
#
# % Nottingham Music Database
#
# P:AABBCCDD
#
# S:Kevin Briggs, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:A
#
# **** Added info: Dictionary added K = A ****
#
# P:A
#
# |:c/2d/2|"A"e3 ecA|"A"ecA "E7"Bcd|"A"e3 ecA|"D"Bcd "E7"cBA|
#
# **** Added info : Dictionary added transcription ****
#
# "A"e3 ecA|"A"ecA "E7"Bcd|"A"e/2a3/2e "D"fed|"E7"cdB "A"A2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# |:e|"A"Ace Ace|"D"Adf Adf|"A"Ace Ace|"Bm"Bcd "E7"c2B|
#
# **** Added info : Dictionary added transcription ****
#
# "A"Ace Ace|"D"Adf Adf|"A"e/2a3/2e "D"fed|"E7"cdB "A"A2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:C
#
# |:e|"A"aee edc|"A"aee edc|"A"aee edc|"D"Bcd "E7"cBA|
#
# **** Added info : Dictionary added transcription ****
#
# "A"aee edc|"A"aee edc|"A"aee fed|"E7"cdB "A"A2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:D
#
# |:A/2B/2|"A"cAc cAc|"D"dBd dBd|"A"cAc cAc|"G"B=GB BGB|
#
# **** Added info : Dictionary added transcription ****
#
# "A"cAc cAc|"E7"dBd dBd|"A"e/2a3/2e "D"fed|"E7"cdB "A"A2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 9
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Aunt Mary's Canadian Jig
#
# % Nottingham Music Database
#
# S:Ms L Dolman, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# A|"D"f2f fga|d2d dcB|"D"ABA "B7"AGF|"Em"E2E E2A|
#
# **** Added info : Dictionary added transcription ****
#
# "A7"e2e efg|e2d c2B|ABA ABA|"D"F3 F2:|
#
# **** Added info : Dictionary added transcription ****
#
# A|"D"ABA fgf|e2d d2z|"D"AFA "B7"BcB|"Em"A2G G2z|
#
# **** Added info : Dictionary added transcription ****
#
# "A7"GFG efe|d2c c2B|ABA ABc|"D"d3 d2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 10
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Avon Jig
#
# % Nottingham Music Database
#
# S:Pauline Wilson, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Em
#
# **** Added info: Dictionary added K = Em ****
#
# B|"Em"e2e B2B|GAB E3|"D7"FED AGF|FED AGF|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"e2e B2B|"Em"GAB E3|"D7"FED A2A|"Em"GEE E2::
#
# **** Added info : Dictionary added transcription ****
#
# D|"G"G2G B2B|"D7"ABA D3|"G"G2G B2B|"Am"d2d "D7"cBA|"G"G2G B2B|"D7"ABA D3|\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"EFG "A7"FED|"Em"E3 -E2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 11
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Backstairs Jig
#
# % Nottingham Music Database
#
# S:EF
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# P:A
#
# d|"G"d2b baf|"G"a2g g2g|"D7"f2f fef|"G"a2g "D7"gfe|
#
# **** Added info : Dictionary added transcription ****
#
# "G"d2b baf|"G"a2g g2g|"D7"f2f fef|"G"a2g fg:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# d|"G"gfg bge|"D7"d2d def|"G"gfg bge|"A7"e2d "D7"def|
#
# **** Added info : Dictionary added transcription ****
#
# "G"g2g "G7"gab|"C"e2e "Am"efg|"D7"ded cBF|"G"GBd g2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 12
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:The Leaking Bagpipe
#
# % Nottingham Music Database
#
# S:The Cantii Collection, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# D3 |"Em"E3 B2A|B2G E2G|"D"F3 A2G|A2F DEF|"Em"E3 B2A|"Em"B2c d2e|"G"B2A "C"G2F|\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"E3 ::
#
# **** Added info : Dictionary added transcription ****
#
# G3 |"Am"A3 c2B|A2B c2A|"Em"E3 G2F|E2F G2E|"Am"A3 c2B|A2B c2d|"Em"e2f gfg|\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"e3 :|
#
# **** Added info : Dictionary added transcription ****
#
# X: 13
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Ballybunion
#
# % Nottingham Music Database
#
# S:Folk Camps, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# P:A
#
# B/2A/2|"G"G3 "C"g2e|"G/b"dBG "D7/a"AFD|"G"G3 "C"g2e|"G"dBG "D"A2B|
#
# **** Added info : Dictionary added transcription ****
#
# "G""Em"G3 g2e|"G"dBG GAB|"C"cde "G/b"dcB|"D7/a"cBA "G"G2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# B|"Em"eBe gbg|"Em"eBe gbg|"Em"eBe g2a|"Am"bag "B7"agf|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"eBe "Em/d+"gbg|"Em/d"eBe "Em/c+"g2a|"Am/c"bag "B7"agf|1"Em"e3 e2:|2\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"e3 "D7"d2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 14
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Barbary Bell
#
# % Nottingham Music Database
#
# S:Kevin Briggs, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# P:A
#
# d|"G"GAG GBc|"G"ded dBG|"C"ABc "G/b"BAG|"Am"EGE "D7"E2D|
#
# **** Added info : Dictionary added transcription ****
#
# "G"GAG GBc|"G"ded dBG|"C"ABc "G/b"BAG|"C"E2F "G"G2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# D|"D7"def "G"gag|"D"fed "Em"edB|"Bm"def "Em"gag|"Bm"fed "Em"e2d|
#
# **** Added info : Dictionary added transcription ****
#
# "D7"def "G"gdB|"C"cde "G"dBG|"C"ABc "G/b"BAG|"C"E2F "G"G2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 15
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:The Barley Mow
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# "G"G2G "D"A2A|"G"B2c dBG|"C"E2E c2B|"Am"ABG "D7"FED|"G"G2G "D"A2A|"G"B2c dBG|\
#
# **** Added info : Dictionary added transcription ****
#
# "C"EcB "D7"AGF|"G"G6:|
#
# **** Added info : Dictionary added transcription ****
#
# "G"d2d "C"e2e|"G"d2g dBG|"G"d2d "C"e2e|"G"dBG "D"A3|"G"d2d "C"e2e|"G"d2g g2f|\
#
# **** Added info : Dictionary added transcription ****
#
# "A7"egf ed^c|"D7"d3 D3||
#
# **** Added info : Dictionary added transcription ****
#
# "G"G2G "D"A2A|"G"B2c dBG|"C"E2E c2B|"Am"ABG "D7"FED|"G"G2G "D"A2A|"G"B2c dBG|\
#
# **** Added info : Dictionary added transcription ****
#
# "C"EcB "D7"AGF|"G"G6||
#
# **** Added info : Dictionary added transcription ****
#
# X: 16
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Bean Setting (North Skelton)
#
# % Nottingham Music Database
#
# S:EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# P:A
#
# G/2A/2|"G"BAG D2D|"C"EFG "D7"FED|"G"BAG D2D|"C"E2D "D7"G2A|"G"BAG D2D|
#
# **** Added info : Dictionary added transcription ****
#
# "C"EFG "D7"FED|"G"BAG D2D|"C"E2D "D7"G2A|"G"B2B "D"A2A|"Em"G2G "Bm"FED|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"G2B "D7"A2F|"G"G2B "G7"d3|"C"e2e "G"d2B|"D7"c2c "G"BAG|"G"GAB "C"c2B|\
#
# **** Added info : Dictionary added transcription ****
#
# "D7"AGF "G"G2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 17
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Belfast Almanac
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# D|"G"G2G "D7"FED|"C"E2F G2A|"G"B2G "D7"c2A|"G"B2G "D7"c2A|
#
# **** Added info : Dictionary added transcription ****
#
# "G"B3/2c/2d "Am"E2E|"A7"ABG "D7"FED|"C"EFG "D7"AFD|"G"G3 -G2::
#
# **** Added info : Dictionary added transcription ****
#
# c|"G"Bcd def|g2g g3|"G"B2B Bcd|"C"e2e e3|
#
# **** Added info : Dictionary added transcription ****
#
# "G"dcB "C"cde|"G"dBd D2D|"C"EFG "D7"AFD|"G"G3 -G2::
#
# **** Added info : Dictionary added transcription ****
#
# A|"G"B2G "D7"c2A|"G"B2G "D7"c2A|"G"Bcd "C"E2E|"A7"ABG "D7"FED|
#
# **** Added info : Dictionary added transcription ****
#
# "G"B2G "D7"c2A|"G"B2G Bcd|"C"EFG "D7"AFD|"G"G3 -G2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 18
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Bell's Favourite
#
# % Nottingham Music Database
#
# S:Don Messer's Way Down East Fiddlin' Tunes, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# A|"D"FEF "G"GFG|"D"BAF A2d|"A7"cde ABc|"D"dcB "A7"A2G|
#
# **** Added info : Dictionary added transcription ****
#
# "D"FEF "G"GFG|"D"BAF A2d|"A7"cde ABc|"D"d3 d2::
#
# **** Added info : Dictionary added transcription ****
#
# f|"D"aba fef|"Em"gfg e2d|"A7"cde ABc|"D"dcB "A7"A2f|
#
# **** Added info : Dictionary added transcription ****
#
# "D"aba fef|"Em"gfg e2d|"A7"cde ABc|"D"d3 d2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 19
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Squire of Bensham
#
# % Nottingham Music Database
#
# S:NPTB, via EF
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# K:C
#
# **** Added info: Dictionary added K = C ****
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# P:A
#
# c/2d/2|"C"edc "F"A2F|"C/e"G2c "G7/d"E2c|"C"edc g2c|"Dm"Bdd "G7"d2c/2d/2|
#
# **** Added info : Dictionary added transcription ****
#
# "C"edc "F"A2c|"C"G2c "Am"E2c|"Dm"def "G7"e2d|"C"edc c2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# |:c/2d/2|"C"ed"C/e"c g2c|"F"c'2a "G7"g2c|"C"edc g2c|"Dm"Adc "G7"BAG|
#
# **** Added info : Dictionary added transcription ****
#
# "C"ed"C/c"c g2c|"F"c'2a "G"ggf|"Am"abc' "G7/b"bd'b|[1"C"c'ge c2:|[2 "C" c'ge c3|
#
# **** Added info : Dictionary added transcription ****
#
# X: 20
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:The Bent Pin
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# "A7"A|"D"D2F A2d| "G7"^A2B "D"=AFD|\
#
# **** Added info : Dictionary added transcription ****
#
# "G7"^A2B "D"=AFD|"E7" =FDF "A7"EDB,|
#
# **** Added info : Dictionary added transcription ****
#
# "D"D2^F A2d|\
#
# **** Added info : Dictionary added transcription ****
#
# "G7"^A2B "D"=AFD|"E7"=FDF "A7"EDB,|"D"D3 -D2::
#
# **** Added info : Dictionary added transcription ****
#
# d|"G7"B2d e2=f| "D"^fdB A2d|"G7"B=Fd e2=f|"D"fdB A2d|
#
# **** Added info : Dictionary added transcription ****
#
# "G7"B=Fd e2=f\
#
# **** Added info : Dictionary added transcription ****
#
# | "D"=fdB "Bm"ABA|\
#
# **** Added info : Dictionary added transcription ****
#
# =FDF "A7"EDB,|"D"D3 -D2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 21
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Biddy The Bowl Wife
#
# % Nottingham Music Database
#
# S:FTB 2 34, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:A
#
# **** Added info: Dictionary added K = A ****
#
# P:A
#
# c|"A"EAc e2f|"A"ecA a2f|"A"ecA EAc|"D"dcd "E7"B2c|
#
# **** Added info : Dictionary added transcription ****
#
# "A"EAc e2f|"A"ecA a2f|"A"ecA EAc|"E7"B3 "A"A2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# e|"A"efe a2g|"D"bag fga|"A"ecA EAc|"E7"dcd B2e|
#
# **** Added info : Dictionary added transcription ****
#
# "A"efe a2g|"D"bag fga|"A"ecA EAc|"E7"B3 "A"A2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 22
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Bill Charlton's Fancy
#
# % Nottingham Music Database
#
# S:Billy Pigg, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# P:A
#
# (3d/2e/2f/2|"G"g2G f2G|e2G d3|"G"DGB dBG|"D"DFA c3|"D"aAc g2A|
#
# **** Added info : Dictionary added transcription ****
#
# "D"f2A e3|"D7"d^cd e2=c|"G"Bdg B2d|"G"gGB f2G|e2G d3|"G"DGB dBG|
#
# **** Added info : Dictionary added transcription ****
#
# "C"ecA E3|"C"ecG EGc|"G"gdB GBd|"D7"fed ^cdF|"G"GBd g2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# (3d/2e/2f/2|gGB fGB|eGB dGB|eGB dGB|cAF DFA|
#
# **** Added info : Dictionary added transcription ****
#
# aAc gAc|fAc eAc|d^cd ^de=c|Bdg B2d|
#
# **** Added info : Dictionary added transcription ****
#
# gGB fGB|eGB dGB|eGB dGB|"C"ecA E3|
#
# **** Added info : Dictionary added transcription ****
#
# "C"ecG EGc|"G"gdB GBd|"D7"fed ^cdF|"G"GBd g2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:C
#
# d|bGB aBG|gGB fGB|eGB dGB|cAF DFA|
#
# **** Added info : Dictionary added transcription ****
#
# aAc gAc|fAc eAc|d^cd ^de=c|Bdg B2d|
#
# **** Added info : Dictionary added transcription ****
#
# bGB aBG|gGB fGB|eGB dGB|"C"ecA E3|
#
# **** Added info : Dictionary added transcription ****
#
# "C"ecG EGc|"G"gdB GBd|"D7"fed ^cdF|"G"GBd g2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 23
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Blackberry Quadrille
#
# % Nottingham Music Database
#
# S:Kevin Briggs, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# P:A
#
# f/2g/2|"D"a2a ba^g|"D"a2f d2f|"A7"e2c A2g|"D"fdB "A7"A2f/2g/2|
#
# **** Added info : Dictionary added transcription ****
#
# "D"a2a ba^g|"D"a2f d2f|"A7"e2c ABc|"D"d3 d2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# c/2B/2|"D"A2B "A7"G2A|"D"F2A def|"Em"g2e "A7"cBc|"D"dfe "G"dcB|
#
# **** Added info : Dictionary added transcription ****
#
# "D"A2B "A7"G2A|"D"F2A def|"G"g2e "A7"cBc|"D"d3 d2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 24
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Blackthorne Stick
#
# % Nottingham Music Database
#
# S:Kevin Briggs, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# P:A
#
# d|"G"gfg "C"ege|"G"dBG "C"AGE|"G"DGG "D7"FGA|"G"BAG "D7"A2d|
#
# **** Added info : Dictionary added transcription ****
#
# "G"gfg "C"age|"G"dBG "C"AGE|"G"DGG "D7"FGA|"G"BGG G2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# d|"G"edd gdd|"G"edd gdd|"G"ede "C"gfe|"Am"dcB "D7"A2d|
#
# **** Added info : Dictionary added transcription ****
#
# "G"gfg "C"age|"G"dBG "C"AGE|"G"DGG "D7"FGA|"G"BGG G2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 25
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Blarney Pilgrim
#
# % Nottingham Music Database
#
# P:AABBCC
#
# S:Alistair Anderson, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# P:A
#
# |:D|"G"DED DEG|"C"A2G ABc|"G"BAG "C"AGE|"Am"GEA "D7"GED|
#
# **** Added info : Dictionary added transcription ****
#
# "G"DED DEG|"C"A2G ABc|"G"BAG "C"AGE|"D7"GED D2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# |:d|"G"ded dBG|"Am"AGA "Em"BGE|"G"ded dBG|"C"AGA "D7"GBd|
#
# **** Added info : Dictionary added transcription ****
#
# "G"g2e dBG|"Am"AGA "Em"BGE|"Em"B2G AGE|"Em"GAG G2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:C
#
# |:G|"D"A2D "Em"B2D|"D"A2D ABc|"G"BAG "C"AGE|"Am"GEA "D7"GED|
#
# **** Added info : Dictionary added transcription ****
#
# "D"A2D "Em"B2D|"D"A2D ABc|"G"BAG "C"AGE|"D7"GED D2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 26
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Blaydon Races
#
# % Nottingham Music Database
#
# S:Kevin Briggs, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# A|"D"d2d d2d|"D"d2d d2d|"A7"e2e e2e|"D"f3 "D7"d3|"G"ggg g2g|"D"f2f f2f|
#
# **** Added info : Dictionary added transcription ****
#
# "E7"e2f e2d|"A7"c3 A3|"D"d2d d2d|"D"d2d d2d|"A7"e2e e2e|"D"f3 "D7"d3|\
#
# **** Added info : Dictionary added transcription ****
#
# "G"ggg g2g|
#
# **** Added info : Dictionary added transcription ****
#
# "D"f2g a2a|"A7"a2g f2e|"D"d2e f2g|"D"a3 "A7/e"a2f|"D/f+"d3 "G"d2d|\
#
# **** Added info : Dictionary added transcription ****
#
# "E7/g+"e2e "A7"e2e|
#
# **** Added info : Dictionary added transcription ****
#
# "D"f3 "D7/c"d3|"G/b"g2g "A7/c+"g2g|"D"f2f "D/f+"f2f|"G"e2f "E7/g+"e2d|\
#
# **** Added info : Dictionary added transcription ****
#
# "A"c3 "A7/g"A3|"D/f+"d2d "G"d2d|"D/f+"d3 "G"d2d|
#
# **** Added info : Dictionary added transcription ****
#
# "E7/g+"e2e "A7"e2e|"D"f3 "D7/c"d3|"G/b"g2g "A7/c+"g2g|"D"f2g "B7/f+"a2a|\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"a2g "A7"f2e|"D"d3 d2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 27
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Bonnets So Blue
#
# % Nottingham Music Database
#
# P:AAB
#
# S:Kevin Briggs, via EF
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# K:C
#
# **** Added info: Dictionary added K = C ****
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# P:A
#
# |:G|"C"cdc efg|"G7"GAG GAB|"C"ceg gec|"G7"d2e gfd|
#
# **** Added info : Dictionary added transcription ****
#
# "C"cdc efg|"Dm"GAG "G7"G2g|"Am"gfe "G7"dcB|"C"c3 c2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# |:d/2c/2|"G/b"Bcd "D7/a"ded|"G/b"G3 "D7/a"G2c|"G"Bcd "G7/f"def|"C/e"g3 "G7/d"g2f|
#
# **** Added info : Dictionary added transcription ****
#
# "C"e2 d c2 "b"B|"Am"A2 B c2 d|"Am" efe "E7" dcB|"Am" A3 "G7" G3|
#
# **** Added info : Dictionary added transcription ****
#
# "C"cdc efg|"C" cdc "G7" c2A|"C"ceg gec|"Dm" d3 "G7" e2d|
#
# **** Added info : Dictionary added transcription ****
#
# "C"cdc efg|"G"GAG G2 g| "Am" gfe "G7"dcB|"C" c3 c2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 28
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Bonnets So Blue
#
# % Nottingham Music Database
#
# P:AAB
#
# S:FTB 1 p 47, via EF
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# P:A
#
# |:A|"D"ded def|"A7"ABA ABc|"A7"dfb afd|"A7"efe e2A|
#
# **** Added info : Dictionary added transcription ****
#
# "D"ded def|"A7"ABA A2b|"Bm"agf "A7"age|"D"d3 d2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# |:e/2d/2|"A"cde "E7"efe|"A"A3 A2d|"A"cde "A7"efg|"D"a3 "A7"a2g|"D"f2e d2c|\
#
# **** Added info : Dictionary added transcription ****
#
# "Bm"B2c d2e|
#
# **** Added info : Dictionary added transcription ****
#
# "Bm"fgf "F#7"edc|"Bm"B3 "A7"A3|"D"def def|"D"def d2A|"D"dfb agf|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"egf "A7"e2A|"D"def def|"Bm"def d2b|"Em"agf "A7"age|"D"d3 d2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 29
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Brian Borouhme
#
# % Nottingham Music Database
#
# S:Jimmy Galway, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Am
#
# **** Added info: Dictionary added K = Am ****
#
# P:A
#
# e|"Am"cBA Aed|"Am"cBA A2"ab"d|"G"BAG Gdc|"G"BAG G2" ""gb"e|
#
# **** Added info : Dictionary added transcription ****
#
# "Am""F"cBA Aed|"Am""F"cBA A2B|"Dm""E7"cde "E7"e2d|"Am"cAA A2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# B|"C"cde efe|"C"efe edc|"G"Bcd ded|"G"ded dcB|
#
# **** Added info : Dictionary added transcription ****
#
# "C"cde efe|"C"efe edc|"E7"e3 e2d|"Am"cAA A2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 30
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Bridal Jig
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# D|"G"G2G BGB|"D"def "Em"gfg|"Am"ecA "G"dBG|"D7"FAG FED|
#
# **** Added info : Dictionary added transcription ****
#
# "G"GFG BGB|"D"def "Em"gfg|"Am"ecA "G"dBG|"D7"FED G2::
#
# **** Added info : Dictionary added transcription ****
#
# A|"Em"Bee edB|"D"def "Em"g2a|"G"bag "D"agf|"Em"geg "Bm"fdB|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"Bee edB|"D"def "Em"g2a|"G"bag "D"agf| [1"Em"gee e2:|\
#
# **** Added info : Dictionary added transcription ****
#
#  [2"G"g2g gdB||
#
# **** Added info : Dictionary added transcription ****
#
# X: 31
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:The Mug of Brown Ale
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# G|"Am"EAA ABd|edB c2A|"G"BGG dGG|Bdc BAG|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"EAA ABd|"Am"ede "Em"a2g|"Am"edc "Em"Bcd|"Am"ecA A2:|
#
# **** Added info : Dictionary added transcription ****
#
# f|"Em"gef g2a|"Em"gef "D7"gdc|"G"BGG dGG|Bdc BAG|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"gef g2a|"D7"gef "G"g2d|"C"edc "E7"Bcd|"Am"ecA A2f|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"gef g2a|"Em"gef "D7"gdc|"G"BGG dGG|Bdc BAG|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"EAA ABd|"Am"ede "Em"a2g|"Am"edc "E7"Bcd|"Am"ecA A2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 32
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:St. Bruno
#
# % Nottingham Music Database
#
# S:Chris Dewhurst, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Dm
#
# **** Added info: Dictionary added K = Dm ****
#
# A|"Dm"d2e f2g|"Dm"a2d "G"def|"C"g2c cde|"Bb"fed "Am"c=BA|
#
# **** Added info : Dictionary added transcription ****
#
# "Dm"d2e "A7"f2g|"Dm"afd "Gm"b2g|"Dm"fed "A"ed^c|"Dm"d3 -d2::
#
# **** Added info : Dictionary added transcription ****
#
# a|"Dm"add "Gm"bdd|"Dm"add fef|"Gm"g2b d'c'b|"Dm"a3 d3|
#
# **** Added info : Dictionary added transcription ****
#
# "Gm"g2a bag|"Dm"afd A2f|"A"e^cA f2e|"Dm"d3 -d2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 33
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Buggy Ride Jig
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# P:INTRO
#
# g|f/2a3/2d f/2a3/2d|fg2 "D7"d^c=c|:"G"B2B BAG|B2B BAG|"G"B/2d3/2G B/2d3/2G|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"Bcc cBc|"D"eff fed|"D"f2f fed|"D7"f/2a3/2d f/2a3/2d|"G"fg2 "D7"gfg::
#
# **** Added info : Dictionary added transcription ****
#
# "G"D2G B2d|"G"b3 -b2f|"G"a2g "E7"f2e|"Am"c3 cBA|"D"c2c cBA|
#
# **** Added info : Dictionary added transcription ****
#
# "D"f2f fed|"Am"f/2a3/2d "D7"f/2a3/2d| [1"G"fg2 gfg:|
#
# **** Added info : Dictionary added transcription ****
#
#  [2"G"g2zz3|"G"g6||
#
# **** Added info : Dictionary added transcription ****
#
# X: 34
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Bung Your Eye
#
# % Nottingham Music Database
#
# S:FTB 2/42, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Am
#
# **** Added info: Dictionary added K = Am ****
#
# P:A
#
# E|"Am"ABA c2d|"Am"edc B2A|"G"GAG B2c|"G"dge dBG|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"ABA c2d|"Am"edc "G"Bcd|"Am"e2A "E7"AB^G|"Am"A3 A2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# B|"C"c3/2d/2e/2f/2 g2a|"C"gec gec|"G"G3/2A/2B/2c/2 d2e|"G"dge dBG|
#
# **** Added info : Dictionary added transcription ****
#
# "C"c3/2d/2e/2f/2 g2a|"C"gec "E7"de^g|"Am"a2A "E7"AB^G|"Am"A3 A2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 35
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:The Burdett
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# A|"D"d2d f2a|"Em"gfg "A7"e2a|"Bm"f2d "E7"B2e|"A7"cBc A2A|
#
# **** Added info : Dictionary added transcription ****
#
# "D"d2d f2a|"Em"gfg "A7"e2a|"Em"afd "A7"gec|"D"d2f d2::
#
# **** Added info : Dictionary added transcription ****
#
# A|"D"d2d "F#m"cBc|"G"B2B B2B|"E7"e2e dcd|"A7"c2c c2A|
#
# **** Added info : Dictionary added transcription ****
#
# "D"dcd "A7"ede|"Bm"fef "Em"gfg|"D"afd "A7"gec|"D"d2f d2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 36
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Cadeau's Jig
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Bb
#
# **** Added info: Dictionary added K = Bb ****
#
# B-c|"Bb"dBF DFB-|dBF DFE-|"Bb"DFB dcB|
#
# **** Added info : Dictionary added transcription ****
#
# "Eb"AG^F "Cm"G2A|"F7"aAA aAa|"F7"g3 -ga-g|"F7"f=ef _ede-|d3 dB-c|
#
# **** Added info : Dictionary added transcription ****
#
# "Bb"dBF DFB-|dBF DFE-|"Bb"DFB dcB-|"Eb"AG^F "Cm"G2A|
#
# **** Added info : Dictionary added transcription ****
#
# "F7"aAA aAa|g3 -gA-G|"F7"FAc -ecA-|"Bb"B3 BF-E||
#
# **** Added info : Dictionary added transcription ****
#
# "Bb"D-FA BFB-|d3 d^c=c|"Bb"B-AB gfg|f3 -f2b|"F7"a3 -a^ga|
#
# **** Added info : Dictionary added transcription ****
#
# "F7"g3 -gag|f=ef _ede|"Bb"d3 -dF-E|"Bb"D-FA BFB-|d3 d^c=c|
#
# **** Added info : Dictionary added transcription ****
#
# "Bb"B-AB gfg|f3 -f2b|"F7"a3 -a^ga|"F7"g3 -gAG|F-Ac ecA-|"Bb"B3 B||
#
# **** Added info : Dictionary added transcription ****
#
# X: 37
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:There Came A Young Man
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Am
#
# **** Added info: Dictionary added K = Am ****
#
# E|"Am"ABA c2d|"Am"edc "D7"\
#
# **** Added info : Dictionary added transcription ****
#
# B2A|"G"GAG B2c|dge d
#
# **** Added info : Dictionary added transcription ****
#
# BG|"Am"ABA c2d|"Am"edc "E7"Bcd|"Am"e2A "E7"AB^G|"Am"
#
# **** Added info : Dictionary added transcription ****
#
# A3 -A2::B|"C"c2e g2a|gec gec|"G"G2B d2e|dge d
#
# **** Added info : Dictionary added transcription ****
#
# BG|"C"\
#
# **** Added info : Dictionary added transcription ****
#
# c2e g2a|"C"gec "E7"de^g|"Am"a2A "E7"AB^G|"Am"A3 -A2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 38
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Captain White
#
# % Nottingham Music Database
#
# P:AAB
#
# S:Kevin Briggs, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# P:A
#
# A|"D"DFA d2f|"A"edc "G"B2d|"D"A2d F2B|"Em"AGF "A7"E2A|
#
# **** Added info : Dictionary added transcription ****
#
# "D"DFA d2f|"A"edc "G"B2d|"D"A2d "Bm"F2B|"A7"ABc "D"d2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# f|"A"e^de A2f|"A"e^de a2f|"Bm"efe "E7"dcB|"A"A2B "E7"c2f|"A"e^de A2f|
#
# **** Added info : Dictionary added transcription ****
#
# "A"e^de a2f|"Bm"efe "E7"dcB|"A7"ABA GFE|"D"D2f fef|"D"d2A A^GA|
#
# **** Added info : Dictionary added transcription ****
#
# "D"D2f fef|"G"gfe "A7"ecA|"D"D2f fef|"D"d2A A^GA|"Em"Bed "A7"cBc|"D"d3 -d2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 39
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Crossing The Cascades
#
# % Nottingham Music Database
#
# S:Mike Richardson 16.9.90, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# "A"A2F |:"D"DED DFA|d3 d2c|"G"B2B Bcd|"D"A3 F2A|
#
# **** Added info : Dictionary added transcription ****
#
# "G"BAB "A"cBc|"D"d2A "Bm"AGF| [1"Em"E2F GFE|"A"C3 A,2C:|
#
# **** Added info : Dictionary added transcription ****
#
#  [2"A"EFG F2E|"D"D3 DFA||"D"d3 def|"F#"c3 -cBc|"G"d2d dcB|"D"A3 F2A|
#
# **** Added info : Dictionary added transcription ****
#
# "G"B2c dcB|"D"A2d "Bm"AGF|"Em"E2F GFE|"A"C3 A2c|"D"d3 def|"F#"c3 -cBc|
#
# **** Added info : Dictionary added transcription ****
#
# "G"d2d dcB|"D"A3 F2A|"G"BAB "A"cBc|"D"dcd "G"efg|"D"fed "A"A2c|"D"d3 ||
#
# **** Added info : Dictionary added transcription ****
#
# X: 40
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:The Castle
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# D|"G"G3 GAB|"Am"A3 "D7"ABc|"G"edd gdd|"C"edB "D7"dBA|
#
# **** Added info : Dictionary added transcription ****
#
# "G"G3 GAB|"Am"A3 "D7"ABc|"G"edd gdB|"D7"AGF "G"G2::
#
# **** Added info : Dictionary added transcription ****
#
# A|"G"BAB dBd|"C"e/2f/2ge "D"dBA|"G"BAB dBG|"D7"ABA A2A|
#
# **** Added info : Dictionary added transcription ****
#
# "G"BAB dBd|"C"e/2f/2ge "D"dBA|"G"gfg "D7"aga|"G"bgg g2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 41
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Cat in the Kitchen
#
# % Nottingham Music Database
#
# S:Bob McQuillen Jan 1975, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Bm
#
# **** Added info: Dictionary added K = Bm ****
#
# F|"Bm"B2c dcB|"Em"e2f gfe|"Bm"fbb bag|"F#7"fgf edc|
#
# **** Added info : Dictionary added transcription ****
#
# "Bm"B2c dcB|"Em"e2f gfe|"Bm"fgf "F#7"edc|[1"Bm"dBB B2:|[2 dBB B
#
# **** Added info : Dictionary added transcription ****
#
# |:"A7"AG|"D"F2B "A7"ABc|"D"d2d "A"ede|"Bm"fBB Bcd|"A"cAA "G"BAG|
#
# **** Added info : Dictionary added transcription ****
#
# "F#m"F2B "A7"ABc|"D"dcd "A"ede|"Bm"fed "F#m"cBA|"Bm"FBB B:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 42
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Cavan Buck
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Bm
#
# **** Added info: Dictionary added K = Bm ****
#
# "Bm""Bm"d2B "F#m""A"c3|"Bm""G"B2c d2e|"Bm"f2f "E7"e2d| "A"c2A ABc|
#
# **** Added info : Dictionary added transcription ****
#
#  "Bm"dcB "F#m"cBA|"Bm"B2c d2e|"Bm"f^ga "F#m"gfe|"Bm"f2B B3::
#
# **** Added info : Dictionary added transcription ****
#
# "D"a2f d2e|"Bm"f2b b2f|"D"a2f "E7"e2d|"A"c2A ABc|
#
# **** Added info : Dictionary added transcription ****
#
# "Bm"dcB "F#m"cBA|"Bm"B2c d2e|"Bm"f^ga "F#m"gfe|"Bm"f2B B3:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 43
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Champion Jig
#
# % Nottingham Music Database
#
# S:EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Em
#
# **** Added info: Dictionary added K = Em ****
#
# P:A
#
# |:B|"Em"Bef gfe|"Em"bef gfe|"B7"f^dB fdB|"B7"bc'b agf|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"Bef gfe|"Em"bef gfe|"B7"b3 b2a|[1"Em"gee e2:|[2 "Em" gee e3|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"\
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# |:d3 "D7"c3|"G"Bdg bgd|"D7"cdf afd|"G"Bdg bgd|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"d3 "D7"c3|"G"Bdg bgd|"D7"cdf afd|"G"gdb g3:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 44
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Charlbytown Two-Step
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:C
#
# **** Added info: Dictionary added K = C ****
#
# ef|"C"g^fg a2g|"C7"edc G2E|"F"FEF A2G|F3 -FEF|"G7"G^FG B2A|
#
# **** Added info : Dictionary added transcription ****
#
# G^FG B2A|"G7"G^FG A2G|"C"E3 -"G7"E2g|"C"g^fg a2g|"C7"edc G2E|"Dm"FEF A2G|
#
# **** Added info : Dictionary added transcription ****
#
# F3 -FEF|"G7"G^FG B2A|G^FG B2A|"G7"GAB e2d|"C"+E3 c3 +zef||
#
# **** Added info : Dictionary added transcription ****
#
# "C"g2g gfe|"C7"g3 -g^fg|"F"agf def|"Dm"a3 -a^ga|"G7"b2a g2f|
#
# **** Added info : Dictionary added transcription ****
#
# "C"e2d cBA|"G""c"G^FG "G7"A2G|"C"e3 -"G7"eef|"C"g2g gfe|"C7"g3 z^fg|"F"agf def\
#
# **** Added info : Dictionary added transcription ****
#
# |
#
# **** Added info : Dictionary added transcription ****
#
# "D7"a3 -a^ga|"G7"b2a g2f|"C"e2d "C/dim"cBA|"G"GAB "G7"e2d|"C"[E3c3]-[E3c3]|
#
# **** Added info : Dictionary added transcription ****
#
# X: 45
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Charlie Hunter
#
# % Nottingham Music Database
#
# S:Jim McLeod, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# P:A
#
# A|"D"DFA "G"GBd|"D/f+"Adf "A7/e"a2g|"D"fed "G"Bcd|"Em"ecA "A7"GFE|
#
# **** Added info : Dictionary added transcription ****
#
# "D"DFA "G"GBd|"D"Adf "A"a2g|"Bm"fef "A7"gec|"A7"edc "D"d2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# f/2g/2|"D"afd d2c|"G"BGG G2F|"E7"E^GB e2d|"A7"cAA Aag|
#
# **** Added info : Dictionary added transcription ****
#
# "D"fdA FDF|"G"GBd g2a/2g/2|"D"fef "A7"gec|"A7"edc "D"d2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 46
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Chuntering Charlie
#
# % Nottingham Music Database
#
# S:John Kirkpatrick, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:C
#
# **** Added info: Dictionary added K = C ****
#
# "C"cGE "G"B2A|"C"GEC "F"F2E|"G"DB,G, DB,G,|"C"CDE "G"D2G|
#
# **** Added info : Dictionary added transcription ****
#
# "C"cGE "G"B2A|"C"GEC "F"F2E|"G"DB,G, DB,G,|"G"GAB "C"c3::
#
# **** Added info : Dictionary added transcription ****
#
# "G"DDD D2E|F2G A2B|"C"cGE "F"B2A|"C"GEC "F"F2E|
#
# **** Added info : Dictionary added transcription ****
#
# "G"DDD D2E|F2G A2B|"C"cGE "F"B2A|"G"GAB "C"c3::
#
# **** Added info : Dictionary added transcription ****
#
# "F"A2c A2G|F2A F2E|"F"D2F D2C|"G"B,2D G,A,B,|
#
# **** Added info : Dictionary added transcription ****
#
# "C"C2E "G"D2F|"C"E2G "F"F2A| "G"BAG BAG|"G"BAG "C"c3:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 47
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Chelmsford Races
#
# % Nottingham Music Database
#
# S:Thomas Hardy Collection, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Bb
#
# **** Added info: Dictionary added K = Bb ****
#
# F|"Bb"B2B BAB|"F"c2c f2f|"Bb"d2d B2B|"F"ABc FGA|
#
# **** Added info : Dictionary added transcription ****
#
# "Bb"B2B BAB|"F"c2c f2f|"Eb"egf "F"edc|"Bb"B2B B2::
#
# **** Added info : Dictionary added transcription ****
#
# f|"Bb"fef def|"Eb"g2g g3|"F"aga fga|"Bb"b2b b3|
#
# **** Added info : Dictionary added transcription ****
#
# "Bb"fef def|"Eb"g2a bag|"Bb"fgf "F7"edc|"Bb"B2B B2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 48
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Cherish The Ladies
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# B/2c/2|"D"dFF AGF|DFA AFA|"Em"BEE GEE|"G"BdB "A7"AFA|
#
# **** Added info : Dictionary added transcription ****
#
# "D"dFF AGF|"D"DFA AFA|"G"Bcd "A7"efg|"D"fdd d2::
#
# **** Added info : Dictionary added transcription ****
#
# B/2c/2|"D"dfd "A"cec|"Bm"BdB "D"AGF|"Em"BEE GEE|"G"BdB "A7"AFA|
#
# **** Added info : Dictionary added transcription ****
#
# "D"dfd "A"cec|"Bm"BdB "D"AFA|"G"Bcd "A7"efg|"D"fdd d2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 49
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Jig For Chris
#
# % Nottingham Music Database
#
# S:Mike Richardson 30.3.89, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# D|"G"GBd "D"cBA|"G"BGE DB,D|"G"EDB, "Em"G,B,D|"Am"GDB, "D"A,2D|
#
# **** Added info : Dictionary added transcription ****
#
# "G"GBd "D"cBA|"G"BGE DB,D|"G"EDB, "Em"G,B,D|"D"EGF "G"G2:|
#
# **** Added info : Dictionary added transcription ****
#
# A|"G"Bdd gdd|"D"Add fdd|"C"Gcc ecA|"D"
#
# **** Added info : Dictionary added transcription ****
#
# P:3
#
# FAG FED|"G"Bdd gdd|"D"Add fdd|"A"egf ed^c|
#
# **** Added info : Dictionary added transcription ****
#
# "D"d3 dcB|"C"cee "G"Bdd|"D"Acc "G"GBB|"C"cBA "G"BAG|"D"FAF DEF|
#
# **** Added info : Dictionary added transcription ****
#
# "G"GBB "C"Acc|"G"Bdd "C"cee|"G"def "Em"gdB|"D"AGF G2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 50
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Circle Around
#
# % Nottingham Music Database
#
# S:Chris Dewhurst 1978, via Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# "(D7)"B,2C |"G"D2B B^AB|"G"G2D B,CD|"C"E2F GFE|"G"D3 "D"d2c|"G"B2B B^AB|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"G2B E2B|"A7"A^GA ABc|"D"d3 "D7"d2c|"G"B2D B^AB|"G"G2D B,CD|
#
# **** Added info : Dictionary added transcription ****
#
# "C"E2F GFE|"G"D3 ^D3|"C7"E^DE GFE|"G"DGB "Em"d2D|"Am"E2A "D"FEF|"G"G3 B2c||
#
# **** Added info : Dictionary added transcription ****
#
# "G"ded BdB|"G"GBG "C"EGE|"G"DBA GF=F|"C"E3 "E7"e2d|"Am"cdc BcB|
#
# **** Added info : Dictionary added transcription ****
#
# "A7"ABA GAG|"D"FGF "A"EAc|"D"d3 "D7"B2c|"G"ded BdB|"G"GBG "C"EGE|
#
# **** Added info : Dictionary added transcription ****
#
# "G"D2B "G7"c2d|"C"e3 e2f|g2f efg|"G""b"d2B "Em"GAB|"Am"cAF "D"DEF|"G"G3 ||
#
# **** Added info : Dictionary added transcription ****
#
# X: 51
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:The Cobbler
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# D|"D"DFA "G"B2A|"D"def "A7"gfe|"D"fdf "A7"ecA|"G"BGB "D"AFD|
#
# **** Added info : Dictionary added transcription ****
#
# "D"DFA "G"B2A|"D"def "A7"gfe|"D"fdf "A7"ecA|"D"Add d2::
#
# **** Added info : Dictionary added transcription ****
#
# g|"D"fad fad|faa agf|"C"eg=c eg=c|efg gfe|
#
# **** Added info : Dictionary added transcription ****
#
# "D"fef "G"gfg|"D"agf "A7"efg|"D"fed "Am"=cAG|"D"Add d2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 52
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Cock of the North
#
# % Nottingham Music Database
#
# S:Kevin Briggs, via EF
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:A
#
# **** Added info: Dictionary added K = A ****
#
# P:A
#
# e/2d/2|"A"cdc cBA|"A"Ace "D"f2e|"A"cdc cBA|"B7"BcB "E7"Bed|
#
# **** Added info : Dictionary added transcription ****
#
# "A"cdc cBA|"A"Ace "D"f2e|"A"c2c "E7"BcB|"A"A3 A2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# (3e/2f/2g/2|"A"a2e "D"f2e|"A"a2e "D"f2e|"A"cdc cBA|"Bm"Bcd "E7"efg|
#
# **** Added info : Dictionary added transcription ****
#
# "A"a2e "D"f2e|"A"a2e "D"f2e|"A"c2c "E7"BcB|"A"A3 A2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 53
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Coleraine
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Am
#
# **** Added info: Dictionary added K = Am ****
#
# E|"Am"EAA ABc|"E7"Bee e2d|"Am"cBA ABc|"E7"B^GE E2E|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"EAA ABc|"E7"Bee e2d|"Am"cBA "E7"B^GE|"Am"A3 -A2::
#
# **** Added info : Dictionary added transcription ****
#
# B|"C"c2c cdc|"G"Bdg g2^g|"Am"aed cBA|"E7"^GBG E^FG|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"A^GA "E7"BAB|"Am"cde "Dm"fed|"Am"cBA "E7"EA^G|"Am"A3 -A2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 54
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:The Connaught Man's Rambles
#
# % Nottingham Music Database
#
# S:Trad, arr Phil Rowe
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# A|"D"FAA dAA|"G"BAB "A7"dAG|"D"FAA "A"Afe|"Bm"dBB "A7"BAG|
#
# ...
#
# **** Added info : Dictionary added transcription ****
#
# X: 45
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Starry Nights of Shetland
#
# % Nottingham Music Database
#
# S:Kevin Briggs
#
# M:3/4
#
# **** Added info: Dictionary added M = 3/4 ****
#
# L:1/4
#
# K:C
#
# **** Added info: Dictionary added K = C ****
#
# G|"C"e2c|"C"GAG|"Dm"F3|"Dm"B2A|"G"G2B|"G"d2G|"C"e3-|"C"e2G|"C"e2c|
#
# **** Added info : Dictionary added transcription ****
#
# "C"GAG|"Dm"F3|"Dm"B2A|"G"G3/2B/2d/2e/2|"G7"fAB|"C"c3-|"C"cde|"F"fAf|
#
# **** Added info : Dictionary added transcription ****
#
# "F"fAf|"C"eGe|"C"eGe|"C"ece|"Am"gfe|"Dm"d3-|"G7"d2G|
#
# **** Added info : Dictionary added transcription ****
#
# "C"e2c|"C"GAG|"Dm"F3|"Dm"B2A|"G"G3/2B/2d/2e/2|"G7"fAB|"C"c3-|"C"c2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 46
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Just as the Sun was Setting
#
# % Nottingham Music Database
#
# S:John Kirkpatrick
#
# M:3/4
#
# **** Added info: Dictionary added M = 3/4 ****
#
# L:1/4
#
# K:Am
#
# **** Added info: Dictionary added K = Am ****
#
# E|"Am"A3/2B/2A|"Am"e2a|"Em"g3/2a/2g|"Em"e2d|"Am"c3/2B/2A|"G"BAG|"F"A3/2B/2A|\
#
# **** Added info : Dictionary added transcription ****
#
# "E7"E2E|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"A3/2B/2A|"Am"e2a|"C"g3/2a/2g|"Em"e2d|"Am"c3/2B/2A|"E7"e3/2d/2e|"Am"A2"G"G|\
#
# **** Added info : Dictionary added transcription ****
#
# "Am"A2e|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"a3/2b/2"B7"a|"E7"^g2e/2^f/2|"G"g3/2a/2"A7"g|"D"^f2d/2e/2|"F"f3/2g/2"G7"f|\
#
# **** Added info : Dictionary added transcription ****
#
# "C"e2d|"F"c3/2d/2c|"E7"B2E|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"A3/2B/2A|"Am"e2a|"C"g3/2a/2g|"Em"e2d|"Am"c3/2B/2A|"E7"e3/2d/2e|"Am"A2"G"G|\
#
# **** Added info : Dictionary added transcription ****
#
# "Am"A2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 47
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Sunset Over Ayr
#
# % Nottingham Music Database
#
# S:Bryon Bonnett
#
# M:3/4
#
# **** Added info: Dictionary added M = 3/4 ****
#
# L:1/4
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# D|"G"B3/2A/2B|"Bm"d2d|"C"eGA|"D7"B2A|"Em"G3/2F/2G|"C"G2G|"Am"ecB|
#
# **** Added info : Dictionary added transcription ****
#
# "D7"A2D|"G"B3/2A/2B|"Bm"d2d|"C"gcB|"D7"B2A|"Em"B3/2A/2B|"Bm"d2D|"D7"DBA|
#
# **** Added info : Dictionary added transcription ****
#
# "G"G2A|"Em"B3/2A/2B|"Bm"d2d|"Em"B3/2A/2B|"Bm"d3|"C"e2e|"G"d2B|B3/2c/2B|"D7"A2D\
#
# **** Added info : Dictionary added transcription ****
#
# |
#
# **** Added info : Dictionary added transcription ****
#
# "G"B3/2A/2B|"Bm"d2d|"C"gcB|"D7"B2A|"Em"B3/2A/2B|"Bm"d2D|"D7"DBA|"G"G2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 48
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Twickenham Ferry
#
# % Nottingham Music Database
#
# S:by Pat Shuldam-Shaw for Amy Foxley
#
# M:3/4
#
# **** Added info: Dictionary added M = 3/4 ****
#
# L:1/4
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# d|"G"g3/2f/2e|"G/b"d3/2c/2B|"C"A3/2B/2G|"D7"FED|"G"G3/2A/2B|"G"d3/2e/2B|\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"d3/2e/2B|
#
# **** Added info : Dictionary added transcription ****
#
# "D"d2e/2f/2|"Em"g3/2f/2e|"Bm"d3/2c/2B|"A7"A3/2B/2G|"D7"FED|"G"G3/2E/2"f#"D|\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"G3/2E/2"d"D|"C"G3/2E/2D|
#
# **** Added info : Dictionary added transcription ****
#
# "G"G2d|"Em"e3/2f/2e|"Em"B^AB|"Bm"d3/2e/2d|"Bm"dcB|"Em"e3/2f/2e|"Em"B^AB|\
#
# **** Added info : Dictionary added transcription ****
#
# "Bm"d3/2e/2d|
#
# **** Added info : Dictionary added transcription ****
#
# "D7"def|"G"g3/2f/2e|"Bm"d3/2c/2B|"A7"A3/2B/2G|"D7"FED|"G"G3/2E/2"f#"D|\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"G3/2E/2"d"D|"C"G3/2E/2D|"G"G2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 49
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Waters of Tyne
#
# % Nottingham Music Database
#
# S:NPTB
#
# M:3/4
#
# **** Added info: Dictionary added M = 3/4 ****
#
# L:1/4
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# F/2G/2|"D"AFF|"A"AFE|"G"DD3/2D/2|"D"D2E/2F/2|"G"GGF|"A"EFA|"G"BB3/2B/2|
#
# **** Added info : Dictionary added transcription ****
#
# "A"A2F/2E/2|"D"Dd3/2d/2|"D"def|"D"dA3/2B/2|"G"B2c/2d/2|"D"AFA|"A"A2F/2E/2|\
#
# **** Added info : Dictionary added transcription ****
#
# "G"DD3/2D/2|"D"D2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 50
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Weeping and Wailing
#
# % Nottingham Music Database
#
# S:Rosemary Redpath
#
# M:3/4
#
# **** Added info: Dictionary added M = 3/4 ****
#
# L:1/4
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# A|"D"dde|"D"fed|"G"GBB|"G"B/2B3/2B|"A"Ac3/2B/2|"A"AcA|"A7"gfe|
#
# **** Added info : Dictionary added transcription ****
#
# "D"f2A|"D"dde|"D"fed|"G"GBB|"Em"B/2B3/2B|"A"Ac3/2B/2|"A"AcA|"A7"gfe|
#
# **** Added info : Dictionary added transcription ****
#
# "D"d2d/2e/2|"D"f3|"Bm"a3|"D"a3/2g/2f|"Bm"ef2-|"D"fAA|"D"def|"G"gBe|\
#
# **** Added info : Dictionary added transcription ****
#
# "A7"dcA/2A/2|
#
# **** Added info : Dictionary added transcription ****
#
# "D"dde|"D"fed|"G"GBB|"Em"B/2B3/2B|"A"Ac3/2B/2|"A"AcA|"A7"gfe|"D"d2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 51
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Wind on the Heath
#
# % Nottingham Music Database
#
# S:Scotland
#
# M:3/4
#
# **** Added info: Dictionary added M = 3/4 ****
#
# L:1/4
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# A|"D"D3/2E/2D|"D"F2G|"D"A2B|"D"AFD|"G"G2d|"D"F2d|"Em"EFD|"A7"CB,A,|
#
# **** Added info : Dictionary added transcription ****
#
# "D"D3/2E/2D|"D"F2G|"D"A2B|"D"AFD|"Em"FdF|"A7"Edc|"D"dAF|"D"D2A|
#
# **** Added info : Dictionary added transcription ****
#
# "D"d3/2e/2d|"D"f2g|"D"a2g|"D"fed|"G"B3/2c/2B|"A"c2d|"E7"efd|"A7"cBA|
#
# **** Added info : Dictionary added transcription ****
#
# "D"d3/2e/2d|"Bm"f2g|"F#m"a2g|"Bm"fed|"Em"B/2c/2dB|"A7"c/2d/2ec|"D"d3|"D"d2A|
#
# **** Added info : Dictionary added transcription ****
#
# "D"d3/2e/2d|"D"f2g|"D"a2g|"D"fed|"G"B3/2c/2B|"A"c2d|"E7"efd|"A7"cBA|
#
# **** Added info : Dictionary added transcription ****
#
# "D"dad|"A"cac|"G"Bag|"D"fed|"Em"B/2c/2dB|"A7"c/2d/2ec|"D"dAF|"D"D2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 52
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Young Jane
#
# % Nottingham Music Database
#
# S:FTB 1/36
#
# M:3/4
#
# **** Added info: Dictionary added M = 3/4 ****
#
# L:1/4
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# (3D/2E/2F/2|"G"G3/2A/2B|"D"ABd|"C"e2e|"D7"d3/2B/2A|"G"G3/2A/2B|"D"A2G|"Em"E3|
#
# **** Added info : Dictionary added transcription ****
#
# "D7"D3/2E/2F|"G"G3/2A/2B|"D"ABd|"C"e2e|"D"d2e|"Em"G3/2A/2B|"D"A2G|"G"G3-|
#
# **** Added info : Dictionary added transcription ****
#
# "D7"GBc|"G"dBd|"G"g3/2f/2g|"C"e2e|"Am"A2B|"C"c3/2d/2e|"G"dBA|"A7"G3|
#
# **** Added info : Dictionary added transcription ****
#
# "D7"F3/2D/2E/2F/2|"G"G3/2A/2B|"D"ABd|"C"e2e|"D"d2e|"Em"G3/2A/2B|"D"A2G|"G"G3-|\
#
# **** Added info : Dictionary added transcription ****
#
# "G"G2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 1
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:The Boar's Head
#
# % Nottingham Music Database
#
# %P:AAB
#
# S:Vic
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# L:1/4
#
# K:C
#
# **** Added info: Dictionary added K = C ****
#
# |:G|"C"c2 cc|"G"Bc "C"G3/2E/2|"F"FF "Dm"AF| [1"G"GA/2B/2 "C"c:| [2"G"GA/2B/2 "C"c2|
#
# **** Added info : Dictionary added transcription ****
#
# "C"ee "G"dd|"Am"AA "Em"G3/2E/2|"F"FF "Dm"AF|"G"GA/2B/2 "C"c||
#
# **** Added info : Dictionary added transcription ****
#
# X: 2
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Ding Dong
#
# % Nottingham Music Database
#
# S:Trad
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# L:1/4
#
# K:Bb
#
# **** Added info: Dictionary added K = Bb ****
#
# P:A
#
# "Bb"BB "Eb"c/2B/2A/2G/2|"F"F3F|"Eb"GB "F7"BA|"Bb"B2 B2::
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# "Bb"f3/2e/2 d/2e/2f/2d/2|"Eb"e3/2d/2 "F7"c/2d/2e/2c/2|\
#
# **** Added info : Dictionary added transcription ****
#
# "Bb"d3/2c/2 "Gm"B/2c/2d/2B/2|"Cm"c3/2B/2 "F7"A/2B/2c/2A/2|
#
# **** Added info : Dictionary added transcription ****
#
# "Gm"B3/2A/2 "C7"G/2A/2B/2G/2|"F7"A3/2G/2 FF|"Eb"GB "F7"BA|"Bb"B2 B2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 3
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:GKW
#
# % Nottingham Music Database
#
# %P:AAB
#
# S:Trad
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# L:1/4
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# %P:A
#
# "G"GG G"D"A|"G"G"C"G "D"D2|"C"E"G"D "C"E"D7"F|"G"G2 G2|
#
# **** Added info : Dictionary added transcription ****
#
# %P:A
#
# "G"GG G"D"A|"G"G"C"G "D"D2|"C"E"G"D "C"E"D7"F|"G"G2 G2|
#
# **** Added info : Dictionary added transcription ****
#
# %P:B
#
# "G"d"D"c "G"B"D"A|"G"B"D"A "Em"G2|"C"E"G"D "C"E"D7"F|"G"G2 G2|"G"DD "C"E"D"F|\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"GG "D7"A-"c"A|"G/b"d"C"c "G"B"D"A|"Em"G2 "C"c2|"G"G4||
#
# **** Added info : Dictionary added transcription ****
#
# X: 4
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:God rest you, merry gentlemen
#
# % Nottingham Music Database
#
# S:Trad
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# L:1/4
#
# K:Em
#
# **** Added info: Dictionary added K = Em ****
#
# E|"Em"EB BA|"Em"GF ED|"Em"EF GA|"B7"B3E|"Em"EB BA|"Em"GF ED|
#
# **** Added info : Dictionary added transcription ****
#
# "Em"EF GA|"B7"B3B|"D7"cA Bc|"G"de "B7"BA|"Em"GE "A7"FG|"D7"A2 GA|"G"B2 "C"cB|
#
# **** Added info : Dictionary added transcription ****
#
# "D"BA "B7"GF|"Em"E2 "A7"(3GFE|"D7"A2 GA|"G"Bc d"Em"e|"A"BA "B7"GF|"Em"E4-|\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"E3||
#
# **** Added info : Dictionary added transcription ****
#
# X: 5
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Good Christian Men Rejoice
#
# % Nottingham Music Database
#
# S:Trad
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:F
#
# **** Added info: Dictionary added K = F ****
#
# F|"F"F2F A2B|"F"c2d "C7"c2c|"F"F2F A2B|"F"c2d "C7"c3|"F"c2d c2B|
#
# **** Added info : Dictionary added transcription ****
#
# "F"A2G "Dm"F3|"F"F3 "F/a"F3|"Bb"G2G "C7"A2G|"Bb"F2"c"G "F"A3|"F"c2d c2B|\
#
# **** Added info : Dictionary added transcription ****
#
# "F"A2G "Dm"F2F|
#
# **** Added info : Dictionary added transcription ****
#
# "Bb"G2G "C7"A2G|"Bb"F2"c"G "F"A3|"Dm"D2D "A7"E2E|"Dm"F3 "C7"c3|"F"A2A "C7"G2G|\
#
# **** Added info : Dictionary added transcription ****
#
# "F"F3 -F2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 7
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Jubilate Deo (round)
#
# % Nottingham Music Database
#
# P:AAB
#
# S:Taize?
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# L:1/4
#
# K:C
#
# **** Added info: Dictionary added K = C ****
#
# "C"c2 "G7"d2|ec cB|cA GF|EF D2|C2 G,G,|C2 z2||
#
# **** Added info : Dictionary added transcription ****
#
# X: 8
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Nos Galan
#
# % Nottingham Music Database
#
# P:AABA
#
# S:Vic
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# L:1/4
#
# K:F
#
# **** Added info: Dictionary added K = F ****
#
# P:A
#
# |:"F"c3/2B/2 AG|"F"FG AF|"Bb"G/2A/2B/2G/2 "Gm"A3/2G/2|"C7"FE "F"F2:|
#
# **** Added info : Dictionary added transcription ****
#
# P:B
#
# |"C7"G3/2A/2 BG|"F"A3/2B/2 "C7"cG|"F"A/2B/2c "Bb"d/2e/2f|"G7"ed
#
# **** Added info : Dictionary added transcription ****
#
# P:dc
#
# "C7"c2||
#
# **** Added info : Dictionary added transcription ****
#
# % continue here %
#
# X: 9
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:On Christmas Night
#
# % Nottingham Music Database
#
# S:Trad
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# d|"G"d2B "C"c2d|"G"BAG "D7"A2F|"G"G2G "C"ABc|"D7"B2A "G"G2d|"G"d2B "C"c2d|\
#
# **** Added info : Dictionary added transcription ****
#
# "G"BAG "D7"A2F|
#
# **** Added info : Dictionary added transcription ****
#
# "G"G2G "C"ABc|"D7"B2A "G"G3|"Am"A3 A2G|"D7"ABc "G"dcB|"D7"A3 -A3|\
#
# **** Added info : Dictionary added transcription ****
#
# M:9/8
#
# **** Added info: Dictionary added M = 9/8 ****
#
# "G"d3 "C"e3 "D"d3|\
#
# **** Added info : Dictionary added transcription ****
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# "Am"c2B "D7"AGA|"G"G3 -G2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 10
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Wassail 1
#
# % Nottingham Music Database
#
# S:Trad
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# L:1/8
#
# K:Dm
#
# **** Added info: Dictionary added K = Dm ****
#
# D|"Dm"D2A A2G|"Dm"F2F F2E|"Dm"D2E F2G|"A7"A3 -A2D|"Dm"D2A A2G|"Dm"F2F F2E|\
#
# **** Added info : Dictionary added transcription ****
#
# "Dm"D2E F2G|"A7"A3 ||
#
# **** Added info : Dictionary added transcription ****
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# L:1/4
#
# "C7"AB "F"c"Bb"d|"F"c2 AG|"F"FG "Bb"FD|"C"C2 FG|\
#
# **** Added info : Dictionary added transcription ****
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# L:1/8
#
# "Dm"A3B2c |"Dm"D3F2F |"Dm"FA2"C"GE2 |"Dm"D3-D2:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 11
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Wassail 2
#
# % Nottingham Music Database
#
# S:Trad
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:D
#
# **** Added info: Dictionary added K = D ****
#
# D|"D"D2A A2B|"D"A2F D2C|"D"D2E F2G|"A7"A3 -A2D|"D"D2A A2B|"D"A2F D2C|\
#
# **** Added info : Dictionary added transcription ****
#
# "D"D2E F2G|"A7"A3 -A3||
#
# **** Added info : Dictionary added transcription ****
#
# |:"D"d2d d2d|"C"=c3 "G"B3|"D"A2F D2D|"G"G3 F2G|"D"A3 "A7/e"A3|"D/f+"A3 "G"A2B|\
#
# **** Added info : Dictionary added transcription ****
#
# "Em"A3 "A7"G2E|"D"D3 D3:|
#
# **** Added info : Dictionary added transcription ****
#
# X: 12
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:Wassail 3
#
# % Nottingham Music Database
#
# S:Trad
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:G
#
# **** Added info: Dictionary added K = G ****
#
# G|"G"G2A B2A|"G"G2A B2A|"G"G2d d2d|"D7"d3 -d2:|
#
# **** Added info : Dictionary added transcription ****
#
# d|"C"e2e "G"d2B|"G"d3 c2B|"Am"A2G A2B|"D7"c3 ||
#
# **** Added info : Dictionary added transcription ****
#
# M:4/4
#
# **** Added info: Dictionary added M = 4/4 ****
#
# L:1/4
#
# Bc |"G"d2 "C"ge|"G"d2 "D7"Bc|"G"dd "C"ge|"G"d2 "D7"Bc|"G"d2 "Em"eB|
#
# **** Added info : Dictionary added transcription ****
#
# "Am"cA "D7"GF|"G"G3/2A/2 BG|"C"c2 "D7"Bc|"G"d2 "Em"eB|"Am"cA "D7"GF|"G"G4-|\
#
# **** Added info : Dictionary added transcription ****
#
# "G"G3||
#
# **** Added info : Dictionary added transcription ****
#
# X: 13
#
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****
#
# T:W3KOOA
#
# % Nottingham Music Database
#
# S:Trad
#
# M:6/8
#
# **** Added info: Dictionary added M = 6/8 ****
#
# K:Em
#
# **** Added info: Dictionary added K = Em ****
#
# "Em"B2A G2E|"B7"FGF "Em"E3|"Em"B2A G2E|"B7"FGF "Em"E3|"Em"G2G "D"A2A|
#
# **** Added info : Dictionary added transcription ****
#
# "G"B2B dcB|"C"ABA "B7"G2F|"Em"E3 "D7"F2A|"G"G2G G2D|"C"G2E "G"G3|
#
# **** Added info : Dictionary added transcription ****
#
# "G"G2G G2D|"C"G2E "G"G3|"Em"G2G "D"A2B|"C"c2B "D"A2B|"G"G2G G2D|"Em"G2E "G"G3\
#
# **** Added info : Dictionary added transcription ****
#
# ||
#
# **** Added info : Dictionary added transcription ****
#
# X: null
# **** Added info: Added dict_line to all rows ****
#
# **** Added info: Dictionary reinitialized ****

# %%
music_df
# Out:
#                                           transcription    M   K
# 0     f|"A"ecc c2f|"A"ecc c2f|"A"ecc c2f|"Bm"BcB "E7...  6/8   D
# 1     "G"g2g B^AB|d2d G3|"Em"GAB "Am"A2A|"D7"ABc "G"...  6/8   G
# 2     A|"D" def fed|"G" BdB AFD| "D"DFA "G"B2 A|"Em"...  6/8   D
# 3     |d/2c/2\!segno! "G"B2B Bgf|"C"e2e efg|"G"ded "...  6/8   G
# 4     e|"A"eaf e2c|"E7"BAB "A"c3|"A"E2A "E7/b"BAB|"A...  6/8   A
# ...                                                 ...  ...  ..
# 1031  d|"G"d2B "C"c2d|"G"BAG "D7"A2F|"G"G2G "C"ABc|"...  6/8   G
# 1032  D|"Dm"D2A A2G|"Dm"F2F F2E|"Dm"D2E F2G|"A7"A3 -...  6/8  Dm
# 1033  D|"D"D2A A2B|"D"A2F D2C|"D"D2E F2G|"A7"A3 -A2D...  6/8   D
# 1034  G|"G"G2A B2A|"G"G2A B2A|"G"G2d d2d|"D7"d3 -d2:...  4/4   G
# 1035  "Em"B2A G2E|"B7"FGF "Em"E3|"Em"B2A G2E|"B7"FGF...  6/8  Em
#
# [1036 rows x 3 columns]

# %% [markdown]
# # Data Loader

# %%
# Data loading function from here - https://medium.datadriveninvestor.com/music-generation-using-deep-learning-85010fb982e2

# %%
def data_loader(all_characters, num_unique_chars, batch_size, seq_length):
    length = all_characters.shape[0]
    batch_chars = int(length / batch_size) 
    
    for start in range(0, batch_chars - seq_length, seq_length):  

        X = np.zeros((batch_size, seq_length))    
        Y = np.zeros((batch_size, seq_length, num_unique_chars))   
        
        for batch_index in range(0, batch_size):    

            for i in range(0, seq_length):  

                X[batch_index, i] = all_characters[batch_index * batch_chars + start + i]
                Y[batch_index, i, all_characters[batch_index * batch_chars + start + i + 1]] = 1 
                
        yield X, Y

# %% [markdown]
# # Model Experimentation

# %% [markdown]
# ## Baseline

# %%
model_weights_directory = 'Data/Model_Weights/Model_3/Baseline/'
generated_samples_directory = 'Data/Generated_Samples/Model_3/Baseline/'

batch_size = 64
seq_length = 64
num_epochs = 200

optimizer_ = tf.keras.optimizers.Adam()

model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.2))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.2))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))

 
model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (64, 64, 512)             47616
# _________________________________________________________________
# lstm (LSTM)                  (64, 64, 512)             2099200
# _________________________________________________________________
# dropout (Dropout)            (64, 64, 512)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (64, 64, 512)             2099200
# _________________________________________________________________
# dropout_1 (Dropout)          (64, 64, 512)             0
# _________________________________________________________________
# time_distributed (TimeDistri (64, 64, 93)              47709
# _________________________________________________________________
# activation (Activation)      (64, 64, 93)              0
# =================================================================
# Total params: 4,293,725
# Trainable params: 4,293,725
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (64, 50, 512)             47616
# _________________________________________________________________
# lstm (LSTM)                  (64, 50, 512)             2099200
# _________________________________________________________________
# dropout (Dropout)            (64, 50, 512)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (64, 50, 512)             2099200
# _________________________________________________________________
# dropout_1 (Dropout)          (64, 50, 512)             0
# _________________________________________________________________
# time_distributed (TimeDistri (64, 50, 93)              47709
# _________________________________________________________________
# activation (Activation)      (64, 50, 93)              0
# =================================================================
# Total params: 4,293,725
# Trainable params: 4,293,725
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)

print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 0.12819835543632507
# Accuracy: 0.953125

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.2))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.2))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 73
seq_length = 500

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# %%
evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '5/4': 0.0009652509652509653, '6/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'4/4': 0.44680851063829785, '6/8': 0.40425531914893614, '9/8': 0.06382978723404255, '2/4': 0.0425531914893617, '5/8': 0.02127659574468085, '3/4': 0.02127659574468085}
#
# Unique 'M' values to generated dataset: ['5/8']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'Cm': 0.0009652509652509653, 'B': 0.0009652509652509653, 'E': 0.0009652509652509653}
# Generated Dataset Distribution
# {'D': 0.4393939393939394, 'G': 0.19696969696969696, 'C': 0.10606060606060606, 'Em': 0.09090909090909091, 'A': 0.07575757575757576, 'F': 0.045454545454545456, 'Dm': 0.030303030303030304, 'Am': 0.015151515151515152}
#
# Unique 'K' values to generated dataset: []
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 231.55
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 54.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.41324066530172276
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Increased Complexity

# %%
model_weights_directory = 'drive/MyDrive/Data/Model_Weights/Model_3/2ExtraLayers128/'
generated_samples_directory = 'drive/MyDrive/Data/Generated_Samples/Model_3/2ExtraLayers128/'

# %%
batch_size = 64
seq_length = 64
num_epochs = 200

# %%
optimizer_ = tf.keras.optimizers.Adam()

model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.2))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.2))

model.add(LSTM(128, return_sequences = True, stateful = True))
model.add(Dropout(0.2))

model.add(LSTM(128, return_sequences = True, stateful = True))
model.add(Dropout(0.2))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))

 
model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_401"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_401 (Embedding)    (64, 64, 512)             47616
# _________________________________________________________________
# lstm_802 (LSTM)              (64, 64, 512)             2099200
# _________________________________________________________________
# dropout_802 (Dropout)        (64, 64, 512)             0
# _________________________________________________________________
# lstm_803 (LSTM)              (64, 64, 512)             2099200
# _________________________________________________________________
# dropout_803 (Dropout)        (64, 64, 512)             0
# _________________________________________________________________
# lstm_804 (LSTM)              (64, 64, 128)             328192
# _________________________________________________________________
# dropout_804 (Dropout)        (64, 64, 128)             0
# _________________________________________________________________
# lstm_805 (LSTM)              (64, 64, 128)             131584
# _________________________________________________________________
# dropout_805 (Dropout)        (64, 64, 128)             0
# _________________________________________________________________
# time_distributed_1 (TimeDist (64, 64, 93)              11997
# _________________________________________________________________
# activation_401 (Activation)  (64, 64, 93)              0
# =================================================================
# Total params: 4,717,789
# Trainable params: 4,717,789
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)

print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 0.45386603474617004
# Accuracy: 0.8515625

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.2))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.2))

    generator_model.add(LSTM(128, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.2))

    generator_model.add(LSTM(128, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.2))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 73
seq_length = 500

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# %%
evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '5/4': 0.0009652509652509653, '6/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'4/4': 0.4246575342465753, '6/8': 0.3835616438356164, '2/4': 0.0821917808219178, '3/4': 0.0684931506849315, '9/8': 0.0273972602739726, '44/8': 0.0136986301369863}
#
# Unique 'M' values to generated dataset: ['44/8']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'Cm': 0.0009652509652509653, 'B': 0.0009652509652509653, 'E': 0.0009652509652509653}
# Generated Dataset Distribution
# {'G': 0.3977272727272727, 'D': 0.3522727272727273, 'A': 0.125, 'Am': 0.045454545454545456, 'C': 0.03409090909090909, 'Gm': 0.022727272727272728, 'Bb': 0.011363636363636364, 'Em': 0.011363636363636364}
#
# Unique 'K' values to generated dataset: []
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 294.53
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 27.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.38494022053802107
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Increasing dropout

# %%
model_weights_directory = 'drive/MyDrive/Data/Model_Weights/Model_3/Dropout0.4_2ExtraLayers128/'
generated_samples_directory = 'drive/MyDrive/Data/Generated_Samples/Model_3/Dropout0.4_2ExtraLayers128/'

# %%
batch_size = 64
seq_length = 64
num_epochs = 200

# %%
optimizer_ = tf.keras.optimizers.Adam()

model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.4))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.4))

model.add(LSTM(128, return_sequences = True, stateful = True))
model.add(Dropout(0.4))

model.add(LSTM(128, return_sequences = True, stateful = True))
model.add(Dropout(0.4))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))

 
model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (64, 64, 512)             47616
# _________________________________________________________________
# lstm_8 (LSTM)                (64, 64, 512)             2099200
# _________________________________________________________________
# dropout_8 (Dropout)          (64, 64, 512)             0
# _________________________________________________________________
# lstm_9 (LSTM)                (64, 64, 512)             2099200
# _________________________________________________________________
# dropout_9 (Dropout)          (64, 64, 512)             0
# _________________________________________________________________
# lstm_10 (LSTM)               (64, 64, 128)             328192
# _________________________________________________________________
# dropout_10 (Dropout)         (64, 64, 128)             0
# _________________________________________________________________
# lstm_11 (LSTM)               (64, 64, 128)             131584
# _________________________________________________________________
# dropout_11 (Dropout)         (64, 64, 128)             0
# _________________________________________________________________
# time_distributed_1 (TimeDist (64, 64, 93)              11997
# _________________________________________________________________
# activation_2 (Activation)    (64, 64, 93)              0
# =================================================================
# Total params: 4,717,789
# Trainable params: 4,717,789
# Non-trainable params: 0
# _________________________________________________________________

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)

print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 0.5440436005592346
# Accuracy: 0.83935546875

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.4))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.4))

    generator_model.add(LSTM(128, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.4))

    generator_model.add(LSTM(128, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.4))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 84
seq_length = 1000

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '5/4': 0.0009652509652509653, '6/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'4/4': 0.6410256410256411, '6/8': 0.21794871794871795, '3/4': 0.0641025641025641, '9/8': 0.038461538461538464, '2/4': 0.038461538461538464}
#
# Unique 'M' values to generated dataset: []
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Gm': 0.010617760617760617, 'Bb': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'E': 0.0009652509652509653, 'Cm': 0.0009652509652509653, 'B': 0.0009652509652509653}
# Generated Dataset Distribution
# {'G': 0.3563218390804598, 'D': 0.28735632183908044, 'A': 0.1839080459770115, 'Em': 0.05747126436781609, 'Am': 0.04597701149425287, 'C': 0.034482758620689655, 'Fm': 0.011494252873563218, 'Es': 0.011494252873563218, 'Dm': 0.011494252873563218}
#
# Unique 'K' values to generated dataset: ['Fm', 'Es']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 415.03
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 22.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.34514156496042525
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Increasing dropout further

# %%
model_weights_directory = 'drive/MyDrive/Data/Model_Weights/Model_3/Dropout0.6_2ExtraLayers128/'
generated_samples_directory = 'drive/MyDrive/Data/Generated_Samples/Model_3/Dropout0.6_2ExtraLayers128/'

# %%
batch_size = 64
seq_length = 64
num_epochs = 200

# %%
optimizer_ = tf.keras.optimizers.Adam()

model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.6))

model.add(LSTM(512, return_sequences = True, stateful = True))
model.add(Dropout(0.6))

model.add(LSTM(128, return_sequences = True, stateful = True))
model.add(Dropout(0.6))

model.add(LSTM(128, return_sequences = True, stateful = True))
model.add(Dropout(0.6))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))

 
model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (64, 64, 512)             47616
# _________________________________________________________________
# lstm (LSTM)                  (64, 64, 512)             2099200
# _________________________________________________________________
# dropout (Dropout)            (64, 64, 512)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (64, 64, 512)             2099200
# _________________________________________________________________
# dropout_1 (Dropout)          (64, 64, 512)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (64, 64, 128)             328192
# _________________________________________________________________
# dropout_2 (Dropout)          (64, 64, 128)             0
# _________________________________________________________________
# lstm_3 (LSTM)                (64, 64, 128)             131584
# _________________________________________________________________
# dropout_3 (Dropout)          (64, 64, 128)             0
# _________________________________________________________________
# time_distributed (TimeDistri (64, 64, 93)              11997
# _________________________________________________________________
# activation (Activation)      (64, 64, 93)              0
# =================================================================
# Total params: 4,717,789
# Trainable params: 4,717,789
# Non-trainable params: 0
# _________________________________________________________________

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)

print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 0.8126569390296936
# Accuracy: 0.743896484375

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.6))

    generator_model.add(LSTM(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.6))

    generator_model.add(LSTM(128, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.6))

    generator_model.add(LSTM(128, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.6))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 84
seq_length = 1000

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

# %%
generated_df
# Out:
#    transcription
# 0
# 1
# 2
# 3
# 4
# ..           ...
# 95
# 96
# 97
# 98
# 99
#
# [100 rows x 1 columns]

# %%
# Since that didn't work, we can try reducing the complexity (in terms of the number of hidden units) with the same dropout instead

# %% [markdown]
# # Reducing complexity - hidden units

# %%
model_weights_directory = 'drive/MyDrive/Data/Model_Weights/Model_3/Dropout0.4_DecreaseComplextyHiddenUnits/'
generated_samples_directory = 'drive/MyDrive/Data/Generated_Samples/Model_3/Dropout0.4_DecreaseComplextyHiddenUnits/'

# %%
batch_size = 64
seq_length = 64
num_epochs = 200

# %%
optimizer_ = tf.keras.optimizers.Adam()

model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(256, return_sequences = True, stateful = True))
model.add(Dropout(0.4))

model.add(LSTM(256, return_sequences = True, stateful = True))
model.add(Dropout(0.4))

model.add(LSTM(128, return_sequences = True, stateful = True))
model.add(Dropout(0.4))

model.add(LSTM(128, return_sequences = True, stateful = True))
model.add(Dropout(0.4))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))

 
model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_101"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_101 (Embedding)    (64, 64, 512)             47616
# _________________________________________________________________
# lstm_404 (LSTM)              (64, 64, 256)             787456
# _________________________________________________________________
# dropout_404 (Dropout)        (64, 64, 256)             0
# _________________________________________________________________
# lstm_405 (LSTM)              (64, 64, 256)             525312
# _________________________________________________________________
# dropout_405 (Dropout)        (64, 64, 256)             0
# _________________________________________________________________
# lstm_406 (LSTM)              (64, 64, 128)             197120
# _________________________________________________________________
# dropout_406 (Dropout)        (64, 64, 128)             0
# _________________________________________________________________
# lstm_407 (LSTM)              (64, 64, 128)             131584
# _________________________________________________________________
# dropout_407 (Dropout)        (64, 64, 128)             0
# _________________________________________________________________
# time_distributed_1 (TimeDist (64, 64, 93)              11997
# _________________________________________________________________
# activation_101 (Activation)  (64, 64, 93)              0
# =================================================================
# Total params: 1,701,085
# Trainable params: 1,701,085
# Non-trainable params: 0
# _________________________________________________________________

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)

print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 0.8181054592132568
# Accuracy: 0.750244140625

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(256, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.4))

    generator_model.add(LSTM(256, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.4))

    generator_model.add(LSTM(128, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.4))

    generator_model.add(LSTM(128, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.4))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 84
seq_length = 1000

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '6/4': 0.0009652509652509653, '5/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'6/8': 0.43636363636363634, '4/4': 0.38181818181818183, '3/4': 0.16363636363636364, '9/8': 0.01818181818181818}
#
# Unique 'M' values to generated dataset: []
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Gm': 0.010617760617760617, 'Bb': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'E': 0.0009652509652509653, 'B': 0.0009652509652509653, 'Cm': 0.0009652509652509653}
# Generated Dataset Distribution
# {'D': 0.375, 'G': 0.2857142857142857, 'C': 0.10714285714285714, 'A': 0.08928571428571429, 'Em': 0.03571428571428571, 'Am': 0.03571428571428571, 'F': 0.03571428571428571, 'B/2B3 -A2F A2B|"Am"A2E "D"A2B|"D7"B2d "G7"cdd|"G"G6|"Cm"EGc A2e|': 0.017857142857142856, 'Cm': 0.017857142857142856}
#
# Unique 'K' values to generated dataset: ['B/2B3 -A2F A2B|"Am"A2E "D"A2B|"D7"B2d "G7"cdd|"G"G6|"Cm"EGc A2e|']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 196.62
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 47.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.2276237972880628
# -------------------------------------------------------------------------------------

# %%
seed_index = 84
seq_length = 1200

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '6/4': 0.0009652509652509653, '5/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'4/4': 0.5294117647058824, '6/8': 0.35294117647058826, '3/4': 0.09803921568627451, '1/4': 0.0196078431372549}
#
# Unique 'M' values to generated dataset: ['1/4']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Gm': 0.010617760617760617, 'Bb': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'E': 0.0009652509652509653, 'B': 0.0009652509652509653, 'Cm': 0.0009652509652509653}
# Generated Dataset Distribution
# {'G': 0.41509433962264153, 'D': 0.32075471698113206, 'A': 0.09433962264150944, 'C': 0.07547169811320754, 'Am': 0.05660377358490566, 'Bm': 0.018867924528301886, 'E': 0.018867924528301886}
#
# Unique 'K' values to generated dataset: []
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 192.18
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 49.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.2171210062489768
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Reverting dropout back to 0.2 with new complexity

# %%
model_weights_directory = 'drive/MyDrive/Data/Model_Weights/Model_3/Dropout0.2_DecreaseComplextyHiddenUnits/'
generated_samples_directory = 'drive/MyDrive/Data/Generated_Samples/Model_3/Dropout0.2_DecreaseComplextyHiddenUnits/'

# %%
batch_size = 64
seq_length = 64
num_epochs = 100

# %%
optimizer_ = tf.keras.optimizers.Adam()

model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(256, return_sequences = True, stateful = True))
model.add(Dropout(0.2))

model.add(LSTM(256, return_sequences = True, stateful = True))
model.add(Dropout(0.2))

model.add(LSTM(128, return_sequences = True, stateful = True))
model.add(Dropout(0.2))

model.add(LSTM(128, return_sequences = True, stateful = True))
model.add(Dropout(0.2))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))

 
model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (64, 64, 512)             47616
# _________________________________________________________________
# lstm (LSTM)                  (64, 64, 256)             787456
# _________________________________________________________________
# dropout (Dropout)            (64, 64, 256)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (64, 64, 256)             525312
# _________________________________________________________________
# dropout_1 (Dropout)          (64, 64, 256)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (64, 64, 128)             197120
# _________________________________________________________________
# dropout_2 (Dropout)          (64, 64, 128)             0
# _________________________________________________________________
# lstm_3 (LSTM)                (64, 64, 128)             131584
# _________________________________________________________________
# dropout_3 (Dropout)          (64, 64, 128)             0
# _________________________________________________________________
# time_distributed (TimeDistri (64, 64, 93)              11997
# _________________________________________________________________
# activation (Activation)      (64, 64, 93)              0
# =================================================================
# Total params: 1,701,085
# Trainable params: 1,701,085
# Non-trainable params: 0
# _________________________________________________________________

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)

print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/100
# Epoch 2/100
# Epoch 3/100
# Epoch 4/100
# Epoch 5/100
# Epoch 6/100
# Epoch 7/100
# Epoch 8/100
# Epoch 9/100
# Epoch 10/100
# Epoch 11/100
# Epoch 12/100
# Epoch 13/100
# Epoch 14/100
# Epoch 15/100
# Epoch 16/100
# Epoch 17/100
# Epoch 18/100
# Epoch 19/100
# Epoch 20/100
# Epoch 21/100
# Epoch 22/100
# Epoch 23/100
# Epoch 24/100
# Epoch 25/100
# Epoch 26/100
# Epoch 27/100
# Epoch 28/100
# Epoch 29/100
# Epoch 30/100
# Epoch 31/100
# Epoch 32/100
# Epoch 33/100
# Epoch 34/100
# Epoch 35/100
# Epoch 36/100
# Epoch 37/100
# Epoch 38/100
# Epoch 39/100
# Epoch 40/100
# Epoch 41/100
# Epoch 42/100
# Epoch 43/100
# Epoch 44/100
# Epoch 45/100
# Epoch 46/100
# Epoch 47/100
# Epoch 48/100
# Epoch 49/100
# Epoch 50/100
# Epoch 51/100
# Epoch 52/100
# Epoch 53/100
# Epoch 54/100
# Epoch 55/100
# Epoch 56/100
# Epoch 57/100
# Epoch 58/100
# Epoch 59/100
# Epoch 60/100
# Epoch 61/100
# Epoch 62/100
# Epoch 63/100
# Epoch 64/100
# Epoch 65/100
# Epoch 66/100
# Epoch 67/100
# Epoch 68/100
# Epoch 69/100
# Epoch 70/100
# Epoch 71/100
# Epoch 72/100
# Epoch 73/100
# Epoch 74/100
# Epoch 75/100
# Epoch 76/100
# Epoch 77/100
# Epoch 78/100
# Epoch 79/100
# Epoch 80/100
# Epoch 81/100
# Epoch 82/100
# Epoch 83/100
# Epoch 84/100
# Epoch 85/100
# Epoch 86/100
# Epoch 87/100
# Epoch 88/100
# Epoch 89/100
# Epoch 90/100
# Epoch 91/100
# Epoch 92/100
# Epoch 93/100
# Epoch 94/100
# Epoch 95/100
# Epoch 96/100
# Epoch 97/100
# Epoch 98/100
# Epoch 99/100
# Epoch 100/100
# Loss: 0.8077231645584106
# Accuracy: 0.744140625

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(256, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.2))

    generator_model.add(LSTM(256, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.2))

    generator_model.add(LSTM(128, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.2))

    generator_model.add(LSTM(128, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.2))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 84
seq_length = 1000

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '5/4': 0.0009652509652509653, '6/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'6/8': 0.5625, '4/4': 0.375, '9/8': 0.0625}
#
# Unique 'M' values to generated dataset: []
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'B': 0.0009652509652509653, 'Cm': 0.0009652509652509653, 'E': 0.0009652509652509653}
# Generated Dataset Distribution
# {'G': 0.4, 'D': 0.3, 'A': 0.1, 'Am': 0.1, 'C': 0.05, 'F': 0.05}
#
# Unique 'K' values to generated dataset: []
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 160.5
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 84.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.10309142990209043
# -------------------------------------------------------------------------------------

# %%
seed_index = 73
seq_length = 600

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '6/4': 0.0009652509652509653, '5/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'6/8': 0.3333333333333333, '6': 0.16666666666666666, '3/4': 0.16666666666666666, '2/4': 0.16666666666666666, '4/4': 0.16666666666666666}
#
# Unique 'M' values to generated dataset: ['6']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'E': 0.0009652509652509653, 'Cm': 0.0009652509652509653, 'B': 0.0009652509652509653}
# Generated Dataset Distribution
# {'D': 0.3333333333333333, 'G': 0.3333333333333333, 'C': 0.16666666666666666, 'Am': 0.16666666666666666}
#
# Unique 'K' values to generated dataset: []
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 69.16
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 95.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.043774603541224574
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Test

# %%
model_weights_directory = 'drive/MyDrive/Data/Model_Weights/Model_3/Test/'
generated_samples_directory = 'drive/MyDrive/Data/Generated_Samples/Model_3/Test/'

# %%
batch_size = 64
seq_length = 64
num_epochs = 200

# %%
optimizer_ = tf.keras.optimizers.Adam()

model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(LSTM(256, return_sequences = True, stateful = True))
model.add(Dropout(0.4))

model.add(LSTM(256, return_sequences = True, stateful = True))
model.add(Dropout(0.4))

model.add(LSTM(128, return_sequences = True, stateful = True))
model.add(Dropout(0.2))

model.add(LSTM(128, return_sequences = True, stateful = True))
model.add(Dropout(0.2))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))

 
model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_202"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_202 (Embedding)    (64, 64, 512)             47616
# _________________________________________________________________
# lstm_808 (LSTM)              (64, 64, 256)             787456
# _________________________________________________________________
# dropout_808 (Dropout)        (64, 64, 256)             0
# _________________________________________________________________
# lstm_809 (LSTM)              (64, 64, 256)             525312
# _________________________________________________________________
# dropout_809 (Dropout)        (64, 64, 256)             0
# _________________________________________________________________
# lstm_810 (LSTM)              (64, 64, 128)             197120
# _________________________________________________________________
# dropout_810 (Dropout)        (64, 64, 128)             0
# _________________________________________________________________
# lstm_811 (LSTM)              (64, 64, 128)             131584
# _________________________________________________________________
# dropout_811 (Dropout)        (64, 64, 128)             0
# _________________________________________________________________
# time_distributed_2 (TimeDist (64, 64, 93)              11997
# _________________________________________________________________
# activation_202 (Activation)  (64, 64, 93)              0
# =================================================================
# Total params: 1,701,085
# Trainable params: 1,701,085
# Non-trainable params: 0
# _________________________________________________________________

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)

print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 0.7880010604858398
# Accuracy: 0.75

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(LSTM(256, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.4))

    generator_model.add(LSTM(256, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.4))

    generator_model.add(LSTM(128, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.2))

    generator_model.add(LSTM(128, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.2))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 84
seq_length = 1200

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '5/4': 0.0009652509652509653, '6/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'4/4': 0.5714285714285714, '6/8': 0.38095238095238093, ':s/4': 0.047619047619047616}
#
# Unique 'M' values to generated dataset: [':s/4']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'E': 0.0009652509652509653, 'B': 0.0009652509652509653, 'Cm': 0.0009652509652509653}
# Generated Dataset Distribution
# {'G': 0.40540540540540543, 'D': 0.2702702702702703, 'A': 0.10810810810810811, 'C': 0.08108108108108109, 'Em': 0.05405405405405406, '-a|"Eb"G/2A/2B/2A/2G/2A/2|Bs:|': 0.02702702702702703, 'Am': 0.02702702702702703, 'C "D7"Eee|"G"d2e Bdc|"G"G3 G2||': 0.02702702702702703}
#
# Unique 'K' values to generated dataset: ['-a|"Eb"G/2A/2B/2A/2G/2A/2|Bs:|', 'C "D7"Eee|"G"d2e Bdc|"G"G3 G2||']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 263.2
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 81.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.3230220462300183
# -------------------------------------------------------------------------------------

# %%
seed_index = 86
seq_length = 1200

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '5/4': 0.0009652509652509653, '6/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'4/4': 0.3870967741935484, '6/8': 0.3548387096774194, '3/4': 0.0967741935483871, '1/4': 0.06451612903225806, '9/8': 0.06451612903225806, 'T/4': 0.03225806451612903}
#
# Unique 'M' values to generated dataset: ['1/4', 'T/4']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'E': 0.0009652509652509653, 'B': 0.0009652509652509653, 'Cm': 0.0009652509652509653}
# Generated Dataset Distribution
# {'D': 0.32, 'G': 0.26, 'A': 0.14, 'C': 0.14, 'Em': 0.06, 'Go^%P:Her, vA7"a "G"A2B|B2B "Am"AgB c2A|': 0.02, 'Dm': 0.02, 'Gm': 0.02, 'F': 0.02}
#
# Unique 'K' values to generated dataset: ['Go^%P:Her, vA7"a "G"A2B|B2B "Am"AgB c2A|']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 277.87
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 72.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.3466243570680526
# -------------------------------------------------------------------------------------

# %% [markdown]
# # GRU

# %%
model_weights_directory = 'drive/MyDrive/Data/Model_Weights/Model_3/GRU/'
generated_samples_directory = 'drive/MyDrive/Data/Generated_Samples/Model_3/GRU/'

# %%
batch_size = 64
seq_length = 64
num_epochs = 200

# %%
optimizer_ = tf.keras.optimizers.Adam()

model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(GRU(256, return_sequences = True, stateful = True))
model.add(Dropout(0.4))

model.add(GRU(256, return_sequences = True, stateful = True))
model.add(Dropout(0.4))

model.add(GRU(128, return_sequences = True, stateful = True))
model.add(Dropout(0.4))

model.add(GRU(128, return_sequences = True, stateful = True))
model.add(Dropout(0.4))

model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))

 
model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_403"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_403 (Embedding)    (64, 64, 512)             47616
# _________________________________________________________________
# gru (GRU)                    (64, 64, 256)             591360
# _________________________________________________________________
# dropout_1612 (Dropout)       (64, 64, 256)             0
# _________________________________________________________________
# gru_1 (GRU)                  (64, 64, 256)             394752
# _________________________________________________________________
# dropout_1613 (Dropout)       (64, 64, 256)             0
# _________________________________________________________________
# gru_2 (GRU)                  (64, 64, 128)             148224
# _________________________________________________________________
# dropout_1614 (Dropout)       (64, 64, 128)             0
# _________________________________________________________________
# gru_3 (GRU)                  (64, 64, 128)             99072
# _________________________________________________________________
# dropout_1615 (Dropout)       (64, 64, 128)             0
# _________________________________________________________________
# time_distributed_3 (TimeDist (64, 64, 93)              11997
# _________________________________________________________________
# activation_403 (Activation)  (64, 64, 93)              0
# =================================================================
# Total params: 1,293,021
# Trainable params: 1,293,021
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)

print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 0.6684197783470154
# Accuracy: 0.804443359375

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(GRU(256, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.4))

    generator_model.add(GRU(256, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.4))

    generator_model.add(GRU(128, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.4))

    generator_model.add(GRU(128, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.4))

    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 86
seq_length = 1000

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '5/4': 0.0009652509652509653, '6/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'4/4': 0.6451612903225806, '6/8': 0.22580645161290322, '3/4': 0.0967741935483871, '2/2': 0.03225806451612903}
#
# Unique 'M' values to generated dataset: []
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'E': 0.0009652509652509653, 'B': 0.0009652509652509653, 'Cm': 0.0009652509652509653}
# Generated Dataset Distribution
# {'D': 0.38596491228070173, 'G': 0.3333333333333333, 'C': 0.12280701754385964, 'F': 0.05263157894736842, 'A': 0.03508771929824561, 'D3': 0.017543859649122806, 'd': 0.017543859649122806, 'Em': 0.017543859649122806, '': 0.017543859649122806}
#
# Unique 'K' values to generated dataset: ['D3', 'd', '']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 388.22
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 70.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.36251709167493573
# -------------------------------------------------------------------------------------

# %%
generated_df
# Out:
#                                         transcription    K    M
# 0   ff/2e/2 A/2B/2A/2G/2|c3/2A/2c/2B/2 A3/2B/2c|d3...  NaN  NaN
# 1   AB|Adfa bgaf|gbg agge|A2|Aba gfef|"F#m"e2c2 "G...  NaN  NaN
# 2   "F"ffe f3|"F7"e3/2e/2c/2A/2 "G7"B^A/2B/2|"C"cc...    F  NaN
# 3   A2fa|"A7""E7"g2f2 e2d2|"A7"cBcd efe3|"D"dcde "...  NaN  NaN
# 4   BA|"G"GFDG B2dg|"C"ec(3cBc "G"dedB|"Am"AcBA "E...    G  4/4
# ..                                                ...  ...  ...
# 95  FGF DEF|GFG C2D|EGF EFE|:G|"F#m"F2C DAB|"C"ccB...    F  NaN
# 96  "D"FAA FAd|"Em"BAB dAB|"Em"G3/2F/2G "A7""Em"G2...  NaN  NaN
# 97  "D"a2f "C"g3|"F"c2c "G7"ded|"F"c2c "Gm"dBc|"F"...  NaN  NaN
# 98  F/2G/2A/2B/2 c/2d/2e/2fd/2|"C"=e/2f/2c/2f/2 a/...  NaN  NaN
# 99  ddc czB|"G"BGG Gdd|"C"edc "G"BGG|"C"cBc edc|"D...  NaN  NaN
#
# [100 rows x 3 columns]

# %% [markdown]
# # GRU with more complexirty

# %%
model_weights_directory = 'drive/MyDrive/Data/Model_Weights/Model_3/GRU_IncreaseComplexity2Layers/'
generated_samples_directory = 'drive/MyDrive/Data/Generated_Samples/Model_3/GRU_IncreaseComplexity2Layers/'

# %%
batch_size = 64
seq_length = 64
num_epochs = 200

# %%
optimizer_ = tf.keras.optimizers.Adam()

model = Sequential()
    
model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (batch_size, seq_length))) 

model.add(GRU(512, return_sequences = True, stateful = True))
model.add(Dropout(0.4))

model.add(GRU(512, return_sequences = True, stateful = True))
model.add(Dropout(0.4))

model.add(GRU(256, return_sequences = True, stateful = True))
model.add(Dropout(0.4))

model.add(GRU(256, return_sequences = True, stateful = True))
model.add(Dropout(0.4))




model.add(TimeDistributed(Dense(num_unique_chars)))

model.add(Activation("softmax"))

 
model.compile(loss = "categorical_crossentropy", optimizer = optimizer_, metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_504"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_504 (Embedding)    (64, 64, 512)             47616
# _________________________________________________________________
# gru_404 (GRU)                (64, 64, 512)             1575936
# _________________________________________________________________
# dropout_2016 (Dropout)       (64, 64, 512)             0
# _________________________________________________________________
# gru_405 (GRU)                (64, 64, 512)             1575936
# _________________________________________________________________
# dropout_2017 (Dropout)       (64, 64, 512)             0
# _________________________________________________________________
# gru_406 (GRU)                (64, 64, 256)             591360
# _________________________________________________________________
# dropout_2018 (Dropout)       (64, 64, 256)             0
# _________________________________________________________________
# gru_407 (GRU)                (64, 64, 256)             394752
# _________________________________________________________________
# dropout_2019 (Dropout)       (64, 64, 256)             0
# _________________________________________________________________
# time_distributed_4 (TimeDist (64, 64, 93)              23901
# _________________________________________________________________
# activation_504 (Activation)  (64, 64, 93)              0
# =================================================================
# Total params: 4,209,501
# Trainable params: 4,209,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %%
for epoch in range(1, num_epochs+1):
    print(f"Epoch {epoch}/{num_epochs}")

    for j, (x, y) in enumerate(data_loader(all_characters, num_unique_chars, batch_size, seq_length)):
        loss, accuracy = model.train_on_batch(x, y)

print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

model.save_weights(os.path.join(model_weights_directory, "Weights_{}.h5".format(epoch)))
# Out:
# Epoch 1/200
# Epoch 2/200
# Epoch 3/200
# Epoch 4/200
# Epoch 5/200
# Epoch 6/200
# Epoch 7/200
# Epoch 8/200
# Epoch 9/200
# Epoch 10/200
# Epoch 11/200
# Epoch 12/200
# Epoch 13/200
# Epoch 14/200
# Epoch 15/200
# Epoch 16/200
# Epoch 17/200
# Epoch 18/200
# Epoch 19/200
# Epoch 20/200
# Epoch 21/200
# Epoch 22/200
# Epoch 23/200
# Epoch 24/200
# Epoch 25/200
# Epoch 26/200
# Epoch 27/200
# Epoch 28/200
# Epoch 29/200
# Epoch 30/200
# Epoch 31/200
# Epoch 32/200
# Epoch 33/200
# Epoch 34/200
# Epoch 35/200
# Epoch 36/200
# Epoch 37/200
# Epoch 38/200
# Epoch 39/200
# Epoch 40/200
# Epoch 41/200
# Epoch 42/200
# Epoch 43/200
# Epoch 44/200
# Epoch 45/200
# Epoch 46/200
# Epoch 47/200
# Epoch 48/200
# Epoch 49/200
# Epoch 50/200
# Epoch 51/200
# Epoch 52/200
# Epoch 53/200
# Epoch 54/200
# Epoch 55/200
# Epoch 56/200
# Epoch 57/200
# Epoch 58/200
# Epoch 59/200
# Epoch 60/200
# Epoch 61/200
# Epoch 62/200
# Epoch 63/200
# Epoch 64/200
# Epoch 65/200
# Epoch 66/200
# Epoch 67/200
# Epoch 68/200
# Epoch 69/200
# Epoch 70/200
# Epoch 71/200
# Epoch 72/200
# Epoch 73/200
# Epoch 74/200
# Epoch 75/200
# Epoch 76/200
# Epoch 77/200
# Epoch 78/200
# Epoch 79/200
# Epoch 80/200
# Epoch 81/200
# Epoch 82/200
# Epoch 83/200
# Epoch 84/200
# Epoch 85/200
# Epoch 86/200
# Epoch 87/200
# Epoch 88/200
# Epoch 89/200
# Epoch 90/200
# Epoch 91/200
# Epoch 92/200
# Epoch 93/200
# Epoch 94/200
# Epoch 95/200
# Epoch 96/200
# Epoch 97/200
# Epoch 98/200
# Epoch 99/200
# Epoch 100/200
# Epoch 101/200
# Epoch 102/200
# Epoch 103/200
# Epoch 104/200
# Epoch 105/200
# Epoch 106/200
# Epoch 107/200
# Epoch 108/200
# Epoch 109/200
# Epoch 110/200
# Epoch 111/200
# Epoch 112/200
# Epoch 113/200
# Epoch 114/200
# Epoch 115/200
# Epoch 116/200
# Epoch 117/200
# Epoch 118/200
# Epoch 119/200
# Epoch 120/200
# Epoch 121/200
# Epoch 122/200
# Epoch 123/200
# Epoch 124/200
# Epoch 125/200
# Epoch 126/200
# Epoch 127/200
# Epoch 128/200
# Epoch 129/200
# Epoch 130/200
# Epoch 131/200
# Epoch 132/200
# Epoch 133/200
# Epoch 134/200
# Epoch 135/200
# Epoch 136/200
# Epoch 137/200
# Epoch 138/200
# Epoch 139/200
# Epoch 140/200
# Epoch 141/200
# Epoch 142/200
# Epoch 143/200
# Epoch 144/200
# Epoch 145/200
# Epoch 146/200
# Epoch 147/200
# Epoch 148/200
# Epoch 149/200
# Epoch 150/200
# Epoch 151/200
# Epoch 152/200
# Epoch 153/200
# Epoch 154/200
# Epoch 155/200
# Epoch 156/200
# Epoch 157/200
# Epoch 158/200
# Epoch 159/200
# Epoch 160/200
# Epoch 161/200
# Epoch 162/200
# Epoch 163/200
# Epoch 164/200
# Epoch 165/200
# Epoch 166/200
# Epoch 167/200
# Epoch 168/200
# Epoch 169/200
# Epoch 170/200
# Epoch 171/200
# Epoch 172/200
# Epoch 173/200
# Epoch 174/200
# Epoch 175/200
# Epoch 176/200
# Epoch 177/200
# Epoch 178/200
# Epoch 179/200
# Epoch 180/200
# Epoch 181/200
# Epoch 182/200
# Epoch 183/200
# Epoch 184/200
# Epoch 185/200
# Epoch 186/200
# Epoch 187/200
# Epoch 188/200
# Epoch 189/200
# Epoch 190/200
# Epoch 191/200
# Epoch 192/200
# Epoch 193/200
# Epoch 194/200
# Epoch 195/200
# Epoch 196/200
# Epoch 197/200
# Epoch 198/200
# Epoch 199/200
# Epoch 200/200
# Loss: 0.5193050503730774
# Accuracy: 0.83935546875

# %%
def make_model(num_unique_chars):
    generator_model = Sequential()

    generator_model.add(Embedding(input_dim = num_unique_chars, output_dim = 512, batch_input_shape = (1, 1))) 

    generator_model.add(GRU(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.4))

    generator_model.add(GRU(512, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.4))

    generator_model.add(GRU(256, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.4))

    generator_model.add(GRU(256, return_sequences = True, stateful = True))
    generator_model.add(Dropout(0.4))


    generator_model.add((Dense(num_unique_chars)))

    generator_model.add(Activation("softmax"))

    return generator_model

# %%
seed_index = 86
seq_length = 1000

music = ''
all_rows = []

for k in range(100):

    generated_sample = generate_sequence(epoch_num = 200, initial_index = seed_index, seq_length = seq_length)
    all_rows.append(convert_sample_to_dict(generated_sample))

    music += generated_sample
    music += '\n'
    music += '\n'


# Write samples to file 
textfile = open(generated_samples_directory+'generated_samples.txt', 'w')
textfile.write(music)
textfile.close()

# Converting samples to a dataframe
generated_df = pd.DataFrame(all_rows)

evaluate_performance(music_df, generated_df)
# Out:
# -------------------------------------------------------------------------------------
# Distribution Comparison - Meter / Time Signature
#
# Original Dataset Distribution
# {'4/4': 0.5222007722007722, '6/8': 0.3581081081081081, '3/4': 0.05694980694980695, '2/4': 0.03861003861003861, '9/8': 0.012548262548262547, '2/2': 0.006756756756756757, '3/2': 0.0028957528957528956, '5/4': 0.0009652509652509653, '6/4': 0.0009652509652509653}
# Generated Dataset Distribution
# {'4/4': 0.47058823529411764, '6/8': 0.4411764705882353, '3/4': 0.058823529411764705, '2/4': 0.029411764705882353}
#
# Unique 'M' values to generated dataset: []
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Distribution Comparison - Key
#
# Original Dataset Distribution
# {'D': 0.35424710424710426, 'G': 0.3359073359073359, 'A': 0.12355212355212356, 'C': 0.05791505791505792, 'Am': 0.037644787644787646, 'Em': 0.02702702702702703, 'F': 0.023166023166023165, 'Dm': 0.013513513513513514, 'Bb': 0.010617760617760617, 'Gm': 0.010617760617760617, 'Bm': 0.0028957528957528956, 'E': 0.0009652509652509653, 'B': 0.0009652509652509653, 'Cm': 0.0009652509652509653}
# Generated Dataset Distribution
# {'G': 0.358974358974359, 'D': 0.3076923076923077, 'A': 0.15384615384615385, 'C': 0.10256410256410256, 'C[': 0.02564102564102564, 'Bm': 0.02564102564102564, 'F': 0.02564102564102564}
#
# Unique 'K' values to generated dataset: ['C[']
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Length Comparison
# Original Average Transcription Length - 334.4150579150579
# Generated Average Transcription Length - 243.96
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Error Rate - 66.0%
# -------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# Average Max Similarity Score - 0.38859189218777707
# -------------------------------------------------------------------------------------
